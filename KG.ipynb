# %% [markdown]
# # Conversational Recommender System : : Knowledge Graph

# %% [markdown]
# Mount your drive with redial_dataset.zip and add its location, then just run all the blocks

# %%
import zipfile

dataset_file_location = './data/input/redial_dataset.zip'

with zipfile.ZipFile( dataset_file_location, 'r') as z:
    z.extractall()

print("Item Loaded")
# Out:
# Item Loaded

# %% [markdown]
# # Preprocessing

# %%
# %pip install jsonlines pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jsonlines in c:\users\taksh\appdata\roaming\python\python311\site-packages (4.0.0)
# Requirement already satisfied: pandas in c:\users\taksh\appdata\roaming\python\python311\site-packages (2.1.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from jsonlines) (23.1.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json

# Function to read a JSONL file and return a list of dictionaries
def read_jsonl(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
    return data

# Function to write a list of dictionaries to a JSONL file
def write_jsonl(file_path, data):
    with open(file_path, 'w') as file:
        for item in data:
            file.write(json.dumps(item) + '\n')

# Input file paths
file1_path = './test_data.jsonl'
file2_path = './train_data.jsonl'

# Read data from both JSONL files
data_from_file1 = read_jsonl(file1_path)
data_from_file2 = read_jsonl(file2_path)

# Combine the data from both files
combined_data = data_from_file1 + data_from_file2

# Output file path for the combined data
output_file_path = 'true_train.jsonl'

# Write the combined data to the output JSONL file
write_jsonl(output_file_path, combined_data)

# %% [markdown]
# # Movie Extraction - Subjects

# %% [markdown]
# movies are directly given in movies_mentions.csv so no need to do much

# %%
import json

# Assuming extracted_data is a dictionary containing the data from the JSON Lines file
extracted_data = {}

# Read data from the JSON Lines file with explicit encoding
with open('./data/generated/movies_with_year.jsonl', 'r', encoding='utf-8') as file:
    for line in file:
        movie_info = json.loads(line)
        movie_id = len(extracted_data) + 1  # You can modify this based on your actual data structure
        extracted_data[movie_id] = movie_info

# Initialize the movie_names_data array
movie_names_data = []

# Modify the code to create the desired list
for movie_id, movie_info in extracted_data.items():
    title = movie_info['name']
    release_year = movie_info['year']
    movie_names_data.append({"title": title, "release_year": release_year})

# Print or use the modified list as needed
print("Length of movie_names_data:", len(movie_names_data))
# Out:
# Length of movie_names_data: 6629

# %% [markdown]
# # Text Extraction - Objects and relations

# %%
# Initialize a list to store the extracted data
messages_text = []

# %%
# Open the JSON lines file and read it line by line
with open('./data/generated/true_train.jsonl', 'r') as json_file:
    for line in json_file:
        # Load and parse each JSON object
        entry = json.loads(line)

        # Check if the entry contains the required fields
        if "conversationId" in entry and "messages" in entry:
            conversation_id = entry["conversationId"]
            messages = [message["text"] for message in entry["messages"]]

            # Create a dictionary for the conversation data
            conversation_data = {
                "conversationId": conversation_id,
                "messages": messages
            }

            # Append the conversation data to the list
            messages_text.append(conversation_data)

# %%
# Write the extracted data to an output .jsonl file
with open('./data/generated/messages_text_data.jsonl', 'w') as output_file:
    for conversation_data in messages_text:
        output_file.write(json.dumps(conversation_data) + '\n')

# %%
import json

# Initialize a list to store the extracted data
conversation_data_list = []

# %%
# Open the JSON lines file and read it line by line
with open('./data/generated/true_train.jsonl', 'r') as json_file:
    for line in json_file:
        # Load and parse each JSON object
        entry = json.loads(line)

        # Check if the entry contains the required fields
        if "conversationId" in entry and "messages" in entry:
            conversation_id = entry["conversationId"]
            messages = entry["messages"]

            # Initialize variables to store concatenated messages
            concatenated_messages = []
            current_sender_id = ""
            current_message = ""

            # Iterate through messages
            for message in messages:
                sender_id = message['senderWorkerId']
                text = message['text']

                # Check if senderWorkerID is the same as the previous message
                if sender_id == current_sender_id:
                    # Concatenate the messages
                    current_message += " " + text
                else:
                    concatenated_messages.append(current_message)
                    current_message = text


                # Start a new concatenated message
                current_sender_id = sender_id

            # Last message should be added
            concatenated_messages.append(current_message)

            # Create a dictionary for the conversation data
            conversation_data = {
                "conversationId": conversation_id,
                "messages": concatenated_messages
            }

            # Append the conversation data to the list
            conversation_data_list.append(conversation_data)

# %%
conversation_data_list[1]
# Out:
# {'conversationId': '20041',
#  'messages': ['',
#   'Hello!',
#   'Hello!',
#   'What kind of movies do you like?',
#   'I am looking for a movie recommendation.   When I was younger I really enjoyed the @77161',
#   'Oh, you like scary movies? I recently watched @204334',
#   'I also enjoyed watching @132562',
#   'It was really good for a new &quot;scary movie&quot;',
#   'I do enjoy some of the newer horror movies that I have seen as well.',
#   'I heard that @205430 is good. It is still in theaters though.',
#   'I really liked the movie @125431',
#   'Me, too! It was really creepy, but I thought it was good!',
#   'Or @118338 I saw while in theaters, this was a very good movie.  It had me on the edge of my seat for the whole show.',
#   "I'm not sure if I saw that one, I'll have to check into it. Sounds familiar, but not sure. Thank you for your suggestions!",
#   'Are there any comedies that you would suggest?',
#   'Sure! I like comedies a lot. I like movies like @175203 and @111776 , but I also like @187061 and @157765 .',
#   'Wonderful! Thank you so much I think I am ready for movie night now.',
#   'No problem! Thank you, too! :)']}

# %%
# Write the extracted data to an output .jsonl file
with open('./data/generated/output.jsonl', 'w') as output_file:
    for conversation_data in conversation_data_list:
        output_file.write(json.dumps(conversation_data) + '\n')

# %% [markdown]
# Can Be further Processed for movie to movie relation

# %% [markdown]
# ## Objects

# %% [markdown]
# ### People

# %%
# Function to read a JSONL file and return a list of dictionaries

relations_people_data = []

def read_jsonl(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            relations_people_data.append(json.loads(line))
    return relations_people_data

read_jsonl("./bin/input/filtered_actor_names.jsonl")
# Out:
# [{'391': ['Alec Baldwin']},
#  {'395': []},
#  {'397': []},
#  {'405': ['Drew Barrymore']},
#  {'407': []},
#  {'411': []},
#  {'415': ['New Orleans']},
#  {'418': ['Quentin Tarantino', 'Stephen King']},
#  {'419': ['Will Smith', 'Tom Cruise', 'Jeff Bridges']},
#  {'426': ['Kevin Hart']},
#  {'450': []},
#  {'455': []},
#  {'458': ['Kevin Hart', 'Will Ferrel', 'Ice Cube', 'Mark Wahlberg']},
#  {'459': ['Martin Lawrence', 'Kevin Hart', 'Adam Sandler', 'Damon Wayans']},
#  {'461': []},
#  {'462': ['Jack Black', 'Jim Carey']},
#  {'463': ['Bill Murphy', 'Leslie Nielsen']},
#  {'464': ['Tom Hardy', 'Reese Witherspoon', 'Tom Cruise', 'Chris Pine']},
#  {'465': ['Bruce Willis', 'Samuel Jackson']},
#  {'466': ['Mark Rylance']},
#  {'467': []},
#  {'468': ['Kevin Hart']},
#  {'469': []},
#  {'470': ['Jim Carrey']},
#  {'471': ['Taylor Kitsch', 'Salma Hayek', 'Blake Lively']},
#  {'474': []},
#  {'475': ['Reese Witherspoon']},
#  {'477': ['Michelle Rodriguez']},
#  {'480': []},
#  {'481': ['Alfred Hitchcock']},
#  {'482': ['Queen Latifah', 'John Travolta']},
#  {'484': ['Eddie Murphy']},
#  {'485': ['Catherine Zeta Jones', 'Queen Latifa']},
#  {'487': []},
#  {'502': ['Kevin Hart', 'Kurt Russel', 'Will Farrell', 'Morgan Freeman']},
#  {'503': ['Billy Bob', 'Bad Santa', 'Billy Bob Thornton']},
#  {'507': ['Amy Adams']},
#  {'512': ['Anne Hathaway', 'Sci Fi']},
#  {'513': []},
#  {'514': ['Will Ferrell', 'Tracey Morgan', 'Bruce Willis']},
#  {'516': []},
#  {'518': []},
#  {'519': ['Kevin Hart', 'Will Farrell']},
#  {'522': []},
#  {'533': []},
#  {'538': []},
#  {'540': ['Anthony Hopkins', 'Eddie Norton']},
#  {'542': []},
#  {'543': []},
#  {'544': ['Black Panther']},
#  {'554': ['Bryan Cranston', 'James Franco', 'Adam Sandler']},
#  {'556': ['Diane Lane', 'Rob Zombie', 'Richard Gere']},
#  {'557': ['Star Wars']},
#  {'558': []},
#  {'560': ['Adam Sandler']},
#  {'561': ['Bing Crosby']},
#  {'563': []},
#  {'564': []},
#  {'567': ['Michael Douglas']},
#  {'569': ['Big Fish', 'Jeff Bridges']},
#  {'570': []},
#  {'571': ['Jack Black']},
#  {'573': ['Stephen King']},
#  {'575': []},
#  {'579': ['Hugh Grant']},
#  {'582': ['Anne Hathaway', 'Adam Sandler', 'Jeff Bridges', 'Owen Wilson']},
#  {'583': []},
#  {'584': ['James Cameron']},
#  {'585': ['Steve Zahn', 'Paul Walker']},
#  {'586': ['Ed Harris', 'Abbie Cornish', 'The Rock']},
#  {'588': ['Kevin Spacey']},
#  {'589': []},
#  {'590': []},
#  {'593': ['Jason Statham']},
#  {'595': []},
#  {'596': []},
#  {'599': []},
#  {'600': ['Keanu Reeves']},
#  {'601': []},
#  {'602': []},
#  {'603': ['Arnold Schwarzenegger', 'Sylvester Stallone']},
#  {'606': ['Brad Pitt', 'Harrison Ford']},
#  {'609': ['Anthony Hopkins', 'Sir Ben Kingsley']},
#  {'610': []},
#  {'611': ['Natalie Portman', 'Naomi Watts', 'Ben Kingsley', 'Susan Sarandon']},
#  {'612': []},
#  {'613': ['Kevin Hart', 'Will Farrell']},
#  {'614': ['Sci Fi']},
#  {'615': ['The Sheriff']},
#  {'616': ['John Carpenter', 'Rob Zombie', 'Anthony Hopkins']},
#  {'619': ['Sci Fi', 'De Niro']},
#  {'620': []},
#  {'622': []},
#  {'624': []},
#  {'625': ['Paul Rodriguez']},
#  {'626': []},
#  {'627': []},
#  {'628': ['Sci Fi']},
#  {'629': []},
#  {'630': []},
#  {'632': ['Tony Jaa']},
#  {'633': []},
#  {'654': ['Amy Adams']},
#  {'657': []},
#  {'659': []},
#  {'661': ['Clint Eastwood']},
#  {'663': []},
#  {'664': []},
#  {'665': []},
#  {'668': []},
#  {'669': ['Wes Anderson']},
#  {'671': []},
#  {'672': []},
#  {'674': []},
#  {'681': []},
#  {'710': ['Kevin Smith']},
#  {'718': []},
#  {'722': []},
#  {'734': []},
#  {'735': []},
#  {'736': []},
#  {'737': []},
#  {'738': ['Gerard Butler']},
#  {'742': []},
#  {'762': ['Stephen King']},
#  {'763': ['Wesley Snipes', 'Sean Connery']},
#  {'764': []},
#  {'766': []},
#  {'767': ['The Mummy']},
#  {'768': ['The Witch']},
#  {'769': []},
#  {'770': ['Gal Gadot', 'Wonder Woman']},
#  {'776': ['Anthony Hopkins']},
#  {'777': []},
#  {'778': []},
#  {'779': []},
#  {'780': ['Bruce Willis']},
#  {'781': []},
#  {'782': []},
#  {'783': ['Will Ferrell']},
#  {'784': []},
#  {'785': []},
#  {'786': ['Ryan Gosling', 'Wesley Snipes', 'Sean Connery']},
#  {'787': []},
#  {'788': ['Bill Murray']},
#  {'790': []},
#  {'791': []},
#  {'793': []},
#  {'794': ['Will Ferrell', 'Jim Carrey']},
#  {'795': []},
#  {'796': []},
#  {'797': []},
#  {'798': []},
#  {'799': ['Daisy Ridley', 'Johnny Depp']},
#  {'803': ['The House', 'Tyler Perry']},
#  {'804': ['John Boyega']},
#  {'806': []},
#  {'807': []},
#  {'808': []},
#  {'809': []},
#  {'810': []},
#  {'811': []},
#  {'816': []},
#  {'832': []},
#  {'833': ['David Bowie']},
#  {'854': []},
#  {'855': []},
#  {'856': ['Pauly Shore']},
#  {'857': ['Leslie Mann']},
#  {'858': []},
#  {'860': []},
#  {'861': []},
#  {'862': []},
#  {'865': ['Kevin Hart']},
#  {'869': ['Ryan Reynolds']},
#  {'870': []},
#  {'871': ['The Dude', 'Robin Williams', 'Fisher King', 'Jeff Bridges']},
#  {'872': []},
#  {'874': []},
#  {'875': []},
#  {'879': []},
#  {'881': ['Ryan Reynolds']},
#  {'882': ['Paul Walker', 'Jimmy Stewart']},
#  {'883': []},
#  {'886': ['Bruce Willis', 'Robin Williams']},
#  {'888': []},
#  {'889': []},
#  {'890': []},
#  {'891': []},
#  {'892': []},
#  {'893': []},
#  {'894': ['Michael Fassbender']},
#  {'895': ['Meryl Streep', 'Bill Murray']},
#  {'896': ['Elephant Man', 'Jimmy Stewart']},
#  {'897': []},
#  {'898': ['Kevin Hart', 'Will Ferrel']},
#  {'902': []},
#  {'921': []},
#  {'925': []},
#  {'927': ['The New']},
#  {'928': ['Mark Walberg', 'Amy Adams', 'Ice Cube']},
#  {'929': []},
#  {'930': ['Drew Barrymore',
#    'Adam Sandler',
#    'Nicole Kidman',
#    'Ice Cube',
#    'Charlie Day']},
#  {'931': ['Jonah Hill', 'James Franco']},
#  {'932': ['Ryan Gosling', 'Rachael Adams']},
#  {'938': ['Tom Hanks']},
#  {'941': ['Mia Farrow', 'Reese Witherspoon']},
#  {'942': []},
#  {'943': []},
#  {'944': ['Ashley Judd', 'Reese Witherspoon', 'Johnny Cash']},
#  {'945': []},
#  {'946': ['Angelina Jolie']},
#  {'947': ['Adam Sandler',
#    'Mila Kunis',
#    'Hilary Swank',
#    'Charlize Theron',
#    'Jason Segal']},
#  {'950': ['Seth Rogen', 'Jonah Hill']},
#  {'954': ['Paul Rudd']},
#  {'956': ['Lizzy Caplan']},
#  {'957': ['Seth Rogen', 'Jonah Hill', 'James Franco']},
#  {'959': ['Jim Caviezel', 'Ashley Judd', 'Hugh Jackman', 'Morgan Freeman']},
#  {'962': ['Juliette Lewis', 'Morgan Freeman']},
#  {'963': ['Johnny Cash',
#    'Reese Witherspoon',
#    'Matt Dillon',
#    'Joaquin Phoenix',
#    'Chris Pratt',
#    'Topher Grace',
#    'June Carter']},
#  {'966': ['Sandra Bullock',
#    'Josh Hartnett',
#    'Tom Hanks',
#    'Meg Ryan',
#    'Debra Messing']},
#  {'974': ['John Cusack', 'Tom Hanks']},
#  {'975': ['Matt Damon', 'Robin Williams', 'Edward Norton']},
#  {'977': ['Bryan Cranston', 'James Franco', 'Ryan Reynolds']},
#  {'980': []},
#  {'981': []},
#  {'982': ['Jessica Alba', 'Dane Cook', 'Adam Sandler']},
#  {'985': []},
#  {'986': ['Jennifer Lawrence', 'Adam Sandler']},
#  {'987': ['Star Wars', 'Tina Fey']},
#  {'988': ['Drew Barrymore', 'Meg Ryan', 'Adam Sandler', 'Tom Hanks']},
#  {'989': ['Star Wars', 'Ryan Reynolds']},
#  {'994': ['Morris Chestnut', 'Eddie Murphy', 'Richard Gere']},
#  {'995': []},
#  {'997': ['Morris Chestnut', 'Kate Winslet', 'Idris Elba']},
#  {'998': ['Dan Brown', 'Robert Langdon', 'Tom Hanks']},
#  {'999': ['Don Cheadle',
#    'Morris Chestnut',
#    'Omar Epps',
#    'Taye Diggs',
#    'Shemar Moore']},
#  {'1000': ['Clive Owen']},
#  {'1001': ['Kate Winslet', 'Daisy Ridley', 'Johnny Depp', 'Idris Elba']},
#  {'1002': ['Dennis Quaid', 'Ryan Reynolds', 'Ben Foster', 'Chris Pratt']},
#  {'1003': ['Tom Cruise', 'Demi Moor']},
#  {'1014': ['Helen Hunt', 'Diane Keaton', 'Greg Kinnear']},
#  {'1015': ['Bela Lugosi']},
#  {'1018': ['Joan Bennett', 'James Mason', 'Barbara Stanwyck']},
#  {'1021': ['Viola Davis', 'Sandra Bullock', 'Emma Stone']},
#  {'1022': ['Vincent Price', 'Marilyn Monroe', 'Joseph Gordon']},
#  {'1023': ['Will Ferrell',
#    'Reese Witherspoon',
#    'Jason Bateman',
#    'Jennifer Aniston',
#    'Vince Vaughn']},
#  {'1043': []},
#  {'1050': []},
#  {'1053': []},
#  {'1054': []},
#  {'1057': ['John Candy', 'Steve Martin']},
#  {'1059': []},
#  {'1060': ['Tom Hardy']},
#  {'1061': []},
#  {'1062': ['John Travolta']},
#  {'1063': ['Johnny English']},
#  {'1065': ['Eddie Murphy', 'Ben Stiller']},
#  {'1066': []},
#  {'1067': ['Bob Hoskins', 'Chevy Chase']},
#  {'1071': []},
#  {'1073': ['Wyatt Earp', 'Kurt Russell']},
#  {'1074': ['Adam Sandler']},
#  {'1075': ['South Park']},
#  {'1077': []},
#  {'1078': ['Artie Lange']},
#  {'1079': []},
#  {'1083': []},
#  {'1088': []},
#  {'1089': ['Ellen Page']},
#  {'1090': ['Billy Zane']},
#  {'1092': []},
#  {'1093': ['Bryan Cranston', 'Mila Kunis', 'James Franco', 'Zoey Deutch']},
#  {'1094': []},
#  {'1096': []},
#  {'1099': ['Kathy Bates',
#    'Andy Garcia',
#    'Ashley Judd',
#    'Monica Potter',
#    'Morgan Freeman']},
#  {'1100': ['Nicole Kidman',
#    'Hugh Jackman',
#    'Angelina Jolie',
#    'Edward Norton']},
#  {'1101': ['Mad Max', 'Bruce Willis']},
#  {'1102': ['Harrison Ford', 'Mark Hamil']},
#  {'1103': ['Jennifer Aniston', 'James Franco']},
#  {'1105': []},
#  {'1107': []},
#  {'1108': []},
#  {'1109': []},
#  {'1110': ['John Cusack', 'Chelsea Handler', 'Reese Witherspoon']},
#  {'1111': ['Jamie Fox', 'Angelina Jolie']},
#  {'1112': ['Sandra Bullock', 'Robin Williams', 'Tom Hanks']},
#  {'1114': []},
#  {'1115': []},
#  {'1116': []},
#  {'1117': []},
#  {'1118': ['Jack Black', 'Gene Wilder']},
#  {'1119': []},
#  {'1120': ['Tom Hank',
#    'Clint Eastwood',
#    'Reese Witherspoon',
#    'Josh Hartnett',
#    'Tom Hanks',
#    'Joaquin Phoenix',
#    'Hilary Swank',
#    'James Franco',
#    'Scarlett Johansson',
#    'Aron Ralston']},
#  {'1122': []},
#  {'1123': ['Ryan Gosling']},
#  {'1124': ['Nicole Kidman', 'Ashley Judd', 'Kathy Bates', 'Morgan Freeman']},
#  {'1126': ['Emma Roberts', 'Jennifer Lawrence']},
#  {'1127': ['Will Ferrel',
#    'Seth Rogen',
#    'Sandra Bullock',
#    'Joseph Gordon',
#    'Cameron Diaz',
#    'Lizzy Caplan',
#    'Jude Law']},
#  {'1137': ['Chris Columbus']},
#  {'1140': ['Ashley Judd', 'Jennifer Lawrence', 'Chris Pratt']},
#  {'1146': []},
#  {'1148': []},
#  {'1149': ['Harley Quinn']},
#  {'1158': ['Emma Roberts', 'Ellen Page', 'Lily Collins']},
#  {'1159': ['Will Ferrell', 'Zac Efron']},
#  {'1160': []},
#  {'1161': ['Adam Sandler',
#    'Sandra Bullock',
#    'Will Smith',
#    'Nicole Kidman',
#    'Heath Ledger']},
#  {'1179': ['Mel Gibson']},
#  {'1181': ['Joaquin Phoenix', 'Bill Murray']},
#  {'1186': []},
#  {'1191': ['Jim Carey']},
#  {'1197': []},
#  {'1200': ['Will Ferrel']},
#  {'1201': ['Tim Curry']},
#  {'1202': []},
#  {'1203': ['Tim Allen']},
#  {'1204': []},
#  {'1205': ['Mike Myers']},
#  {'1207': []},
#  {'1209': ['Che Guevara']},
#  {'1210': ['Tom Cruise', 'Michael Moore']},
#  {'1212': []},
#  {'1214': []},
#  {'1215': ['Gene Wilder']},
#  {'1216': ['John Travolta']},
#  {'1238': []},
#  {'1240': []},
#  {'1241': []},
#  {'1242': []},
#  {'1243': ['Zach Braff', 'Tom Hanks']},
#  {'1269': []},
#  {'1271': ['Bryan Cranston', 'James Franco', 'Ellen Page']},
#  {'1273': ['Ryan Gosling',
#    'Bruce Willis',
#    'Amy Adams',
#    'Joseph Gordon Levitt']},
#  {'1274': ['Antony Hopkins', 'Brad Pitt', 'Ashley Judd', 'Morgan Freeman']},
#  {'1275': []},
#  {'1276': ['Adam Sandler',
#    'Jim Carey',
#    'Paul Rudd',
#    'Zooey Deschanel',
#    'Jason Seigel',
#    'Rashida Jones']},
#  {'1278': []},
#  {'1279': ['Kevin Costner']},
#  {'1280': ['Kevin Spacey', 'Natalie Portman', 'Demi Moore']},
#  {'1281': ['Ben Carson']},
#  {'1282': ['Green Mile', 'Tom Hanks']},
#  {'1283': []},
#  {'1284': ['Taylor Schilling', 'Jennifer Lawrence']},
#  {'1286': ['Jennifer Lawrence']},
#  {'1288': []},
#  {'1289': ['Kevin Spacey', 'Morgan Freeman']},
#  {'1290': []},
#  {'1293': ['Viola Davis', 'Octavia Spencer', 'Denzel Washington']},
#  {'1294': ['Emma Roberts', 'Ashton Kutcher', 'James Franco', 'Zoey Deutch']},
#  {'1298': []},
#  {'1301': []},
#  {'1302': ['Mike Myers', 'Jim Carrey', 'Ben Stiller']},
#  {'1303': ['Mad Max', 'Mel Gibson', 'Russel Crow', 'Tom Hardy']},
#  {'1306': []},
#  {'1307': []},
#  {'1308': []},
#  {'1309': ['Bye Bye']},
#  {'1310': ['The Franco']},
#  {'1313': []},
#  {'1314': []},
#  {'1316': ['Kathy Bates']},
#  {'1317': []},
#  {'1318': ['Emily Blunt']},
#  {'1319': ['Ryan Gosling', 'John Travolta', 'Emma Stone']},
#  {'1322': ['Brad Pitt',
#    'Kevin Spacey',
#    'Ashley Judd',
#    'Morgan Freeman',
#    'Demi Moore']},
#  {'1323': ['Julia Roberts', 'Richard Gere']},
#  {'1324': []},
#  {'1325': ['Jessica Alba', 'Casey Affleck']},
#  {'1327': ['Will Smith', 'Emma Stone']},
#  {'1328': []},
#  {'1329': ['Martin Lawrence', 'Robin Williams']},
#  {'1333': []},
#  {'1334': ['Katherine Heigl']},
#  {'1337': []},
#  {'1338': []},
#  {'1339': []},
#  {'1340': []},
#  {'1342': []},
#  {'1343': ['Jack Nicholson']},
#  {'1344': ['The Judge']},
#  {'1346': ['Ryan Reynolds']},
#  {'1347': []},
#  {'1350': []},
#  {'1357': ['Greta Gerwig', 'Adam Sandler']},
#  {'1363': ['David Gale',
#    'The Life',
#    'Brad Pitt',
#    'Kevin Spacey',
#    'Ashley Judd',
#    'Demi Moore']},
#  {'1367': ['Michael Cera']},
#  {'1375': ['Mel Gibson', 'Edward Norton']},
#  {'1377': ['Bryan Cranston',
#    'Drew Barrymore',
#    'Adam Sandler',
#    'James Franco',
#    'Kate Mckinnon',
#    'Zoey Deutch']},
#  {'1382': ['Drew Barrymore', 'Hi Im', 'Ryan Reynolds', 'Jennifer Aniston']},
#  {'1402': ['Brad Pitt', 'Morgan Freeman']},
#  {'1403': []},
#  {'1411': []},
#  {'1421': []},
#  {'1423': ['David Lynch']},
#  {'1424': []},
#  {'1427': ['Adam Sandler']},
#  {'1428': []},
#  {'1429': []},
#  {'1431': ['Mad Max']},
#  {'1445': ['Russell Crowe',
#    'Denzel Washington',
#    'John Travolta',
#    'John Woo',
#    'Anna Kendrick',
#    'Russel Crow']},
#  {'1447': ['Brad Pitt']},
#  {'1448': ['Mel Brooks', 'Ryan Reynolds']},
#  {'1451': ['Michael Douglass', 'Johnny Depp', 'Michael Douglas']},
#  {'1460': []},
#  {'1461': ['Denzel Washington']},
#  {'1467': ['Bruce Willis', 'Ryan Reynolds']},
#  {'1468': []},
#  {'1472': ['Adam Sandler']},
#  {'1484': ['Michael Cera',
#    'Drew Barrymore',
#    'Adam Sandler',
#    'Sandra Bullock',
#    'Jennifer Aniston']},
#  {'1486': ['No But']},
#  {'1490': []},
#  {'1492': []},
#  {'1494': ['Rock Hudson', 'Morgan Freeman']},
#  {'1495': ['Denzel Washington', 'Brad Pitt', 'Tom Hanks']},
#  {'1497': []},
#  {'1498': ['Channing Tatum', 'Tom Hanks']},
#  {'1501': ['Ben Stiller', 'Adam Sandler']},
#  {'1506': ['Sandra Bullock']},
#  {'1507': ['Hugh Grant']},
#  {'1509': []},
#  {'1510': []},
#  {'1513': []},
#  {'1514': ['Tom Hanks', 'Julia Roberts']},
#  {'1516': ['Richard Gere']},
#  {'1533': ['Ashley Judd', 'Brad Pitt', 'Morgan Freeman']},
#  {'1534': []},
#  {'1535': []},
#  {'1536': ['Brad Pit', 'Jody Foster']},
#  {'1538': ['Sean Connery']},
#  {'1539': ['Meg Ryan']},
#  {'1540': []},
#  {'1544': []},
#  {'1550': ['Joe Pesci']},
#  {'1552': ['Tom Cruise', 'Clint Eastwood', 'Jodi Foster']},
#  {'1553': ['Wall Street']},
#  {'1554': []},
#  {'1556': ['Whitey Bulger']},
#  {'1557': ['Will Smith', 'New Orleans', 'Tom Cruise']},
#  {'1558': ['Michael Douglass', 'Michael Douglas']},
#  {'1562': ['Rebel Wilson']},
#  {'1563': []},
#  {'1572': ['Brad Pitt', 'Anna Kendrick', 'Morgan Freeman', 'Jose Pena']},
#  {'1575': ['Will Ferrel', 'Bill Murray']},
#  {'1579': ['Tim Allen', 'Tom Hanks']},
#  {'1581': ['Robert Mitchum', 'Bing Crosby']},
#  {'1585': ['Diane Keaton']},
#  {'1588': ['Tom Cruise']},
#  {'1589': ['Tom Cruise']},
#  {'1590': []},
#  {'1591': ['Tom Cruise']},
#  {'1602': ['Demi Moore']},
#  {'1609': ['Jim Parsons']},
#  {'1611': ['Michael Fassbender', 'Ashley Judd', 'Brad Pitt', 'Johnny Depp']},
#  {'1612': []},
#  {'1614': ['Hilary Swank', 'Angelina Jolie', 'Nicole Kidman']},
#  {'1615': ['Billy Bob Thornton']},
#  {'1619': ['Sean Connery',
#    'Kate Winslet',
#    'Kevin Spacey',
#    'Hilary Swank',
#    'Ben Affleck']},
#  {'1621': ['Teresa Palmer', 'Ray Romano', 'Holly Hunter']},
#  {'1623': []},
#  {'1625': ['Denzel Washington',
#    'Idris Elba',
#    'John Travolta',
#    'Mark Walberg']},
#  {'1628': []},
#  {'1629': []},
#  {'1630': []},
#  {'1631': []},
#  {'1636': ['Ellen Page']},
#  {'1649': []},
#  {'1650': ['Ashley Judd', 'Anthony Hopkins', 'Morgan Freeman']},
#  {'1654': ['Barbara Stanwyck']},
#  {'1655': ['Stefania Owen']},
#  {'1657': []},
#  {'1659': []},
#  {'1667': []},
#  {'1670': ['Adam Sandler']},
#  {'1672': ['Jennifer Aniston']},
#  {'1674': ['Drew Barrymore',
#    'Adam Sandler',
#    'Sandra Bullock',
#    'Kate Hudson',
#    'Jennifer Aniston']},
#  {'1676': ['Adam Sandler']},
#  {'1693': []},
#  {'1698': []},
#  {'1707': ['Will Ferrell']},
#  {'1711': []},
#  {'1713': []},
#  {'1715': []},
#  {'1717': []},
#  {'1719': []},
#  {'1723': []},
#  {'1724': ['Don Cheadle', 'Adam Sandler']},
#  {'1726': []},
#  {'1727': []},
#  {'1732': ['Paul Rudd', 'Jennifer Aniston']},
#  {'1735': ['Brad Pitt']},
#  {'1736': ['Drew Barrymore',
#    'Adam Sandler',
#    'Christina Applegate',
#    'Justin Long',
#    'Sandra Bullock',
#    'Ryan Reynolds',
#    'No Is']},
#  {'1740': []},
#  {'1744': ['Kathy Bates', 'Angelina Jolie']},
#  {'1746': []},
#  {'1748': ['Hugh Jackman', 'Colin Firth']},
#  {'1750': ['Anna Kendrick',
#    'Ashley Judd',
#    'Tom Hanks',
#    'Leonardo Dicaprio',
#    'Morgan Freeman',
#    'Ben Affleck']},
#  {'1751': ['God Bles']},
#  {'1752': ['Denzel Washington']},
#  {'1753': ['Nicole Kidman', 'Angelina Jolie']},
#  {'1754': ['Joe Pesci', 'Jude Law']},
#  {'1755': ['Hugh Jackman']},
#  {'1760': ['Denzel Washington',
#    'Mel Gibson',
#    'Teresa Palmer',
#    'Andrew Garfield']},
#  {'1761': []},
#  {'1762': ['Drew Barrymore', 'Adam Sandler', 'Justin Long']},
#  {'1764': []},
#  {'1782': []},
#  {'1784': []},
#  {'1785': ['Robin Williams']},
#  {'1787': ['Ashley Judd']},
#  {'1788': ['The Call', 'Hugh Jackman', 'Bruce Willis']},
#  {'1789': ['Kevin Spacey', 'Hugh Jackman']},
#  {'1790': ['Tom Hanks', 'Meg Ryan']},
#  {'1791': []},
#  {'1792': []},
#  {'1793': ['Tom Hanks', 'Jude Law']},
#  {'1797': []},
#  {'1798': ['Brad Pitt']},
#  {'1800': ['Jake Gyllenhaal', 'Kevin Costner']},
#  {'1801': ['Brad Pitt', 'Tom Hardy']},
#  {'1803': []},
#  {'1814': ['Will Ferrell']},
#  {'1827': ['Michael Fassbender']},
#  {'1828': ['Sam Jackson', 'Angelina Jolie']},
#  {'1830': ['James Cameron']},
#  {'1832': ['Ryan Gosling',
#    'Richard Gere',
#    'Edward Norton',
#    'Ashley Judd',
#    'Anthony Hopkins',
#    'Morgan Freeman']},
#  {'1843': []},
#  {'1844': []},
#  {'1845': []},
#  {'1847': ['The Korean',
#    'Hugh Jackman',
#    'Josh Hartnett',
#    'Bruce Willis',
#    'Morgan Freeman',
#    'Spike Lee']},
#  {'1849': []},
#  {'1870': ['Val Kilmer', 'Robert Downey Jr']},
#  {'1887': ['Amy Schumer',
#    'Kristen Wiig',
#    'Anna Kendrick',
#    'Goldie Hawn',
#    'Guy Ritchie']},
#  {'1890': ['Gene Wilder']},
#  {'1893': ['Woody Harrelson', 'Jonah Hill', 'Emma Stone']},
#  {'1895': ['Russell Crow', 'Tom Hanks']},
#  {'1910': ['Bruce Willis', 'Santa Claus']},
#  {'1915': ['Tim Allen', 'Martin Lawrence']},
#  {'1920': ['Sigourney Weaver', 'Bruce Willis']},
#  {'1922': []},
#  {'1923': []},
#  {'1929': []},
#  {'1937': ['Christopher Nolan']},
#  {'1938': ['Anthony Hopkins']},
#  {'1939': ['Jodie Foster']},
#  {'1940': ['The Rock', 'Brad Pitt', 'Zoe Kravitz']},
#  {'1941': ['Anthony Hopkins']},
#  {'1942': ['Star Wars']},
#  {'1944': ['Anthony Hopkins']},
#  {'1948': ['Jackie Chan']},
#  {'1955': []},
#  {'1958': []},
#  {'1960': ['Stephen King']},
#  {'1961': ['Jeremy Renner']},
#  {'1962': []},
#  {'1964': []},
#  {'1966': []},
#  {'1968': ['Jodie Foster']},
#  {'1970': ['Eddie Murphy']},
#  {'1972': ['Denzel Washington']},
#  {'1973': []},
#  {'1974': []},
#  {'1975': ['Hilary Swank', 'Amy Adams', 'Liam Neeson']},
#  {'1979': ['John Grisham']},
#  {'1986': []},
#  {'1987': []},
#  {'1988': ['Adam Sandler']},
#  {'1989': []},
#  {'1992': ['Star Wars', 'Keanu Reeves', 'Tom Hardy']},
#  {'1994': ['Sean Penn', 'Kevin Bacon']},
#  {'1998': []},
#  {'1999': []},
#  {'2001': ['Bruce Willis', 'Mel Gibson']},
#  {'2003': ['Ashley Judd', 'Brad Pitt', 'Morgan Freeman']},
#  {'2004': ['Tom Hanks']},
#  {'2016': ['Adam Sandler']},
#  {'2020': ['Stanley Tucci', 'Halle Berry']},
#  {'2022': ['Channing Tatum']},
#  {'2023': ['Adam Sandler']},
#  {'2026': []},
#  {'2029': []},
#  {'2031': []},
#  {'2032': []},
#  {'2041': ['Val Kilmer']},
#  {'2042': ['John Cusack', 'Tina Fey']},
#  {'2050': ['Kevin Costner', 'Jake Gyllenhaal']},
#  {'2052': ['Halle Berry', 'Robin Williams']},
#  {'2053': ['Leo Dicaprio', 'Ashley Judd']},
#  {'2054': ['Justin Long', 'Drew Barrymore', 'Sandra Bullock', 'Adam Sandler']},
#  {'2056': ['Drew Barrymore',
#    'Reese Witherspoon',
#    'Colin Firth',
#    'Hugh Grant']},
#  {'2057': ['Denzel Washington',
#    'Sandra Bullock',
#    'Mark Wahlberg',
#    'Hilary Swank']},
#  {'2061': []},
#  {'2063': ['Tim Burton']},
#  {'2065': []},
#  {'2066': ['Michael Moore']},
#  {'2068': []},
#  {'2073': ['Richard Gere', 'Leonardo Dicaprio', 'Ben Affleck']},
#  {'2074': ['Hilary Swank', 'Robin Williams', 'Jake Gyllenhaal']},
#  {'2076': ['The Omen', 'Lorraine Warren']},
#  {'2077': ['Leonardo Dicaprio', 'Morgan Freeman']},
#  {'2082': []},
#  {'2083': ['Ryan Gosling', 'Chris Evans', 'Sandra Bullock']},
#  {'2087': []},
#  {'2089': []},
#  {'2090': ['Drew Barrymore', 'Natalie Portman', 'Adam Sandler', 'Mila Kunis']},
#  {'2092': ['Brad Pitt']},
#  {'2093': ['Leo Dicaprio']},
#  {'2096': []},
#  {'2097': ['Will Smith']},
#  {'2099': []},
#  {'2107': []},
#  {'2108': []},
#  {'2112': []},
#  {'2114': ['Guy Pearce']},
#  {'2116': []},
#  {'2118': ['Will Smith']},
#  {'2119': ['Adam Sandler']},
#  {'2121': []},
#  {'2131': ['Oh Ok']},
#  {'2132': []},
#  {'2133': []},
#  {'2145': ['Star Wars']},
#  {'2146': []},
#  {'2148': []},
#  {'2149': []},
#  {'2150': []},
#  {'2151': ['Clint Eastwood']},
#  {'2152': []},
#  {'2153': ['Joe Pesci']},
#  {'2154': ['Bryan Cranston']},
#  {'2155': []},
#  {'2156': []},
#  {'2161': []},
#  {'2162': []},
#  {'2163': []},
#  {'2164': []},
#  {'2165': ['Meg Ryan']},
#  {'2166': []},
#  {'2169': []},
#  {'2172': []},
#  {'2173': ['Ingrid Bergman']},
#  {'2176': []},
#  {'2177': []},
#  {'2178': []},
#  {'2179': []},
#  {'2180': ['Adam Sandler']},
#  {'2182': []},
#  {'2183': []},
#  {'2185': ['Gene Wilder', 'Tom Hanks', 'Morgan Freeman']},
#  {'2189': []},
#  {'2191': []},
#  {'2194': ['Las Angeles']},
#  {'2198': []},
#  {'2199': []},
#  {'2200': []},
#  {'2201': []},
#  {'2203': []},
#  {'2205': []},
#  {'2208': ['Bad Boys']},
#  {'2209': []},
#  {'2210': []},
#  {'2211': []},
#  {'2212': []},
#  {'2213': []},
#  {'2214': []},
#  {'2215': ['Sean Connery']},
#  {'2216': []},
#  {'2217': []},
#  {'2219': []},
#  {'2221': ['Robin Williams']},
#  {'2222': []},
#  {'2224': ['Reese Witherspoon']},
#  {'2226': []},
#  {'2227': []},
#  {'2228': []},
#  {'2230': []},
#  {'2232': []},
#  {'2234': []},
#  {'2235': []},
#  {'2237': []},
#  {'2238': []},
#  {'2239': []},
#  {'2242': []},
#  {'2243': ['Seth Rogen']},
#  {'2244': []},
#  {'2245': []},
#  {'2246': []},
#  {'2248': ['Dwayne Johnson']},
#  {'2249': []},
#  {'2252': ['Seth Macfarlane']},
#  {'2253': ['Alfred Hitchcock']},
#  {'2255': []},
#  {'2256': []},
#  {'2257': []},
#  {'2258': ['Jack Nicholson']},
#  {'2259': []},
#  {'2261': []},
#  {'2262': []},
#  {'2265': []},
#  {'2267': []},
#  {'2268': []},
#  {'2269': ['Love Williams', 'Robin Williams']},
#  {'2270': []},
#  {'2271': []},
#  {'2272': []},
#  {'2273': ['Drew Barrymore']},
#  {'2274': []},
#  {'2275': ['Will Smith', 'Tom Cruise']},
#  {'2277': []},
#  {'2279': []},
#  {'2280': []},
#  {'2281': []},
#  {'2284': ['Kurt Russell']},
#  {'2285': []},
#  {'2286': []},
#  {'2287': ['Johnny Depp']},
#  {'2289': []},
#  {'2290': []},
#  {'2291': ['Bad Boys']},
#  {'2293': []},
#  {'2294': []},
#  {'2295': []},
#  {'2297': []},
#  {'2298': []},
#  {'2299': []},
#  {'2301': []},
#  {'2303': []},
#  {'2305': []},
#  {'2306': []},
#  {'2307': []},
#  {'2308': []},
#  {'2313': []},
#  {'2316': []},
#  {'2317': []},
#  {'2318': []},
#  {'2319': ['Owen Wilson']},
#  {'2321': []},
#  {'2322': []},
#  {'2323': []},
#  {'2324': []},
#  {'2325': ['Jack Black']},
#  {'2326': ['Marlon Brando']},
#  {'2327': ['Will Ferrel']},
#  {'2328': []},
#  {'2329': []},
#  {'2330': []},
#  {'2331': ['Jack Black']},
#  {'2332': []},
#  {'2333': []},
#  {'2335': []},
#  {'2336': []},
#  {'2339': ['Jude Law']},
#  {'2340': ['Ray Romano',
#    'Will Ferrel',
#    'Mark Walberg',
#    'Greta Gerwig',
#    'Zooey Deschanel']},
#  {'2341': []},
#  {'2342': []},
#  {'2344': []},
#  {'2345': []},
#  {'2346': []},
#  {'2347': ['Natalie Portman',
#    'Drew Barrymore',
#    'Adam Sandler',
#    'Ashton Kutcher',
#    'Howie Mandel']},
#  {'2349': []},
#  {'2350': []},
#  {'2351': []},
#  {'2352': []},
#  {'2353': ['Denzel Washington',
#    'Ashley Judd',
#    'Angelina Jolie',
#    'Morgan Freeman',
#    'Ethan Hawke']},
#  {'2357': []},
#  {'2360': ['Drew Barrymore', 'Stanley Tucci']},
#  {'2362': []},
#  {'2364': ['Charlize Theron',
#    'Clint Eastwood',
#    'Hilary Swank',
#    'Nicole Kidman',
#    'Johnny Depp']},
#  {'2365': []},
#  {'2367': []},
#  {'2368': []},
#  {'2369': ['Seth Rogen', 'Zac Efron']},
#  {'2370': ['Tom Cruise']},
#  {'2371': []},
#  {'2373': []},
#  {'2374': []},
#  {'2376': []},
#  {'2377': ['Stephen King']},
#  {'2378': []},
#  {'2380': []},
#  {'2381': []},
#  {'2382': ['Channing Tatum', 'Jonah Hill']},
#  {'2384': []},
#  {'2386': ['Bruce Willis', 'Keanu Reeves']},
#  {'2387': []},
#  {'2388': []},
#  {'2389': ['Channing Tatum', 'Daniel Craig', 'Adam Driver']},
#  {'2390': []},
#  {'2393': ['Tom Cruise']},
#  {'2394': ['Brad Pitt']},
#  {'2395': []},
#  {'2396': ['Star Wars']},
#  {'2398': ['Channing Tatum', 'Jonah Hill', 'Jackie Chan']},
#  {'2399': ['The Dude', 'Jim Carrey']},
#  {'2403': ['Jada Pinkett Smith']},
#  {'2404': []},
#  {'2405': ['Of The Dead']},
#  {'2406': ['Johnny Cash',
#    'Ryan Gosling',
#    'Reese Witherspoon',
#    'Whitney Houston',
#    'Nicole Kidman',
#    'Jude Law',
#    'June Carter']},
#  {'2409': ['The Rock', 'Kevin Hart', 'Jennifer Lawrence', 'Amy Schumer']},
#  {'2411': ['Whoopi Goldberg', 'New York']},
#  {'2412': []},
#  {'2413': []},
#  {'2414': ['Hilary Swank', 'Amy Adams']},
#  {'2416': []},
#  {'2420': ['Ashley Judd', 'Brad Pitt']},
#  {'2421': []},
#  {'2422': ['Harrison Ford']},
#  {'2423': ['Spider Man']},
#  {'2424': []},
#  {'2426': ['Steve Mcqueen']},
#  {'2427': ['Teresa Palmer']},
#  {'2429': []},
#  {'2431': []},
#  {'2432': ['Will Ferrel', 'Kristen Wiig']},
#  {'2433': ['Sandra Bullock', 'Michael Ore', 'Hilary Swank']},
#  {'2434': ['The Rock']},
#  {'2435': ['Wesley Snipes', 'Kevin Hart', 'Eddie Murphy', 'Nick Nolte']},
#  {'2437': []},
#  {'2438': ['Tom Hanks',
#    'Liam Neeson',
#    'Nicole Kidman',
#    'Morgan Freeman',
#    'Jude Law']},
#  {'2439': []},
#  {'2440': ['Tea Leoni']},
#  {'2441': []},
#  {'2444': []},
#  {'2445': ['Robin Williams']},
#  {'2446': ['Johnny Depp']},
#  {'2448': ['Will Ferrell', 'Seth Rogen', 'James Franco']},
#  {'2449': ['Jamie Foxx']},
#  {'2452': ['Idina Menzel']},
#  {'2453': []},
#  {'2454': ['The Shining']},
#  {'2455': []},
#  {'2457': []},
#  {'2459': ['New Years', 'Billy Bob Thornton']},
#  {'2462': ['Brad Pitt', 'Ashley Judd', 'Morgan Freeman']},
#  {'2464': ['James Bond']},
#  {'2465': ['Jason Segal']},
#  {'2466': ['Robin Williams']},
#  {'2467': []},
#  {'2468': []},
#  {'2469': ['Duke Ellington', 'Jimmy Stewart']},
#  {'2470': ['Michael Fassbender',
#    'Christian Bale',
#    'The Snowman',
#    'Johnny Depp',
#    'Daisy Ridley']},
#  {'2471': []},
#  {'2472': []},
#  {'2473': []},
#  {'2474': ['Luc Besson']},
#  {'2475': ['Matt Damon']},
#  {'2476': []},
#  {'2478': []},
#  {'2479': []},
#  {'2482': []},
#  {'2483': []},
#  {'2484': []},
#  {'2485': []},
#  {'2487': []},
#  {'2489': []},
#  {'2490': []},
#  {'2492': ['Matt Damon']},
#  {'2493': []},
#  {'2496': ['Julia Roberts']},
#  {'2498': ['Robin Williams']},
#  {'2499': ['Will Smith']},
#  {'2500': []},
#  {'2501': ['Ok Bye']},
#  {'2502': ['Kristen Wiig', 'Adam Sandler']},
#  {'2503': ['Times Square']},
#  {'2504': ['Liam Neeson', 'Alejandro Inarritu']},
#  {'2505': ['Zoe Kravitz', 'Tom Hardy']},
#  {'2506': []},
#  {'2507': ['Neil Patrick Harris', 'Ben Affleck', 'Julia Roberts']},
#  {'2509': ['Great War']},
#  {'2510': []},
#  {'2511': []},
#  {'2512': []},
#  {'2513': []},
#  {'2515': []},
#  {'2516': []},
#  {'2517': ['James Mcavoy', 'Emily Blunt', 'Morgan Freeman']},
#  {'2518': ['Johnny Depp']},
#  {'2520': ['Adam Sandler']},
#  {'2621': []},
#  {'2622': []},
#  {'2623': []},
#  {'2624': ['Joseph Gordon Levitt']},
#  {'2625': ['Daniel Day Lewis']},
#  {'2630': []},
#  {'2631': ['Steven King']},
#  {'2632': ['Vin Diesel']},
#  {'2633': []},
#  {'2635': []},
#  {'2636': ['Matt Damon']},
#  {'2637': ['Woody Allen']},
#  {'2640': ['Jean Claude Van Damme']},
#  {'2643': ['Emily Blunt', 'Renee Zellweger']},
#  {'2646': []},
#  {'2647': ['David Hasselhoff', 'Vince Vaughn']},
#  {'2648': []},
#  {'2649': []},
#  {'2650': ['Will Ferrell']},
#  {'2652': ['Johnny Depp']},
#  {'2653': []},
#  {'2655': ['Wonder Woman']},
#  {'2656': []},
#  {'2658': []},
#  {'2659': []},
#  {'2660': []},
#  {'2662': ['Will Ferrell', 'Adam Sandler']},
#  {'2666': ['Jennifer Lawrence']},
#  {'2667': []},
#  {'2670': []},
#  {'2672': []},
#  {'2673': []},
#  {'2674': []},
#  {'2675': []},
#  {'2676': ['Stephen King']},
#  {'2681': []},
#  {'2682': ['Robin Williams']},
#  {'2683': []},
#  {'2684': []},
#  {'2685': []},
#  {'2687': []},
#  {'2689': ['John Wick']},
#  {'2690': ['Marisa Tomei']},
#  {'2692': []},
#  {'2693': []},
#  {'2696': ['Robin Williams']},
#  {'2697': []},
#  {'2699': ['Blade Runner']},
#  {'2701': []},
#  {'2702': []},
#  {'2703': []},
#  {'2704': []},
#  {'2705': []},
#  {'2706': []},
#  {'2708': []},
#  {'2710': ['The Thing']},
#  {'2711': []},
#  {'2712': []},
#  {'2713': []},
#  {'2714': []},
#  {'2716': []},
#  {'2717': ['Tom Hanks']},
#  {'2718': []},
#  {'2719': []},
#  {'2720': []},
#  {'2722': []},
#  {'2724': []},
#  {'2726': []},
#  {'2733': []},
#  {'2736': ['Adam Sandler']},
#  {'2737': ['St Bernard', 'Nancy Allen', 'Stephen King']},
#  {'2738': []},
#  {'2739': ['The Thing', 'The Ring', 'The Shining']},
#  {'2743': []},
#  {'2746': []},
#  {'2747': []},
#  {'2748': []},
#  {'2749': []},
#  {'2750': []},
#  {'2751': []},
#  {'2753': []},
#  {'2755': []},
#  {'2756': []},
#  {'2764': ['Kevin Smith', 'Owen Wilson', 'Joss Whedon']},
#  {'2765': []},
#  {'2766': []},
#  {'2767': []},
#  {'2769': []},
#  {'2770': []},
#  {'2771': []},
#  {'2772': ['Sally Field', 'Robert Redford', 'John Wayne']},
#  {'2773': []},
#  {'2776': []},
#  {'2777': ['Stephen King']},
#  {'2778': []},
#  {'2779': []},
#  {'2780': []},
#  {'2781': ['Will Ferrell']},
#  {'2782': []},
#  {'2783': []},
#  {'2784': []},
#  {'2785': []},
#  {'2786': ['Jackie Chan']},
#  {'2787': []},
#  {'2788': []},
#  {'2790': []},
#  {'2791': []},
#  {'2792': []},
#  {'2793': []},
#  {'2795': []},
#  {'2796': []},
#  {'2797': []},
#  {'2798': []},
#  {'2799': []},
#  {'2800': []},
#  {'2802': []},
#  {'2804': []},
#  {'2805': ['Leo Dicaprio', 'Mandy Moore']},
#  {'2806': []},
#  {'2807': []},
#  {'2808': ['Captain America']},
#  ...]

# %%
filtered_data = [item for item in relations_people_data if any(item.values())]

print(filtered_data)
# Out:
# [{'391': ['Alec Baldwin']}, {'405': ['Drew Barrymore']}, {'415': ['New Orleans']}, {'418': ['Quentin Tarantino', 'Stephen King']}, {'419': ['Will Smith', 'Tom Cruise', 'Jeff Bridges']}, {'426': ['Kevin Hart']}, {'458': ['Kevin Hart', 'Will Ferrel', 'Ice Cube', 'Mark Wahlberg']}, {'459': ['Martin Lawrence', 'Kevin Hart', 'Adam Sandler', 'Damon Wayans']}, {'462': ['Jack Black', 'Jim Carey']}, {'463': ['Bill Murphy', 'Leslie Nielsen']}, {'464': ['Tom Hardy', 'Reese Witherspoon', 'Tom Cruise', 'Chris Pine']}, {'465': ['Bruce Willis', 'Samuel Jackson']}, {'466': ['Mark Rylance']}, {'468': ['Kevin Hart']}, {'470': ['Jim Carrey']}, {'471': ['Taylor Kitsch', 'Salma Hayek', 'Blake Lively']}, {'475': ['Reese Witherspoon']}, {'477': ['Michelle Rodriguez']}, {'481': ['Alfred Hitchcock']}, {'482': ['Queen Latifah', 'John Travolta']}, {'484': ['Eddie Murphy']}, {'485': ['Catherine Zeta Jones', 'Queen Latifa']}, {'502': ['Kevin Hart', 'Kurt Russel', 'Will Farrell', 'Morgan Freeman']}, {'503': ['Billy Bob', 'Bad Santa', 'Billy Bob Thornton']}, {'507': ['Amy Adams']}, {'512': ['Anne Hathaway', 'Sci Fi']}, {'514': ['Will Ferrell', 'Tracey Morgan', 'Bruce Willis']}, {'519': ['Kevin Hart', 'Will Farrell']}, {'540': ['Anthony Hopkins', 'Eddie Norton']}, {'544': ['Black Panther']}, {'554': ['Bryan Cranston', 'James Franco', 'Adam Sandler']}, {'556': ['Diane Lane', 'Rob Zombie', 'Richard Gere']}, {'557': ['Star Wars']}, {'560': ['Adam Sandler']}, {'561': ['Bing Crosby']}, {'567': ['Michael Douglas']}, {'569': ['Big Fish', 'Jeff Bridges']}, {'571': ['Jack Black']}, {'573': ['Stephen King']}, {'579': ['Hugh Grant']}, {'582': ['Anne Hathaway', 'Adam Sandler', 'Jeff Bridges', 'Owen Wilson']}, {'584': ['James Cameron']}, {'585': ['Steve Zahn', 'Paul Walker']}, {'586': ['Ed Harris', 'Abbie Cornish', 'The Rock']}, {'588': ['Kevin Spacey']}, {'593': ['Jason Statham']}, {'600': ['Keanu Reeves']}, {'603': ['Arnold Schwarzenegger', 'Sylvester Stallone']}, {'606': ['Brad Pitt', 'Harrison Ford']}, {'609': ['Anthony Hopkins', 'Sir Ben Kingsley']}, {'611': ['Natalie Portman', 'Naomi Watts', 'Ben Kingsley', 'Susan Sarandon']}, {'613': ['Kevin Hart', 'Will Farrell']}, {'614': ['Sci Fi']}, {'615': ['The Sheriff']}, {'616': ['John Carpenter', 'Rob Zombie', 'Anthony Hopkins']}, {'619': ['Sci Fi', 'De Niro']}, {'625': ['Paul Rodriguez']}, {'628': ['Sci Fi']}, {'632': ['Tony Jaa']}, {'654': ['Amy Adams']}, {'661': ['Clint Eastwood']}, {'669': ['Wes Anderson']}, {'710': ['Kevin Smith']}, {'738': ['Gerard Butler']}, {'762': ['Stephen King']}, {'763': ['Wesley Snipes', 'Sean Connery']}, {'767': ['The Mummy']}, {'768': ['The Witch']}, {'770': ['Gal Gadot', 'Wonder Woman']}, {'776': ['Anthony Hopkins']}, {'780': ['Bruce Willis']}, {'783': ['Will Ferrell']}, {'786': ['Ryan Gosling', 'Wesley Snipes', 'Sean Connery']}, {'788': ['Bill Murray']}, {'794': ['Will Ferrell', 'Jim Carrey']}, {'799': ['Daisy Ridley', 'Johnny Depp']}, {'803': ['The House', 'Tyler Perry']}, {'804': ['John Boyega']}, {'833': ['David Bowie']}, {'856': ['Pauly Shore']}, {'857': ['Leslie Mann']}, {'865': ['Kevin Hart']}, {'869': ['Ryan Reynolds']}, {'871': ['The Dude', 'Robin Williams', 'Fisher King', 'Jeff Bridges']}, {'881': ['Ryan Reynolds']}, {'882': ['Paul Walker', 'Jimmy Stewart']}, {'886': ['Bruce Willis', 'Robin Williams']}, {'894': ['Michael Fassbender']}, {'895': ['Meryl Streep', 'Bill Murray']}, {'896': ['Elephant Man', 'Jimmy Stewart']}, {'898': ['Kevin Hart', 'Will Ferrel']}, {'927': ['The New']}, {'928': ['Mark Walberg', 'Amy Adams', 'Ice Cube']}, {'930': ['Drew Barrymore', 'Adam Sandler', 'Nicole Kidman', 'Ice Cube', 'Charlie Day']}, {'931': ['Jonah Hill', 'James Franco']}, {'932': ['Ryan Gosling', 'Rachael Adams']}, {'938': ['Tom Hanks']}, {'941': ['Mia Farrow', 'Reese Witherspoon']}, {'944': ['Ashley Judd', 'Reese Witherspoon', 'Johnny Cash']}, {'946': ['Angelina Jolie']}, {'947': ['Adam Sandler', 'Mila Kunis', 'Hilary Swank', 'Charlize Theron', 'Jason Segal']}, {'950': ['Seth Rogen', 'Jonah  ...

# %%
unique_names = set()

for entry in filtered_data:
    for key, value in entry.items():
        unique_names.update(value)

print(unique_names)
# Out:
# {'Julianne Hough', 'Daniel Day Lewis', 'Alan Turing', 'Barbra Streisand', 'Alice Springs', 'John Dillinger', 'The Snowman', 'Tom Hank', 'Woody Allen', 'Jim Cameron', 'Diane Lane', 'Ron Livingston', 'Nicole Kidman', 'Zoe Saldana', 'Taylor Schilling', 'Taylor Kitsch', 'James Cameron', 'Tim Robbins', 'Laura Linney', 'Andy Samberg', 'Minnie Driver', 'Goldie Hawn', 'Molly Ringwald', 'Alexander Skarsgard', 'Billy Wilder', 'Emile Hirsch', 'June Carter', 'Rebel Wilson', 'Cameron Crowe', 'Charlie Kelly', 'Judd Apatow', 'Nic Cage', 'Mark Wahlberg', 'Scarlett Johansson', 'Tom Arnold', 'Milla Jovovich', 'Jack Nicholsen', 'Denzel Washington', 'Max Steel', 'Sean Bean', 'Robert Mitchum', 'Paula Patton', 'Patrick Stewart', 'Rachael Adams', 'How Can', 'The Spy', 'The Martian', 'Tommy Lee Jones', 'Timothy Dalton', 'The Office', 'Martin Lawrence', 'Rosanne Barr', 'King George', 'Monty Python', 'Jake Gyllenhaal', 'Vince Vaughn', 'Jude Law', 'Gary Farmer', 'Billy Howle', 'Chris Rock', 'Matt Smith', 'Steve Carroll', 'Sean Penn', 'Kevin Hart', 'Christina Hendricks', 'Jamie Fox', 'Old School', 'Spider Man', 'Ed Sheeran', 'Nick Swardson', 'The Omen', 'Andy Garcia', 'Donald Glover', 'Kevin Spacey', 'Sandra Bullock', 'Harry Connick Jr', 'Shane West', 'Lee Pace', 'Winston Churchill', 'Hey Hey', 'Van Dam', 'Robert Jauregui', 'Russell Crow', 'Al Capone', 'Nancy Myers', 'Bette Davis', 'Nick Sparks', 'Alec Baldwin', 'De Niro', 'Forest Whitaker', 'Amy Poehler', 'John Carpenter', 'Kim Novak', 'Debra Messing', 'John Candy', 'Patch Adams', 'Elizabeth Olsen', 'Great Ball', 'Lucas Black', 'The Others', 'Desmond Doss', 'Amanda Silver', 'Regina Hall', 'William Wyler', 'John Cusak', 'Justin Bartha', 'Ally Sheedy', 'Ray Romano', 'Morten Tyldum', 'Green Day', 'Rachel Mcadams', 'Jeremy Renner', 'Zodiac Killer', 'The Roman', 'Wes Anderson', 'Richard Dawson', 'Arnold Schwarzenegger', 'Kelly Lebrock', 'Monica Potter', 'Big Edie', 'Billy Murray', 'Cate Blanchett', 'Stanley Kubrick', 'Mike Myers', 'Queen Victoria', 'Armie Hammer', 'Miles Teller', 'Linda Hamilton', 'Lisa Kudrow', 'Natalie Portman', 'Helen Mirren', 'Michelle Monaghan', 'Freddy Krueger', 'Paul Conroy', 'Kurt Russell', 'Danny Masterson', 'Park Il', 'Danny Boyle', 'Martin Scorsese', 'Ray Liotta', 'Joseph Gordon', 'John Grisham', 'Indian Ocean', 'Sarah Connor', 'Brooke Shield', 'Aaron Swartz', 'Julie Andrews', 'Barkhad Abdi', 'Sally Hawkins', 'Di Caprio', 'Ken Foree', 'Ang Lee', 'Shemar Moore', 'Anna Hathaway', 'Tom Hardy', 'The Hangover', 'Sci Fi', 'The Incredible', 'Chelsea Handler', 'Guy Ritchie', 'Stanley Weber', 'Animated Movie', 'Kathleen Turner', 'Dan Brown', 'Dorothy Vaughan', 'James Mangold', 'Louisa May Alcott', 'Tom Hiddleston', 'Bin Won', 'Dan Roman', 'Grace Kelly', 'Brad Renfro', 'Love You', 'Paris Hilton', 'David Chase', 'Dick Van Dyke', 'Sigourney Weaver', 'Jim Sturgess', 'Asa Butterfield', 'Jon Heder', 'The Clash', 'Zak Bagans', 'Alan Arkin', 'Kristen Wiig', 'Tony Jaa', 'Jackie Robinson', 'Josh Brolin', 'Hei Hei', 'American Beauty', 'Alfred Hitchcock', 'Zach Braff', 'Keanu Reeves', 'Rooney Mara', 'Perry Caravello', 'Die Antwoord', 'Oh Yes', 'Stanley Tucci', 'Rian Johnson', 'Danny Devito', 'Clint Eastwood', 'Jada Pinkett', 'Josh Gad', 'Matthew Broderick', 'Do You', 'Nathan Lane', 'Bradley Cooper', 'John Woo', 'Jackie Kennedy', 'Bye Bye', 'Leonardo Di Caprio', 'Jose Pena', 'Justin Timberlake', 'Emmanuelle Beart', 'Paz Vega', 'Demi Lovato', 'John Robinson', 'Adam Scott', 'Neil Gaiman', 'Richard Madden', 'Ben Still', 'Harvey Weinstein', 'New Orleans', 'Colin Farrell', 'Matt Damon', 'Clive Owen', 'Reese Witherspoon', 'Kiefer Sutherland', 'Les Miserables', 'The Mummy', 'Sam Mullins', 'Noah Wyle', 'James Mason', 'Robert Pattinson', 'Marc Haimes', 'Billy Zane', 'Rosamund Pike', 'The End', 'Van Helsing', 'The Dead', 'The Kids', 'Aron Ralston', 'Ethel Merman', 'New Jersey', 'Brad Ingelsby', 'Ben Affleck', 'Ellen Page', 'Shea Jackson', 'John Glenn', 'Antonio Banderas', 'Chris Farley', 'Leonardo Dicaprio', 'Th ...

# %%
final_names = sorted(unique_names)
print(final_names)
# Out:
# ['Aaron Swartz', 'Abbie Cornish', 'Abby Ryder Fortson', 'Abigail Breslin', 'Ace Ventura', 'Adam Driver', 'Adam Pascal', 'Adam Sander', 'Adam Sandler', 'Adam Scott', 'Adeel Akhtar', 'Adrian Scarborough', 'Adrien Brody', 'Agatha Christie', 'Al Capone', 'Al Pacino', 'Alan Alda', 'Alan Arkin', 'Alan Rickman', 'Alan Turing', 'Albert Brooks', 'Alec Baldwin', 'Alejandro Inarritu', 'Alex Kurtzman', 'Alex Roe', 'Alexander Skarsgard', 'Alexie Gilmore', 'Alfie Allen', 'Alfred Hitchcock', 'Alice Springs', 'Alicia Eve', 'All Super', 'Ally Sheedy', 'Amanda Bynes', 'Amanda Seyfried', 'Amanda Silver', 'American Beauty', 'Amy Adams', 'Amy Poehler', 'Amy Schumer', 'Andre Benjamin', 'Andrei Tarkovsky', 'Andrew Garfield', 'Andrew James Allen', 'Andrew Lincoln', 'Andy Garcia', 'Andy Kaufman', 'Andy Samberg', 'Ane Dahl Torp', 'Ang Lee', 'Angelina Jole', 'Angelina Jolie', 'Animated Movie', 'Anna Hathaway', 'Anna Kendrick', 'Anne Hathaway', 'Ansel Elgort', 'Anthony Hopkins', 'Anthony Rapp', 'Anton Yelchin', 'Antonio Banderas', 'Antony Hopkins', 'Anupam Kher', 'Armie Hammer', 'Arnold Schwarzenegger', 'Aron Ralston', 'Art Parkinson', 'Artie Lange', 'Asa Butterfield', 'Ashley Judd', 'Ashton Kutcher', 'Aubrey Plaza', 'Audrey Hepburn', 'Babe Ruth', 'Bad Boys', 'Bad Santa', 'Barack Obama', 'Barbara Stanwyck', 'Barbra Streisand', 'Barkhad Abdi', 'Barry Keoghan', 'Bela Lugosi', 'Bella Thorne', 'Ben Affleck', 'Ben Carson', 'Ben Feldman', 'Ben Foster', 'Ben Kingsley', 'Ben Mendelsohn', 'Ben Sherwood', 'Ben Still', 'Ben Stiller', 'Benedict Cumberbatch', 'Bernie Mac', 'Bethany Hamilton', 'Bette Davis', 'Bette Midler', 'Betty White', 'Big Bang', 'Big Daddy', 'Big Edie', 'Big Fish', 'Big Sick', 'Bill Cosby', 'Bill Hader', 'Bill Murphy', 'Bill Murray', 'Bill Murry', 'Billy Bob', 'Billy Bob Thornton', 'Billy Crystal', 'Billy Howle', 'Billy Murray', 'Billy Ray Cyrus', 'Billy Wilder', 'Billy Zane', 'Bin Won', 'Bing Crosby', 'Black Mirror', 'Black Panther', 'Black Sabbath', 'Blade Runner', 'Blake Lively', 'Blood Car', 'Blues Brothers', 'Bob Hoskins', 'Bobby Cannavale', 'Bobby Deniro', 'Bon Jovi', 'Bouvier Beale', 'Box Office', 'Brad Ingelsby', 'Brad Pit', 'Brad Pitt', 'Brad Renfro', 'Bradley Cooper', 'Brandon Lee', 'Brian Cox', 'Brian Cranston', 'Brie Larson', 'Britney Spears', 'Brittany Murphy', 'Broken Lizard', 'Brooke Shield', 'Bruce Lee', 'Bruce Springsteen', 'Bruce Willis', 'Bryan Cranston', 'Burnie Mac', 'Burt Reynolds', 'Bye Bye', 'Cable Guy', 'Caitlin Gerard', 'Cameron Crowe', 'Cameron Diaz', 'Captain America', 'Captain Hook', 'Carl Sagan', 'Carl Weathers', 'Carrie Fisher', 'Cary Elwes', 'Cary Grant', 'Casey Affleck', 'Cate Blanchett', 'Catherine Deneuve', 'Catherine Zeta', 'Catherine Zeta Jones', 'Catinca Untaru', 'Chadwick Boseman', 'Channing Tatum', 'Charles Bronson', 'Charlie Chaplin', 'Charlie Day', 'Charlie Hunnam', 'Charlie Kelly', 'Charlie Sheen', 'Charlize Theron', 'Che Guevara', 'Chelsea Handler', 'Chevy Chase', 'Chiwetel Ejiofor', 'Chris Butler', 'Chris Columbus', 'Chris Evans', 'Chris Farley', 'Chris Hemsworth', 'Chris Kattan', 'Chris Nolan', 'Chris Pine', 'Chris Prat', 'Chris Pratt', 'Chris Reeves', 'Chris Rock', 'Chris Sarandon', 'Chris Tucker', 'Christian Bale', 'Christian Slater', 'Christina Applegate', 'Christina Hendricks', 'Christina Ricci', 'Christopher Guest', 'Christopher Mintz', 'Christopher Nolan', 'Christopher Reeve', 'Christopher Walken', 'Claire Danes', 'Claudette Colbert', 'Cleveland Indians', 'Clint Eastwood', 'Clive Owen', 'Cold War', 'Colin Farrell', 'Colin Firth', 'Connie Willis', 'Connor Corum', 'Corey Feldman', 'Crispin Glover', 'Crispin Hellion Glover', 'Cuba Gooding', 'Cuba Gooding Jr', 'Daisy Ridley', 'Dakota Fanning', 'Damon Wayans', 'Damon Wayans Jr', 'Dan Brown', 'Dan Roman', 'Dane Cook', 'Daniel Craig', 'Daniel Day', 'Daniel Day Lewis', 'Daniel Radcliff', 'Danny Boyle', 'Danny Devito', 'Danny Glover', 'Danny Huston', 'Danny Masterson', 'Daryl Sabara', 'Dave Chappelle', 'David Bowie', 'David Carradine', 'David Chase', 'Da ...

# %%
relations_people_data_tmdb = [] # from tmdb

def read_jsonl(file_path, encoding='utf-8'):
    with open(file_path, 'r', encoding=encoding) as file:
        for line in file:
            relations_people_data_tmdb.append(json.loads(line))
    return relations_people_data_tmdb

read_jsonl("./data/input/cast_directors_writers_final.jsonl")
# Out:
# [{'name': "Charlotte's Web",
#   'year': '2006',
#   'cast': ['Dakota Fanning',
#    'Julia Roberts',
#    'Steve Buscemi',
#    'John Cleese',
#    'Oprah Winfrey'],
#   'director': 'Gary Winick',
#   'writer': 'N/A'},
#  {'name': 'Everything You Always Wanted to Know About Sex*',
#   'year': '1972',
#   'cast': ['Woody Allen',
#    'John Carradine',
#    'Lou Jacobi',
#    'Louise Lasser',
#    'Anthony Quayle'],
#   'director': 'Woody Allen',
#   'writer': 'N/A'},
#  {'name': 'Rock-a-Doodle',
#   'year': '1991',
#   'cast': ['Glen Campbell',
#    'Toby Scott Ganger',
#    'Christopher Plummer',
#    'Kathryn Holcomb',
#    'Stan Ivar'],
#   'director': 'Don Bluth',
#   'writer': 'Don Bluth'},
#  {'name': 'Too Late',
#   'year': 'None',
#   'cast': ['John Hawkes',
#    'Vail Bloom',
#    'Joanna Cassidy',
#    'Jeff Fahey',
#    'Robert Forster'],
#   'director': 'Dennis Hauck',
#   'writer': 'Dennis Hauck'},
#  {'name': 'Law Abiding Citizen',
#   'year': '2009',
#   'cast': ['Jamie Foxx',
#    'Gerard Butler',
#    'Colm Meaney',
#    'Bruce McGill',
#    'Leslie Bibb'],
#   'director': 'F. Gary Gray',
#   'writer': 'Kurt Wimmer'},
#  {'name': 'The Black Mask',
#   'year': '1935',
#   'cast': ['Wylie Watson',
#    'Aileen Marson',
#    'Ellis Irving',
#    'Wyndham Goldie',
#    'Herbert Lomas'],
#   'director': 'Ralph Ince',
#   'writer': 'Frank Launder'},
#  {'name': 'Club Dread',
#   'year': '2004',
#   'cast': ['Kevin Heffernan',
#    'Jay Chandrasekhar',
#    'Brittany Daniel',
#    'Bill Paxton',
#    'Steve Lemme'],
#   'director': 'Jay Chandrasekhar',
#   'writer': 'N/A'},
#  {'name': 'Moana',
#   'year': 'None',
#   'cast': ['Dwayne Johnson'],
#   'director': 'Thomas Kail',
#   'writer': 'Jared Bush'},
#  {'name': 'Signs',
#   'year': '2002',
#   'cast': ['Mel Gibson',
#    'Joaquin Phoenix',
#    'Rory Culkin',
#    'Abigail Breslin',
#    'Cherry Jones'],
#   'director': 'M. Night Shyamalan',
#   'writer': 'M. Night Shyamalan'},
#  {'name': 'Beyond the Valley of the Dolls',
#   'year': '1970',
#   'cast': ['Dolly Read',
#    'Cynthia Myers',
#    'Marcia McBroom',
#    'John Lazar',
#    'Michael Blodgett'],
#   'director': 'Russ Meyer',
#   'writer': 'N/A'},
#  {'name': 'Beastly',
#   'year': '2011',
#   'cast': ['Alex Pettyfer',
#    'Vanessa Hudgens',
#    'Mary-Kate Olsen',
#    'LisaGay Hamilton',
#    'Neil Patrick Harris'],
#   'director': 'Daniel Barnz',
#   'writer': 'N/A'},
#  {'name': 'Victoria',
#   'year': '2015',
#   'cast': ['Laia Costa',
#    'Frederick Lau',
#    'Franz Rogowski',
#    'Burak Yiğit',
#    'Max Mauff'],
#   'director': 'Sebastian Schipper',
#   'writer': 'N/A'},
#  {'name': 'The Duel',
#   'year': '2016',
#   'cast': ['Woody Harrelson',
#    'Liam Hemsworth',
#    'Alice Braga',
#    'Emory Cohen',
#    'Felicity Price'],
#   'director': 'Kieran Darcy-Smith',
#   'writer': 'Matt Cook'},
#  {'name': 'American Ninja 2: The Confrontation',
#   'year': '1987',
#   'cast': ['Michael Dudikoff',
#    'Steve James',
#    'Larry Poindexter',
#    'Gary Conway',
#    'Jeff Celentano'],
#   'director': 'Sam Firstenberg',
#   'writer': 'N/A'},
#  {'name': 'Earth to Echo',
#   'year': '2014',
#   'cast': ['Teo Halm',
#    'Astro',
#    'Reese Hartwig',
#    'Ella Wahlestedt',
#    'Jason Gray-Stanford'],
#   'director': 'Dave Green',
#   'writer': 'N/A'},
#  {'name': 'Amélie',
#   'year': '2001',
#   'cast': ['Audrey Tautou',
#    'Mathieu Kassovitz',
#    'Rufus',
#    'Lorella Cravotta',
#    'Serge Merlin'],
#   'director': 'Jean-Pierre Jeunet',
#   'writer': 'Jean-Pierre Jeunet'},
#  {'name': 'Born Free',
#   'year': '1966',
#   'cast': ['Virginia McKenna',
#    'Bill Travers',
#    'Geoffrey Keen',
#    'Peter Lukoye',
#    'Omar Chambati'],
#   'director': 'James Hill',
#   'writer': 'N/A'},
#  {'name': 'Son in Law',
#   'year': '1993',
#   'cast': ['Pauly Shore',
#    'Carla Gugino',
#    'Lane Smith',
#    'Tiffani Thiessen',
#    'Cindy Pickett'],
#   'director': 'Steve Rash',
#   'writer': 'N/A'},
#  {'name': 'Killer Klowns from Outer Space',
#   'year': '1988',
#   'cast': ['Grant Cramer',
#    'Suzanne Snyder',
#    'John Allen Nelson',
#    'John Vernon',
#    'Royal Dano'],
#   'director': 'Stephen Chiodo',
#   'writer': 'Stephen Chiodo'},
#  {'name': 'Holiday Inn',
#   'year': '1942',
#   'cast': ['Bing Crosby',
#    'Fred Astaire',
#    'Marjorie Reynolds',
#    'Virginia Dale',
#    'Walter Abel'],
#   'director': 'Mark Sandrich',
#   'writer': 'N/A'},
#  {'name': 'Dracula Untold',
#   'year': '2014',
#   'cast': ['Luke Evans',
#    'Dominic Cooper',
#    'Sarah Gadon',
#    'Charles Dance',
#    'Art Parkinson'],
#   'director': 'Gary Shore',
#   'writer': 'Matt Sazama'},
#  {'name': 'Tom and Jerry: The Fast and the Furry',
#   'year': 'None',
#   'cast': ['Charlie Adler',
#    'Jeff Bennett',
#    'John DiMaggio',
#    'Jess Harnell',
#    'Tom Kenny'],
#   'director': 'Bill Kopp',
#   'writer': 'N/A'},
#  {'name': 'Shanghai Knights',
#   'year': '2003',
#   'cast': ['Jackie Chan',
#    'Owen Wilson',
#    'Fann Wong',
#    'Aidan Gillen',
#    'Donnie Yen'],
#   'director': 'David Dobkin',
#   'writer': 'N/A'},
#  {'name': 'Dirty Dancing: Havana Nights',
#   'year': 'None',
#   'cast': ['Diego Luna',
#    'Romola Garai',
#    'Sela Ward',
#    'John Slattery',
#    'Jonathan Jackson'],
#   'director': 'Guy Ferland',
#   'writer': 'N/A'},
#  {'name': 'Ghost in the Shell: Stand Alone Complex - Solid State Society',
#   'year': '2006',
#   'cast': ['Atsuko Tanaka',
#    'Osamu Saka',
#    'Koichi Yamadera',
#    'Akio Otsuka',
#    'Yutaka Nakano'],
#   'director': 'Kenji Kamiyama',
#   'writer': 'Kenji Kamiyama'},
#  {'name': 'Chasing Mavericks',
#   'year': '2012',
#   'cast': ['Gerard Butler',
#    'Jonny Weston',
#    'Elisabeth Shue',
#    'Abigail Spencer',
#    'Leven Rambin'],
#   'director': 'Curtis Hanson',
#   'writer': 'N/A'},
#  {'name': "Sophie's Choice",
#   'year': '1982',
#   'cast': ['Meryl Streep',
#    'Kevin Kline',
#    'Peter MacNicol',
#    'Rita Karin',
#    'Josh Mostel'],
#   'director': 'Alan J. Pakula',
#   'writer': 'N/A'},
#  {'name': 'Secondhand Lions',
#   'year': '2003',
#   'cast': ['Michael Caine',
#    'Robert Duvall',
#    'Haley Joel Osment',
#    'Josh Lucas',
#    'Kyra Sedgwick'],
#   'director': 'Tim McCanlies',
#   'writer': 'Tim McCanlies'},
#  {'name': 'Rio 2',
#   'year': '2014',
#   'cast': ['Jesse Eisenberg',
#    'Anne Hathaway',
#    'Will.i.am',
#    'Jamie Foxx',
#    'Leslie Mann'],
#   'director': 'Carlos Saldanha',
#   'writer': 'N/A'},
#  {'name': 'Places in the Heart',
#   'year': '1984',
#   'cast': ['Sally Field',
#    'Lindsay Crouse',
#    'John Malkovich',
#    'Danny Glover',
#    'Ed Harris'],
#   'director': 'Robert Benton',
#   'writer': 'Robert Benton'},
#  {'name': 'The Incident',
#   'year': '2011',
#   'cast': ['Kenny Doughty',
#    'Rupert Evans',
#    'Dave Legeno',
#    'Richard Brake',
#    'Darren Kent'],
#   'director': 'Alexandre Courtes',
#   'writer': 'N/A'},
#  {'name': 'Police Story 2',
#   'year': '2007',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Not Fade Away',
#   'year': '2012',
#   'cast': ['John Magaro',
#    'James Gandolfini',
#    'Bella Heathcote',
#    'Jack Huston',
#    'Will Brill'],
#   'director': 'David Chase',
#   'writer': 'David Chase'},
#  {'name': 'In the Mood for Love',
#   'year': '2000',
#   'cast': ['Tony Leung Chiu-wai',
#    'Maggie Cheung',
#    'Rebecca Pan',
#    'Kelly Lai Chen',
#    'Siu Ping-lam'],
#   'director': 'Wong Kar-wai',
#   'writer': 'N/A'},
#  {'name': 'Kaizoku Sentai Gokaiger the Movie: The Flying Ghost Ship',
#   'year': '2011',
#   'cast': ['Ryota Ozawa',
#    'Yuki Yamada',
#    'Mao Ichimichi',
#    'Kazuki Shimizu',
#    'Yui Koike'],
#   'director': 'Katsuya Watanabe',
#   'writer': 'N/A'},
#  {'name': 'To Live and Die in L.A.',
#   'year': '1985',
#   'cast': ['William Petersen',
#    'Willem Dafoe',
#    'John Pankow',
#    'Debra Feuer',
#    'John Turturro'],
#   'director': 'William Friedkin',
#   'writer': 'N/A'},
#  {'name': 'The Young Guns',
#   'year': '1956',
#   'cast': ['Russ Tamblyn',
#    'Gloria Talbott',
#    'Perry Lopez',
#    'Scott Marlowe',
#    'Wright King'],
#   'director': 'Albert Band',
#   'writer': 'N/A'},
#  {'name': 'Secret Window',
#   'year': '2004',
#   'cast': ['Johnny Depp',
#    'John Turturro',
#    'Maria Bello',
#    'Timothy Hutton',
#    'Charles S. Dutton'],
#   'director': 'David Koepp',
#   'writer': 'N/A'},
#  {'name': 'Ladybird, Ladybird',
#   'year': '1994',
#   'cast': ['Crissy Rock',
#    'Vladimir Vega',
#    'Sandie Lavelle',
#    'Mauricio Venegas',
#    'Ray Winstone'],
#   'director': 'Ken Loach',
#   'writer': 'Rona Munro'},
#  {'name': 'Robot Stories',
#   'year': '2003',
#   'cast': ['Karen Tsen Lee',
#    'Glenn Kubota',
#    'Tamlyn Tomita',
#    'James Saito',
#    'Vin Knight'],
#   'director': 'Greg Pak',
#   'writer': 'Greg Pak'},
#  {'name': 'Amelia',
#   'year': '2009',
#   'cast': ['Hilary Swank',
#    'Richard Gere',
#    'Aaron Abrams',
#    'Ewan McGregor',
#    'Christopher Eccleston'],
#   'director': 'Mira Nair',
#   'writer': 'Ronald Bass'},
#  {'name': '21',
#   'year': '2008',
#   'cast': ['Jim Sturgess',
#    'Kevin Spacey',
#    'Kate Bosworth',
#    'Aaron Yoo',
#    'Liza Lapira'],
#   'director': 'Robert Luketic',
#   'writer': 'N/A'},
#  {'name': 'The Rocky Horror Picture Show',
#   'year': '1975',
#   'cast': ['Tim Curry',
#    'Susan Sarandon',
#    'Barry Bostwick',
#    "Richard O'Brien",
#    'Patricia Quinn'],
#   'director': 'Jim Sharman',
#   'writer': 'N/A'},
#  {'name': 'Curse of Chucky',
#   'year': '2013',
#   'cast': ['Fiona Dourif',
#    'Brad Dourif',
#    'Danielle Bisutti',
#    'Summer H. Howell',
#    'Brennan Elliott'],
#   'director': 'Don Mancini',
#   'writer': 'Don Mancini'},
#  {'name': 'Timeline',
#   'year': '2003',
#   'cast': ['Paul Walker',
#    "Frances O'Connor",
#    'Gerard Butler',
#    'Billy Connolly',
#    'David Thewlis'],
#   'director': 'Richard Donner',
#   'writer': 'N/A'},
#  {'name': 'Picnic at Hanging Rock',
#   'year': '1975',
#   'cast': ['Rachel Roberts',
#    'Vivean Gray',
#    'Helen Morse',
#    'Kirsty Child',
#    'Tony Llewellyn-Jones'],
#   'director': 'Peter Weir',
#   'writer': 'N/A'},
#  {'name': 'Epic Movie',
#   'year': '2007',
#   'cast': ['Kal Penn',
#    'Adam Campbell',
#    'Jennifer Coolidge',
#    'Jayma Mays',
#    'Faune Chambers'],
#   'director': 'Jason Friedberg',
#   'writer': 'Jason Friedberg'},
#  {'name': 'Homeward Bound',
#   'year': '1923',
#   'cast': ['Thomas Meighan',
#    'Lila Lee',
#    'Charles S. Abbe',
#    'William P. Carleton',
#    'Hugh Cameron'],
#   'director': 'Ralph Ince',
#   'writer': 'N/A'},
#  {'name': "White Men Can't Jump",
#   'year': '1992',
#   'cast': ['Wesley Snipes',
#    'Woody Harrelson',
#    'Rosie Perez',
#    'Tyra Ferrell',
#    'Cylk Cozart'],
#   'director': 'Ron Shelton',
#   'writer': 'N/A'},
#  {'name': 'These Final Hours',
#   'year': '2013',
#   'cast': ['Nathan Phillips',
#    'Angourie Rice',
#    'Daniel Henshall',
#    'Jessica De Gouw',
#    'David Field'],
#   'director': 'Zak Hilditch',
#   'writer': 'Zak Hilditch'},
#  {'name': 'Fast 8',
#   'year': 'None',
#   'cast': ['Padung Songsang',
#    'Kunatip Pinpradub',
#    'Aukkarat Jittasiri',
#    'Nida Patcharaveerapong',
#    'Akom Preedakul'],
#   'director': 'Poj Arnon',
#   'writer': 'N/A'},
#  {'name': 'Herbie: Fully Loaded',
#   'year': '2005',
#   'cast': ['Lindsay Lohan',
#    'Michael Keaton',
#    'Matt Dillon',
#    'Breckin Meyer',
#    'Justin Long'],
#   'director': 'Angela Robinson',
#   'writer': 'N/A'},
#  {'name': "Baby's Day Out",
#   'year': '1994',
#   'cast': ['Joe Mantegna',
#    'Lara Flynn Boyle',
#    'Joe Pantoliano',
#    'Brian Haley',
#    'Cynthia Nixon'],
#   'director': 'Patrick Read Johnson',
#   'writer': 'N/A'},
#  {'name': 'Forever Young',
#   'year': '1992',
#   'cast': ['Mel Gibson',
#    'Jamie Lee Curtis',
#    'Elijah Wood',
#    'Isabel Glasser',
#    'George Wendt'],
#   'director': 'Steve Miner',
#   'writer': 'N/A'},
#  {'name': 'Spider',
#   'year': '2007',
#   'cast': ['Nash Edgerton',
#    'Mirrah Foulkes',
#    'Chum Ehelepola',
#    'David Michôd',
#    'Sebastian Dickins'],
#   'director': 'Nash Edgerton',
#   'writer': 'Nash Edgerton'},
#  {'name': 'Fat Man and Little Boy',
#   'year': '1989',
#   'cast': ['Paul Newman',
#    'Dwight Schultz',
#    'Bonnie Bedelia',
#    'John Cusack',
#    'Laura Dern'],
#   'director': 'Roland Joffé',
#   'writer': 'N/A'},
#  {'name': 'Hard Boiled',
#   'year': '1992',
#   'cast': ['Chow Yun-fat',
#    'Tony Leung Chiu-wai',
#    'Anthony Wong',
#    'Teresa Mo',
#    'Philip Chan'],
#   'director': 'John Woo',
#   'writer': 'N/A'},
#  {'name': 'The Eye',
#   'year': '2008',
#   'cast': ['Jessica Alba',
#    'Alessandro Nivola',
#    'Parker Posey',
#    'Rade Šerbedžija',
#    'Mia Stallard'],
#   'director': 'David Moreau',
#   'writer': 'N/A'},
#  {'name': 'List of accolades received by Gone Girl',
#   'year': 'None',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Like Water for Chocolate',
#   'year': '1992',
#   'cast': ['Marco Leonardi',
#    'Lumi Cavazos',
#    'Regina Torné',
#    'Ada Carrasco',
#    'Mario Iván Martínez'],
#   'director': 'Alfonso Arau',
#   'writer': 'N/A'},
#  {'name': 'Urban Legend',
#   'year': '1998',
#   'cast': ['Alicia Witt',
#    'Jared Leto',
#    'Rebecca Gayheart',
#    'Michael Rosenbaum',
#    'Loretta Devine'],
#   'director': 'Jamie Blanks',
#   'writer': 'N/A'},
#  {'name': 'Dr. Strangelove',
#   'year': '1964',
#   'cast': ['Peter Sellers',
#    'George C. Scott',
#    'Sterling Hayden',
#    'Keenan Wynn',
#    'Slim Pickens'],
#   'director': 'Stanley Kubrick',
#   'writer': 'N/A'},
#  {'name': 'Concussion',
#   'year': '2015',
#   'cast': ['Will Smith',
#    'Alec Baldwin',
#    'Albert Brooks',
#    'Gugu Mbatha-Raw',
#    'David Morse'],
#   'director': 'Peter Landesman',
#   'writer': 'Peter Landesman'},
#  {'name': 'Breathe',
#   'year': '2009',
#   'cast': ['Yang Ik-june',
#    'Kim Kkob-bi',
#    'Lee Hwan',
#    'Park Jeong-soon',
#    'Lee Seung-yeon'],
#   'director': 'Yang Ik-june',
#   'writer': 'Yang Ik-june'},
#  {'name': 'Appleseed Ex Machina',
#   'year': 'None',
#   'cast': ['Ai Kobayashi',
#    'Koichi Yamadera',
#    'Yuji Kishi',
#    'Kong Kuwata',
#    'Shinpachi Tsuji'],
#   'director': 'Shinji Aramaki',
#   'writer': 'N/A'},
#  {'name': 'Shaolin Temple',
#   'year': '1976',
#   'cast': ['Alexander Fu Sheng',
#    'Kuan-Chun Chi',
#    'Wai Wang',
#    'David Chiang Da-Wei',
#    'Ti Lung'],
#   'director': 'Chang Cheh',
#   'writer': 'Ni Kuang'},
#  {'name': 'Cheaper by the Dozen',
#   'year': '2003',
#   'cast': ['Steve Martin',
#    'Bonnie Hunt',
#    'Piper Perabo',
#    'Tom Welling',
#    'Hilary Duff'],
#   'director': 'Shawn Levy',
#   'writer': 'N/A'},
#  {'name': 'Windy City Heat',
#   'year': 'None',
#   'cast': ['Perry Caravello',
#    'Don Barris',
#    'Tony Barbieri',
#    'Bobcat Goldthwait',
#    'Dane Cook'],
#   'director': 'Bobcat Goldthwait',
#   'writer': 'Jimmy Kimmel'},
#  {'name': 'Dog Days',
#   'year': '2001',
#   'cast': ['Maria Hofstätter',
#    'Alfred Mrva',
#    'Franziska Weisz',
#    'Christine Jirku',
#    'Viktor Hennemann'],
#   'director': 'Ulrich Seidl',
#   'writer': 'N/A'},
#  {'name': 'Dead Silence',
#   'year': '2007',
#   'cast': ['Ryan Kwanten',
#    'Amber Valletta',
#    'Donnie Wahlberg',
#    'Bob Gunton',
#    'Laura Regan'],
#   'director': 'James Wan',
#   'writer': 'James Wan'},
#  {'name': "Your Sister's Sister",
#   'year': '2011',
#   'cast': ['Emily Blunt',
#    'Rosemarie DeWitt',
#    'Mark Duplass',
#    'Michael Harring',
#    'Mike Birbiglia'],
#   'director': 'Lynn Shelton',
#   'writer': 'Lynn Shelton'},
#  {'name': 'City of Angels',
#   'year': 'None',
#   'cast': ['Nicolas Cage',
#    'Meg Ryan',
#    'Andre Braugher',
#    'Dennis Franz',
#    'Colm Feore'],
#   'director': 'Brad Silberling',
#   'writer': 'N/A'},
#  {'name': 'Gosford Park',
#   'year': '2001',
#   'cast': ['Maggie Smith',
#    'Michael Gambon',
#    'Kristin Scott Thomas',
#    'Camilla Rutherford',
#    'Charles Dance'],
#   'director': 'Robert Altman',
#   'writer': 'Julian Fellowes'},
#  {'name': "You Don't Mess with the Zohan",
#   'year': '2008',
#   'cast': ['Adam Sandler',
#    'Emmanuelle Chriqui',
#    'John Turturro',
#    'Nick Swardson',
#    'Lainie Kazan'],
#   'director': 'Dennis Dugan',
#   'writer': 'N/A'},
#  {'name': "Cheech & Chong's Animated Movie",
#   'year': '2013',
#   'cast': ['Cheech Marin', 'Tommy Chong'],
#   'director': 'Branden Chambers',
#   'writer': 'Cheech Marin'},
#  {'name': 'Beware! The Blob',
#   'year': '1972',
#   'cast': ['Robert Walker Jr.',
#    'Gwynne Gilford',
#    'Richard Stahl',
#    'Richard Webb',
#    'Shelley Berman'],
#   'director': 'Larry Hagman',
#   'writer': 'N/A'},
#  {'name': 'The Uncomfortable Camera',
#   'year': '2005',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Hook',
#   'year': '1991',
#   'cast': ['Dustin Hoffman',
#    'Robin Williams',
#    'Julia Roberts',
#    'Bob Hoskins',
#    'Maggie Smith'],
#   'director': 'Steven Spielberg',
#   'writer': 'N/A'},
#  {'name': 'Winter Passing',
#   'year': '2005',
#   'cast': ['Zooey Deschanel',
#    'Will Ferrell',
#    'Ed Harris',
#    'Amy Madigan',
#    'Amelia Warner'],
#   'director': 'Adam Rapp',
#   'writer': 'Adam Rapp'},
#  {'name': 'Little Giants',
#   'year': '1994',
#   'cast': ['Rick Moranis',
#    "Ed O'Neill",
#    'Devon Sawa',
#    'Shawna Waldron',
#    'Todd Bosley'],
#   'director': 'Duwayne Dunham',
#   'writer': 'N/A'},
#  {'name': 'Failure to Launch',
#   'year': '2006',
#   'cast': ['Matthew McConaughey',
#    'Sarah Jessica Parker',
#    'Zooey Deschanel',
#    'Justin Bartha',
#    'Bradley Cooper'],
#   'director': 'Tom Dey',
#   'writer': 'N/A'},
#  {'name': 'Benji the Hunted',
#   'year': '1987',
#   'cast': ['Red Steagall',
#    'Frank Inn',
#    'Nancy Francis',
#    'Benjean',
#    'Bart The Bear'],
#   'director': 'Joe Camp',
#   'writer': 'Joe Camp'},
#  {'name': 'Father of the Bride Part II',
#   'year': '1995',
#   'cast': ['Steve Martin',
#    'Diane Keaton',
#    'Martin Short',
#    'Kimberly Williams-Paisley',
#    'George Newbern'],
#   'director': 'Charles Shyer',
#   'writer': 'N/A'},
#  {'name': 'King Boxer',
#   'year': '1972',
#   'cast': ['Meng Fei', 'Yasuaki Kurata', 'Mang Fei', 'Kong Lau'],
#   'director': 'Kung Min',
#   'writer': 'N/A'},
#  {'name': 'Bully',
#   'year': '2001',
#   'cast': ['Brad Renfro',
#    'Nick Stahl',
#    'Rachel Miner',
#    'Michael Pitt',
#    'Daniel Franzese'],
#   'director': 'Larry Clark',
#   'writer': 'N/A'},
#  {'name': 'Finding Dory',
#   'year': '2016',
#   'cast': ['Albert Brooks',
#    'Ellen DeGeneres',
#    "Ed O'Neill",
#    'Hayden Rolence',
#    'Diane Keaton'],
#   'director': 'Andrew Stanton',
#   'writer': 'N/A'},
#  {'name': 'Run for Money',
#   'year': '1999',
#   'cast': ['Taner Birsel',
#    'Bennu Yıldırımlar',
#    'Zuhal Gencer',
#    'Engin Alkan',
#    'Sermet Yeşil'],
#   'director': 'Reha Erdem',
#   'writer': 'Reha Erdem'},
#  {'name': 'Stuart Little',
#   'year': '1999',
#   'cast': ['Michael J. Fox',
#    'Geena Davis',
#    'Hugh Laurie',
#    'Jonathan Lipnicki',
#    'Nathan Lane'],
#   'director': 'Rob Minkoff',
#   'writer': 'N/A'},
#  {'name': 'Acts of Worship',
#   'year': '2001',
#   'cast': ['Ana Reeder',
#    'Michael Hyatt',
#    'Christopher Kadish',
#    'Michael Buscemi',
#    'John Ahearn'],
#   'director': 'Rosemary Rodriguez',
#   'writer': 'Rosemary Rodriguez'},
#  {'name': 'Dying of Laughter',
#   'year': '1999',
#   'cast': ['Santiago Segura',
#    'El Gran Wyoming',
#    'Álex Angulo',
#    'Carla Hidalgo',
#    'Eduardo Gómez'],
#   'director': 'Álex de la Iglesia',
#   'writer': 'Jorge Guerricaechevarría'},
#  {'name': 'Y Tu Mamá También',
#   'year': '2001',
#   'cast': ['Gael García Bernal',
#    'Diego Luna',
#    'Maribel Verdú',
#    'Daniel Giménez Cacho',
#    'Diana Bracho'],
#   'director': 'Alfonso Cuarón',
#   'writer': 'N/A'},
#  {'name': 'Lockout',
#   'year': '2012',
#   'cast': ['Guy Pearce',
#    'Maggie Grace',
#    'Vincent Regan',
#    'Joseph Gilgun',
#    'Lennie James'],
#   'director': 'Stephen St. Leger',
#   'writer': 'Luc Besson'},
#  {'name': 'Eddie and the Cruisers II: Eddie Lives!',
#   'year': '1989',
#   'cast': ['Michael Paré',
#    'Marina Orsini',
#    'Bernie Coulson',
#    'Matthew Laurance',
#    'Michael Fennell'],
#   'director': 'Jean-Claude Lord',
#   'writer': 'Charles Zev Cohen'},
#  {'name': 'Jeepers Creepers',
#   'year': '2001',
#   'cast': ['Gina Philips',
#    'Justin Long',
#    'Jonathan Breck',
#    'Patricia Belcher',
#    'Eileen Brennan'],
#   'director': 'Victor Salva',
#   'writer': 'Victor Salva'},
#  {'name': 'Le Mans',
#   'year': '1970',
#   'cast': ['Lang Jeffries',
#    'Erna Schürer',
#    'Maurizio Bonuglia',
#    'Edwige Fenech',
#    'Franco Pesce'],
#   'director': 'Osvaldo Civirani',
#   'writer': 'N/A'},
#  {'name': 'The Sisterhood of the Traveling Pants 2',
#   'year': '2008',
#   'cast': ['Amber Tamblyn',
#    'America Ferrera',
#    'Blake Lively',
#    'Alexis Bledel',
#    'Rachel Nichols'],
#   'director': 'Sanaa Hamri',
#   'writer': 'N/A'},
#  {'name': 'Wreckers',
#   'year': '2011',
#   'cast': ['Benedict Cumberbatch',
#    'Claire Foy',
#    'Shaun Evans',
#    'Sinead Matthews',
#    'Peter McDonald'],
#   'director': 'D.R. Hood',
#   'writer': 'Dictynna Hood'},
#  {'name': 'Death at a Funeral',
#   'year': '2010',
#   'cast': ['Chris Rock',
#    'Martin Lawrence',
#    'Zoe Saldaña',
#    'Tracy Morgan',
#    'Regina Hall'],
#   'director': 'Neil LaBute',
#   'writer': 'Dean Craig'},
#  {'name': 'Judge Dredd',
#   'year': '1995',
#   'cast': ['Sylvester Stallone',
#    'Diane Lane',
#    'Armand Assante',
#    'Rob Schneider',
#    'Jürgen Prochnow'],
#   'director': 'Danny Cannon',
#   'writer': 'N/A'},
#  {'name': '12',
#   'year': '2007',
#   'cast': ['Sergei Makovetsky',
#    'Nikita Mikhalkov',
#    'Sergey Garmash',
#    'Valentin Gaft',
#    'Aleksey Petrenko'],
#   'director': 'Nikita Mikhalkov',
#   'writer': 'Nikita Mikhalkov'},
#  {'name': 'The Call',
#   'year': '2013',
#   'cast': ['Halle Berry',
#    'Abigail Breslin',
#    'Morris Chestnut',
#    'Michael Eklund',
#    'David Otunga'],
#   'director': 'Brad Anderson',
#   'writer': 'N/A'},
#  {'name': 'Heaven & Earth',
#   'year': '1993',
#   'cast': ['Tommy Lee Jones',
#    'Haing S. Ngor',
#    'Joan Chen',
#    'Thuan K. Nguyen',
#    'Hiep Thi Le'],
#   'director': 'Oliver Stone',
#   'writer': 'N/A'},
#  {'name': 'Without Permission',
#   'year': '2012',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Charlie St. Cloud',
#   'year': '2010',
#   'cast': ['Zac Efron',
#    'Charlie Tahan',
#    'Amanda Crew',
#    'Augustus Prew',
#    'Donal Logue'],
#   'director': 'Burr Steers',
#   'writer': 'Lewis Colick'},
#  {'name': 'One Piece Film: Z',
#   'year': 'None',
#   'cast': ['Mayumi Tanaka',
#    'Kazuya Nakai',
#    'Akemi Okamura',
#    'Kappei Yamaguchi',
#    'Hiroaki Hirata'],
#   'director': 'Tatsuya Nagamine',
#   'writer': 'N/A'},
#  {'name': 'The Human Centipede',
#   'year': '2009',
#   'cast': ['Dieter Laser',
#    'Ashley C. Williams',
#    'Ashlynn Yennie',
#    'Akihiro Kitamura',
#    'Andreas Leupold'],
#   'director': 'Tom Six',
#   'writer': 'Tom Six'},
#  {'name': 'The Mask',
#   'year': '1988',
#   'cast': ['Helena Bonham Carter',
#    'Michael Maloney',
#    'Feodor Chaliapin Jr.',
#    'Roberto Herlitzka',
#    'Alberto Cracco'],
#   'director': 'Fiorella Infascelli',
#   'writer': 'Enzo Ungari'},
#  {'name': 'Cast Away',
#   'year': '2000',
#   'cast': ['Tom Hanks',
#    'Helen Hunt',
#    'Chris Noth',
#    'Paul Sanchez',
#    'Lari White'],
#   'director': 'Robert Zemeckis',
#   'writer': 'William Broyles Jr.'},
#  {'name': 'Dogtown and Z-Boys',
#   'year': '2001',
#   'cast': ['Sean Penn',
#    'Jay Adams',
#    'Henry Rollins',
#    'Steve Caballero',
#    'Tony Hawk'],
#   'director': 'Stacy Peralta',
#   'writer': 'Stacy Peralta'},
#  {'name': 'Memoirs of a Geisha',
#   'year': '2005',
#   'cast': ['Zhang Ziyi',
#    'Gong Li',
#    'Michelle Yeoh',
#    'Ken Watanabe',
#    'Suzuka Ohgo'],
#   'director': 'Rob Marshall',
#   'writer': 'N/A'},
#  {'name': 'Vertical Limit',
#   'year': '2000',
#   'cast': ["Chris O'Donnell",
#    'Robin Tunney',
#    'Bill Paxton',
#    'Scott Glenn',
#    'Izabella Scorupco'],
#   'director': 'Martin Campbell',
#   'writer': 'Robert King'},
#  {'name': 'Freddy Got Fingered',
#   'year': '2001',
#   'cast': ['Tom Green',
#    'Rip Torn',
#    'Marisa Coughlan',
#    'Eddie Kaye Thomas',
#    'Harland Williams'],
#   'director': 'Tom Green',
#   'writer': 'N/A'},
#  {'name': 'Steve Jobs',
#   'year': '2015',
#   'cast': ['Michael Fassbender',
#    'Kate Winslet',
#    'Seth Rogen',
#    'Jeff Daniels',
#    'Michael Stuhlbarg'],
#   'director': 'Danny Boyle',
#   'writer': 'Aaron Sorkin'},
#  {'name': 'Hollow Man',
#   'year': '2000',
#   'cast': ['Kevin Bacon',
#    'Elisabeth Shue',
#    'Josh Brolin',
#    'Kim Dickens',
#    'Greg Grunberg'],
#   'director': 'Paul Verhoeven',
#   'writer': 'N/A'},
#  {'name': 'Woman on Top',
#   'year': '2000',
#   'cast': ['Penélope Cruz',
#    'Murilo Benício',
#    'Mark Feuerstein',
#    'John de Lancie',
#    'Anne Ramsay'],
#   'director': 'Fina Torres',
#   'writer': 'Vera Blasi'},
#  {'name': 'Hamlet',
#   'year': '2009',
#   'cast': ['Mel Gibson',
#    'Glenn Close',
#    'Alan Bates',
#    'Paul Scofield',
#    'Ian Holm'],
#   'director': 'Franco Zeffirelli',
#   'writer': 'N/A'},
#  {'name': 'The Seven Five',
#   'year': 'None',
#   'cast': ['Michael Dowd'],
#   'director': 'Tiller Russell',
#   'writer': 'N/A'},
#  {'name': 'The Wizard of Oz',
#   'year': '1939',
#   'cast': ['Judy Garland',
#    'Ray Bolger',
#    'Jack Haley',
#    'Bert Lahr',
#    'Frank Morgan'],
#   'director': 'Victor Fleming',
#   'writer': 'N/A'},
#  {'name': 'The Best Exotic Marigold Hotel',
#   'year': 'None',
#   'cast': ['Bill Nighy',
#    'Maggie Smith',
#    'Tom Wilkinson',
#    'Judi Dench',
#    'Dev Patel'],
#   'director': 'John Madden',
#   'writer': 'N/A'},
#  {'name': 'Lovers',
#   'year': '1999',
#   'cast': ['Élodie Bouchez',
#    'Sergej Trifunović',
#    'Madeleine Barr',
#    'Mathias Benguigui',
#    'Jean-Christophe Bouvet'],
#   'director': 'Jean-Marc Barr',
#   'writer': 'Jean-Marc Barr'},
#  {'name': 'The Transporter',
#   'year': '2002',
#   'cast': ['Jason Statham',
#    'Shu Qi',
#    'François Berléand',
#    'Matt Schulze',
#    'Ric Young'],
#   'director': 'Louis Leterrier',
#   'writer': 'N/A'},
#  {'name': "My Baby's Daddy",
#   'year': '2004',
#   'cast': ['Eddie Griffin',
#    'Anthony Anderson',
#    'Michael Imperioli',
#    'Method Man',
#    'Paula Jai Parker'],
#   'director': 'Cheryl Dunye',
#   'writer': 'David Wagner'},
#  {'name': 'Children of the Corn',
#   'year': '1984',
#   'cast': ['Peter Horton',
#    'Linda Hamilton',
#    'R. G. Armstrong',
#    'John Franklin',
#    'Courtney Gains'],
#   'director': 'Fritz Kiersch',
#   'writer': 'N/A'},
#  {'name': 'Poverty Inc.',
#   'year': '2014',
#   'cast': ['Michael Parenti'],
#   'director': 'Michael Matheson Miller',
#   'writer': 'Michael Matheson Miller'},
#  {'name': 'Mulan',
#   'year': '1998',
#   'cast': ['Ming-Na Wen',
#    'Eddie Murphy',
#    'BD Wong',
#    'Miguel Ferrer',
#    'Harvey Fierstein'],
#   'director': 'Tony Bancroft',
#   'writer': 'N/A'},
#  {'name': 'Drag Me to Hell',
#   'year': '2009',
#   'cast': ['Alison Lohman',
#    'Justin Long',
#    'Lorna Raver',
#    'Dileep Rao',
#    'David Paymer'],
#   'director': 'Sam Raimi',
#   'writer': 'Sam Raimi'},
#  {'name': 'Surf Ninjas',
#   'year': '1993',
#   'cast': ['Ernie Reyes Jr.',
#    'Nicolas Cowan',
#    'Rob Schneider',
#    'Leslie Nielsen',
#    'Ernie Reyes Sr.'],
#   'director': 'Neal Israel',
#   'writer': 'Dan Gordon'},
#  {'name': 'Death Toll',
#   'year': '2008',
#   'cast': ['DMX',
#    'Lou Diamond Phillips',
#    'Keshia Knight Pulliam',
#    'Leila Arcieri',
#    'Alec Rayme'],
#   'director': 'Phenomenon',
#   'writer': 'Dan Garcia'},
#  {'name': 'Beverly Hills Cop',
#   'year': '1984',
#   'cast': ['Eddie Murphy',
#    'Judge Reinhold',
#    'John Ashton',
#    'Lisa Eilbacher',
#    'Ronny Cox'],
#   'director': 'Martin Brest',
#   'writer': 'N/A'},
#  {'name': 'The Revenant',
#   'year': '2009',
#   'cast': ['Chris Wylde',
#    'David Anders',
#    'Louise Griffiths',
#    'Jacy King',
#    'Eric Payne'],
#   'director': 'D. Kerry Prior',
#   'writer': 'D. Kerry Prior'},
#  {'name': 'Cowboy',
#   'year': '1958',
#   'cast': ['Glenn Ford',
#    'Jack Lemmon',
#    'Anna Kashfi',
#    'Brian Donlevy',
#    'Dick York'],
#   'director': 'Delmer Daves',
#   'writer': 'N/A'},
#  {'name': 'Beauty and the Bestie',
#   'year': '2015',
#   'cast': ['Vice Ganda',
#    'Coco Martin',
#    'James Reid',
#    'Nadine Lustre',
#    'Ellen Adarna'],
#   'director': 'Wenn V. Deramas',
#   'writer': 'N/A'},
#  {'name': 'Saving Mr. Banks',
#   'year': '2013',
#   'cast': ['Emma Thompson',
#    'Tom Hanks',
#    'Colin Farrell',
#    'Paul Giamatti',
#    'Ruth Wilson'],
#   'director': 'John Lee Hancock',
#   'writer': 'Sue Smith'},
#  {'name': 'The Holy Mountain',
#   'year': '1973',
#   'cast': ['Alejandro Jodorowsky',
#    'Horacio Salinas',
#    'Zamira Saunders',
#    'Juan Ferrara',
#    'Adriana Page'],
#   'director': 'Alejandro Jodorowsky',
#   'writer': 'N/A'},
#  {'name': 'The Tooth Fairy',
#   'year': '2006',
#   'cast': ['Lochlyn Munro',
#    'Chandra West',
#    'Steve Bacic',
#    'Jianna Ballard',
#    'Carrie Fleming'],
#   'director': 'Chuck Bowman',
#   'writer': 'N/A'},
#  {'name': 'Deadroom',
#   'year': '2005',
#   'cast': ['Harry Goaz', 'Grant James', 'Bill Sebastian', 'Paul T. Taylor'],
#   'director': 'David Lowery',
#   'writer': 'David Lowery'},
#  {'name': 'The Square',
#   'year': '2017',
#   'cast': ['Claes Bang',
#    'Elisabeth Moss',
#    'Dominic West',
#    'Terry Notary',
#    'Christopher Læssø'],
#   'director': 'Ruben Östlund',
#   'writer': 'Ruben Östlund'},
#  {'name': 'Fatty Joins the Force',
#   'year': '1913',
#   'cast': ['Roscoe Arbuckle',
#    'Minta Durfee',
#    'Edgar Kennedy',
#    'Charles Avery',
#    'Lou Breslow'],
#   'director': 'George Nichols',
#   'writer': 'N/A'},
#  {'name': 'The Great Mouse Detective',
#   'year': 'None',
#   'cast': ['Barrie Ingham',
#    'Val Bettin',
#    'Vincent Price',
#    'Susanne Pollatschek',
#    'Candy Candido'],
#   'director': 'Ron Clements',
#   'writer': 'N/A'},
#  {'name': 'Shutter',
#   'year': '2008',
#   'cast': ['Joshua Jackson',
#    'Rachael Taylor',
#    'Megumi Okina',
#    'David Denman',
#    'Eri Otoguro'],
#   'director': 'Masayuki Ochiai',
#   'writer': 'N/A'},
#  {'name': 'Home Alone 2: Lost in New York',
#   'year': '1992',
#   'cast': ['Macaulay Culkin',
#    'Joe Pesci',
#    'Daniel Stern',
#    "Catherine O'Hara",
#    'John Heard'],
#   'director': 'Chris Columbus',
#   'writer': 'N/A'},
#  {'name': 'Dial M for Murder',
#   'year': '1954',
#   'cast': ['Ray Milland',
#    'Grace Kelly',
#    'Robert Cummings',
#    'John Williams',
#    'Anthony Dawson'],
#   'director': 'Alfred Hitchcock',
#   'writer': 'N/A'},
#  {'name': 'Maya the Bee',
#   'year': '2014',
#   'cast': ['Coco Jack Gillies',
#    'Kodi Smit-McPhee',
#    'Richard Roxburgh',
#    'Noah Taylor',
#    'Justine Clarke'],
#   'director': 'Alexs Stadermann',
#   'writer': 'N/A'},
#  {'name': 'Groundhog Day',
#   'year': 'None',
#   'cast': ['Bill Murray',
#    'Andie MacDowell',
#    'Chris Elliott',
#    'Stephen Tobolowsky',
#    'Brian Doyle-Murray'],
#   'director': 'Harold Ramis',
#   'writer': 'N/A'},
#  {'name': 'Secretary',
#   'year': '2002',
#   'cast': ['Maggie Gyllenhaal',
#    'James Spader',
#    'Jeremy Davies',
#    'Lesley Ann Warren',
#    'Stephen McHattie'],
#   'director': 'Steven Shainberg',
#   'writer': 'N/A'},
#  {'name': 'Far and Away',
#   'year': '1992',
#   'cast': ['Tom Cruise',
#    'Nicole Kidman',
#    'Thomas Gibson',
#    'Robert Prosky',
#    'Barbara Babcock'],
#   'director': 'Ron Howard',
#   'writer': 'N/A'},
#  {'name': 'Norbit',
#   'year': '2007',
#   'cast': ['Eddie Murphy',
#    'Thandiwe Newton',
#    'Terry Crews',
#    'Clifton Powell',
#    'Lester Speight'],
#   'director': 'Brian Robbins',
#   'writer': 'N/A'},
#  {'name': 'From Beyond',
#   'year': '1986',
#   'cast': ['Jeffrey Combs',
#    'Barbara Crampton',
#    'Ken Foree',
#    'Ted Sorel',
#    'Carolyn Purdy-Gordon'],
#   'director': 'Stuart Gordon',
#   'writer': 'N/A'},
#  {'name': "Madea's Family Reunion",
#   'year': '2006',
#   'cast': ['Tyler Perry',
#    'Rochelle Aytes',
#    'Lisa Arrindell',
#    'Lynn Whitfield',
#    'Blair Underwood'],
#   'director': 'Tyler Perry',
#   'writer': 'Tyler Perry'},
#  {'name': 'Spetters',
#   'year': '1980',
#   'cast': ['Hans van Tongeren',
#    'Renée Soutendijk',
#    'Toon Agterberg',
#    'Maarten Spanjer',
#    'Marianne Boyer'],
#   'director': 'Paul Verhoeven',
#   'writer': 'N/A'},
#  {'name': 'Amityville: The Awakening',
#   'year': '2017',
#   'cast': ['Bella Thorne',
#    'Cameron Monaghan',
#    'Jennifer Jason Leigh',
#    'Thomas Mann',
#    'Jennifer Morrison'],
#   'director': 'Franck Khalfoun',
#   'writer': 'Franck Khalfoun'},
#  {'name': 'Yours, Mine & Ours',
#   'year': '2005',
#   'cast': ['Dennis Quaid',
#    'Rene Russo',
#    'Sean Faris',
#    'Danielle Panabaker',
#    'Miranda Cosgrove'],
#   'director': 'Raja Gosnell',
#   'writer': 'N/A'},
#  {'name': 'Evan Almighty',
#   'year': '2007',
#   'cast': ['Steve Carell',
#    'Morgan Freeman',
#    'Lauren Graham',
#    'Johnny Simmons',
#    'Graham Phillips'],
#   'director': 'Tom Shadyac',
#   'writer': 'N/A'},
#  {'name': 'Serenity',
#   'year': '2005',
#   'cast': ['Nathan Fillion',
#    'Summer Glau',
#    'Gina Torres',
#    'Alan Tudyk',
#    'Morena Baccarin'],
#   'director': 'Joss Whedon',
#   'writer': 'Joss Whedon'},
#  {'name': 'Apocalypse Now',
#   'year': '1979',
#   'cast': ['Martin Sheen',
#    'Frederic Forrest',
#    'Albert Hall',
#    'Laurence Fishburne',
#    'Sam Bottoms'],
#   'director': 'Francis Ford Coppola',
#   'writer': 'Francis Ford Coppola'},
#  {'name': 'Everly',
#   'year': '2014',
#   'cast': ['Salma Hayek Pinault',
#    'Hiroyuki Watanabe',
#    'Laura Cepeda',
#    'Togo Igawa',
#    'Akie Kotabe'],
#   'director': 'Joe Lynch',
#   'writer': 'N/A'},
#  {'name': 'Jihad: A Story of the Others',
#   'year': '2015',
#   'cast': 'N/A',
#   'director': 'Deeyah Khan',
#   'writer': 'N/A'},
#  {'name': 'The Shootist',
#   'year': '1976',
#   'cast': ['John Wayne',
#    'Lauren Bacall',
#    'Ron Howard',
#    'James Stewart',
#    'Richard Boone'],
#   'director': 'Don Siegel',
#   'writer': 'N/A'},
#  {'name': 'The Danish Girl',
#   'year': '2015',
#   'cast': ['Eddie Redmayne',
#    'Alicia Vikander',
#    'Matthias Schoenaerts',
#    'Ben Whishaw',
#    'Sebastian Koch'],
#   'director': 'Tom Hooper',
#   'writer': 'N/A'},
#  {'name': 'RoboCop',
#   'year': '1987',
#   'cast': ['Peter Weller',
#    'Nancy Allen',
#    "Dan O'Herlihy",
#    'Ronny Cox',
#    'Kurtwood Smith'],
#   'director': 'Paul Verhoeven',
#   'writer': 'Edward Neumeier'},
#  {'name': 'Cyrano de Bergerac',
#   'year': '1990',
#   'cast': ['Gérard Depardieu',
#    'Anne Brochet',
#    'Vincent Perez',
#    'Jacques Weber',
#    'Roland Bertin'],
#   'director': 'Jean-Paul Rappeneau',
#   'writer': 'N/A'},
#  {'name': 'X-Men',
#   'year': 'None',
#   'cast': ['James McAvoy',
#    'Michael Fassbender',
#    'Oscar Isaac',
#    'Jennifer Lawrence',
#    'Nicholas Hoult'],
#   'director': 'Bryan Singer',
#   'writer': 'N/A'},
#  {'name': 'Fast & Furious',
#   'year': '2009',
#   'cast': ['Vin Diesel',
#    'Paul Walker',
#    'Michelle Rodriguez',
#    'Jordana Brewster',
#    'John Ortiz'],
#   'director': 'Justin Lin',
#   'writer': 'Chris Morgan'},
#  {'name': 'Night Train',
#   'year': '2009',
#   'cast': ['Danny Glover',
#    'Steve Zahn',
#    'Leelee Sobieski',
#    'Geoff Bell',
#    'Matthias Schweighöfer'],
#   'director': 'Brian King',
#   'writer': 'N/A'},
#  {'name': 'Psych-Out',
#   'year': '1968',
#   'cast': ['Susan Strasberg',
#    'Dean Stockwell',
#    'Jack Nicholson',
#    'Bruce Dern',
#    'Adam Roarke'],
#   'director': 'Richard Rush',
#   'writer': 'N/A'},
#  {'name': 'Deranged',
#   'year': '1974',
#   'cast': ['Roberts Blossom',
#    'Cosette Lee',
#    'Leslie Carlson',
#    'Robert Warner',
#    'Marcia Diamond'],
#   'director': 'Jeff Gillen',
#   'writer': 'N/A'},
#  {'name': "Charlie's Angels",
#   'year': 'None',
#   'cast': ['Kristen Stewart',
#    'Naomi Scott',
#    'Ella Balinska',
#    'Elizabeth Banks',
#    'Patrick Stewart'],
#   'director': 'Elizabeth Banks',
#   'writer': 'N/A'},
#  {'name': 'Faces in the Crowd',
#   'year': '2011',
#   'cast': ['Milla Jovovich',
#    'Julian McMahon',
#    'David Atrakchi',
#    'Michael Shanks',
#    'Marianne Faithfull'],
#   'director': 'Julien Magnat',
#   'writer': 'N/A'},
#  {'name': 'Tiger Zinda Hai',
#   'year': '2017',
#   'cast': ['Salman Khan',
#    'Katrina Kaif',
#    'Girish Karnad',
#    'Paresh Rawal',
#    'Angad Bedi'],
#   'director': 'Ali Abbas Zafar',
#   'writer': 'Abdul Rafay Chandio'},
#  {'name': "Being Elmo: A Puppeteer's Journey",
#   'year': '2011',
#   'cast': ['Whoopi Goldberg',
#    'Frank Oz',
#    'Kevin Clash',
#    'Bill Barretta',
#    'Fran Brill'],
#   'director': 'Constance Marks',
#   'writer': 'Philip Shane'},
#  {'name': 'Idiocracy',
#   'year': '2006',
#   'cast': ['Luke Wilson',
#    'Maya Rudolph',
#    'Dax Shepard',
#    'Terry Crews',
#    "Anthony 'Citric' Campos"],
#   'director': 'Mike Judge',
#   'writer': 'N/A'},
#  {'name': 'Seed of Chucky',
#   'year': '2004',
#   'cast': ['Brad Dourif',
#    'Jennifer Tilly',
#    'Billy Boyd',
#    'Redman',
#    'Hannah Spearritt'],
#   'director': 'Don Mancini',
#   'writer': 'N/A'},
#  {'name': "A Midsummer Night's Dream",
#   'year': '1999',
#   'cast': ['Rupert Everett',
#    'Calista Flockhart',
#    'Kevin Kline',
#    'Michelle Pfeiffer',
#    'Stanley Tucci'],
#   'director': 'Michael Hoffman',
#   'writer': 'N/A'},
#  {'name': 'When the Levees Broke',
#   'year': 'None',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'B*A*P*S',
#   'year': '1997',
#   'cast': ['Halle Berry',
#    'Natalie Desselle-Reid',
#    'Martin Landau',
#    'Ian Richardson',
#    'Pierre Edwards'],
#   'director': 'Robert Townsend',
#   'writer': 'N/A'},
#  {'name': 'Rush Hour',
#   'year': '1998',
#   'cast': ['Jackie Chan',
#    'Chris Tucker',
#    'Tom Wilkinson',
#    'Philip Baker Hall',
#    'Elizabeth Peña'],
#   'director': 'Brett Ratner',
#   'writer': 'N/A'},
#  {'name': "It's a Mad, Mad, Mad, Mad World",
#   'year': '1963',
#   'cast': ['Spencer Tracy',
#    'Milton Berle',
#    'Sid Caesar',
#    'Buddy Hackett',
#    'Ethel Merman'],
#   'director': 'Stanley Kramer',
#   'writer': 'N/A'},
#  {'name': 'Never Back Down: No Surrender',
#   'year': '2016',
#   'cast': ['Michael Jai White',
#    'Josh Barnett',
#    'Gillian White',
#    'Nathan Jones',
#    'Damian Mavis'],
#   'director': 'Michael Jai White',
#   'writer': 'Chris Hauty'},
#  {'name': 'Leap Year',
#   'year': '2010',
#   'cast': ['Amy Adams',
#    'Matthew Goode',
#    'Adam Scott',
#    'John Lithgow',
#    "Noel O'Donovan"],
#   'director': 'Anand Tucker',
#   'writer': 'Deborah Kaplan'},
#  {'name': "We're the Millers",
#   'year': '2013',
#   'cast': ['Jennifer Aniston',
#    'Jason Sudeikis',
#    'Emma Roberts',
#    'Will Poulter',
#    'Kathryn Hahn'],
#   'director': 'Rawson Marshall Thurber',
#   'writer': 'N/A'},
#  {'name': 'Sully',
#   'year': '2016',
#   'cast': ['Tom Hanks',
#    'Aaron Eckhart',
#    'Laura Linney',
#    'Anna Gunn',
#    'Autumn Reeser'],
#   'director': 'Clint Eastwood',
#   'writer': 'N/A'},
#  {'name': 'Elysium',
#   'year': '2013',
#   'cast': ['Matt Damon',
#    'Jodie Foster',
#    'Sharlto Copley',
#    'Diego Luna',
#    'Wagner Moura'],
#   'director': 'Neill Blomkamp',
#   'writer': 'Neill Blomkamp'},
#  {'name': "Gerald's Game",
#   'year': '2017',
#   'cast': ['Carla Gugino',
#    'Bruce Greenwood',
#    'Henry Thomas',
#    'Chiara Aurelia',
#    'Kate Siegel'],
#   'director': 'Mike Flanagan',
#   'writer': 'N/A'},
#  {'name': 'Fantastic Four',
#   'year': '2015',
#   'cast': ['Miles Teller',
#    'Michael B. Jordan',
#    'Kate Mara',
#    'Jamie Bell',
#    'Toby Kebbell'],
#   'director': 'Stephen E. Rivkin',
#   'writer': 'N/A'},
#  {'name': 'Guess Who',
#   'year': '2005',
#   'cast': ['Bernie Mac',
#    'Ashton Kutcher',
#    'Zoe Saldaña',
#    'Judith Scott',
#    'Hal Williams'],
#   'director': 'Kevin Rodney Sullivan',
#   'writer': 'N/A'},
#  {'name': 'Doctor Who',
#   'year': 'None',
#   'cast': ['Paul McGann',
#    'Eric Roberts',
#    'Daphne Ashbrook',
#    'Sylvester McCoy',
#    'Yee Jee Tso'],
#   'director': 'Geoffrey Sax',
#   'writer': 'N/A'},
#  {'name': 'Snowpiercer',
#   'year': '2013',
#   'cast': ['Chris Evans',
#    'Song Kang-ho',
#    'John Hurt',
#    'Tilda Swinton',
#    'Jamie Bell'],
#   'director': 'Bong Joon-ho',
#   'writer': 'N/A'},
#  {'name': 'The Bridge on the River Kwai',
#   'year': '1957',
#   'cast': ['William Holden',
#    'Alec Guinness',
#    'Jack Hawkins',
#    'Sessue Hayakawa',
#    'James Donald'],
#   'director': 'David Lean',
#   'writer': 'N/A'},
#  {'name': 'S',
#   'year': '2012',
#   'cast': ['Mathias Melloul',
#    'Valérie Maës',
#    'Stephan Hersoen',
#    'Pierre Perrier',
#    'Yan Brian'],
#   'director': 'Jean-Marc Barr',
#   'writer': 'Pascal Arnold'},
#  {'name': 'The Expendables',
#   'year': '2010',
#   'cast': ['Sylvester Stallone',
#    'Jason Statham',
#    'Jet Li',
#    'Dolph Lundgren',
#    'Eric Roberts'],
#   'director': 'Sylvester Stallone',
#   'writer': 'N/A'},
#  {'name': 'Once Upon a Time in America',
#   'year': '1984',
#   'cast': ['Robert De Niro',
#    'James Woods',
#    'Elizabeth McGovern',
#    'Treat Williams',
#    'Tuesday Weld'],
#   'director': 'Sergio Leone',
#   'writer': 'N/A'},
#  {'name': 'Flatliners',
#   'year': '2017',
#   'cast': ['Kiefer Sutherland',
#    'Julia Roberts',
#    'Kevin Bacon',
#    'William Baldwin',
#    'Oliver Platt'],
#   'director': 'Joel Schumacher',
#   'writer': 'Peter Filardi'},
#  {'name': 'Heat',
#   'year': '1996',
#   'cast': ['Al Pacino',
#    'Robert De Niro',
#    'Val Kilmer',
#    'Jon Voight',
#    'Tom Sizemore'],
#   'director': 'Michael Mann',
#   'writer': 'N/A'},
#  {'name': 'Changeling',
#   'year': '2008',
#   'cast': ['Angelina Jolie',
#    'John Malkovich',
#    'Jeffrey Donovan',
#    'Michael Kelly',
#    'Colm Feore'],
#   'director': 'Clint Eastwood',
#   'writer': 'J. Michael Straczynski'},
#  {'name': 'Einstein Girl',
#   'year': '2005',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'The Town',
#   'year': '2010',
#   'cast': ['Ben Affleck',
#    'Jeremy Renner',
#    'Rebecca Hall',
#    'Jon Hamm',
#    'Blake Lively'],
#   'director': 'Ben Affleck',
#   'writer': 'N/A'},
#  {'name': "Valentine's Day",
#   'year': '2007',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': '13th',
#   'year': '2016',
#   'cast': ['Jelani Cobb',
#    'Angela Davis',
#    'Henry Louis Gates, Jr.',
#    'Michelle Alexander',
#    'Cory Booker'],
#   'director': 'Ava DuVernay',
#   'writer': 'Ava DuVernay'},
#  {'name': 'Fever',
#   'year': '2016',
#   'cast': ['Rajeev Khandelwal',
#    'Gauahar Khan',
#    'Gemma Atkinson',
#    'Caterina Murino',
#    'Ankita Makwana'],
#   'director': 'Rajeev Jhaveri',
#   'writer': 'Rajeev Jhaveri'},
#  {'name': 'The Bridesmaid',
#   'year': '2004',
#   'cast': ['Benoît Magimel',
#    'Laura Smet',
#    'Michel Duchaussoy',
#    'Aurore Clément',
#    'Bernard Le Coq'],
#   'director': 'Claude Chabrol',
#   'writer': 'N/A'},
#  {'name': 'Crank',
#   'year': '2006',
#   'cast': ['Jason Statham',
#    'Amy Smart',
#    'Jose Pablo Cantillo',
#    'Efren Ramirez',
#    'Dwight Yoakam'],
#   'director': 'Brian Taylor',
#   'writer': 'N/A'},
#  {'name': 'Aladdin',
#   'year': 'None',
#   'cast': ['Will Smith',
#    'Mena Massoud',
#    'Naomi Scott',
#    'Marwan Kenzari',
#    'Navid Negahban'],
#   'director': 'Guy Ritchie',
#   'writer': 'N/A'},
#  {'name': 'The Little Mermaid',
#   'year': '1989',
#   'cast': ['Jodi Benson',
#    'Samuel E. Wright',
#    'Pat Carroll',
#    'Christopher Daniel Barnes',
#    'Kenneth Mars'],
#   'director': 'Ron Clements',
#   'writer': 'Ron Clements'},
#  {'name': 'Four Sisters and a Wedding',
#   'year': '2013',
#   'cast': ['Bea Alonzo',
#    'Toni Gonzaga',
#    'Angel Locsin',
#    'Shaina Magdayao',
#    'Enchong Dee'],
#   'director': 'Cathy Garcia-Sampana',
#   'writer': 'N/A'},
#  {'name': '79 A.D.',
#   'year': 'None',
#   'cast': ['Brad Harris',
#    'Mara Lane',
#    'José Greci',
#    'Jany Clair',
#    'Jacques Berthier'],
#   'director': 'Gianfranco Parolini',
#   'writer': 'Giovanni Simonelli'},
#  {'name': 'Bottle Rocket',
#   'year': '1996',
#   'cast': ['Owen Wilson',
#    'Luke Wilson',
#    'Robert Musgrave',
#    'Lumi Cavazos',
#    'Andrew Wilson'],
#   'director': 'Wes Anderson',
#   'writer': 'N/A'},
#  {'name': 'Love Station',
#   'year': '2016',
#   'cast': ['Babushaan Mohanty',
#    'Elina Samantaray',
#    'Papu Pom Pom',
#    'Mihir Das',
#    'Pushpa Panda'],
#   'director': 'Ashok Pati',
#   'writer': 'N/A'},
#  {'name': 'American Made',
#   'year': '2017',
#   'cast': ['Tom Cruise',
#    'Sarah Wright',
#    'Domhnall Gleeson',
#    'Alejandro Edda',
#    'Jesse Plemons'],
#   'director': 'Doug Liman',
#   'writer': 'Gary Spinelli'},
#  {'name': 'Pokémon 3: The Movie',
#   'year': 'None',
#   'cast': ['Rica Matsumoto',
#    'Ikue Otani',
#    'Yuji Ueda',
#    'Mayumi Izuka',
#    'Megumi Hayashibara'],
#   'director': 'Kunihiko Yuyama',
#   'writer': 'N/A'},
#  {'name': 'Swades',
#   'year': '2004',
#   'cast': ['Shah Rukh Khan',
#    'Gayatri Joshi',
#    'Kishori Balal',
#    'Smith Seth',
#    'Lekh Tandon'],
#   'director': 'Ashutosh Gowariker',
#   'writer': 'Ashutosh Gowariker'},
#  {'name': 'The Road to El Dorado',
#   'year': '2000',
#   'cast': ['Kenneth Branagh',
#    'Kevin Kline',
#    'Rosie Perez',
#    'Armand Assante',
#    'Edward James Olmos'],
#   'director': 'Bibo Bergeron',
#   'writer': 'N/A'},
#  {'name': 'Tequila Sunrise',
#   'year': '1988',
#   'cast': ['Mel Gibson',
#    'Michelle Pfeiffer',
#    'Kurt Russell',
#    'Raúl Juliá',
#    'J.T. Walsh'],
#   'director': 'Robert Towne',
#   'writer': 'N/A'},
#  {'name': 'Where the Money Is',
#   'year': '2000',
#   'cast': ['Paul Newman',
#    'Linda Fiorentino',
#    'Dermot Mulroney',
#    'Susan Barnes',
#    'Anne Pitoniak'],
#   'director': 'Marek Kanievska',
#   'writer': 'N/A'},
#  {'name': 'Scent of a Woman',
#   'year': '1974',
#   'cast': ['Vittorio Gassman',
#    'Alessandro Momo',
#    'Agostina Belli',
#    'Moira Orfei',
#    'Franco Ricci'],
#   'director': 'Dino Risi',
#   'writer': 'N/A'},
#  {'name': 'For Love of the Game',
#   'year': '1999',
#   'cast': ['Kevin Costner',
#    'Kelly Preston',
#    'John C. Reilly',
#    'Jena Malone',
#    'Brian Cox'],
#   'director': 'Sam Raimi',
#   'writer': 'N/A'},
#  {'name': 'The Vanishing',
#   'year': '1988',
#   'cast': ['Bernard-Pierre Donnadieu',
#    'Gene Bervoets',
#    'Johanna ter Steege',
#    'Gwen Eckhaus',
#    'Pierre Forget'],
#   'director': 'George Sluizer',
#   'writer': 'N/A'},
#  {'name': 'Super8',
#   'year': 'None',
#   'cast': 'N/A',
#   'director': 'Rémi Lange',
#   'writer': 'N/A'},
#  {'name': 'Superman: Doomsday',
#   'year': 'None',
#   'cast': ['Adam Baldwin',
#    'Anne Heche',
#    'James Marsters',
#    'John DiMaggio',
#    'Swoosie Kurtz'],
#   'director': 'Lauren Montgomery',
#   'writer': 'N/A'},
#  {'name': 'Taking Lives',
#   'year': '2004',
#   'cast': ['Angelina Jolie',
#    'Ethan Hawke',
#    'Kiefer Sutherland',
#    'Gena Rowlands',
#    'Olivier Martinez'],
#   'director': 'D. J. Caruso',
#   'writer': 'N/A'},
#  {'name': 'Never Say Die',
#   'year': '1939',
#   'cast': ['Martha Raye',
#    'Bob Hope',
#    'Andy Devine',
#    'Alan Mowbray',
#    'Gale Sondergaard'],
#   'director': 'Elliott Nugent',
#   'writer': 'N/A'},
#  {'name': 'The Single Moms Club',
#   'year': '2014',
#   'cast': ['Nia Long',
#    'Wendi McLendon-Covey',
#    'Cocoa Brown',
#    'Zulay Henao',
#    'Amy Smart'],
#   'director': 'Tyler Perry',
#   'writer': 'Tyler Perry'},
#  {'name': 'Thirteen Days',
#   'year': '2000',
#   'cast': ['Kevin Costner',
#    'Bruce Greenwood',
#    'Steven Culp',
#    'Dylan Baker',
#    'Michael Fairman'],
#   'director': 'Roger Donaldson',
#   'writer': 'N/A'},
#  {'name': 'Richie Rich',
#   'year': '1994',
#   'cast': ['Macaulay Culkin',
#    'John Larroquette',
#    'Edward Herrmann',
#    'Christine Ebersole',
#    'Jonathan Hyde'],
#   'director': 'Donald Petrie',
#   'writer': 'N/A'},
#  {'name': 'The Beatles: Eight Days a Week',
#   'year': 'None',
#   'cast': ['Paul McCartney',
#    'Ringo Starr',
#    'John Lennon',
#    'George Harrison',
#    'Larry Kane'],
#   'director': 'Ron Howard',
#   'writer': 'N/A'},
#  {'name': 'Mars',
#   'year': '2004',
#   'cast': ['Natasha Henstridge',
#    'Ice Cube',
#    'Pam Grier',
#    'Jason Statham',
#    'Clea DuVall'],
#   'director': 'John Carpenter',
#   'writer': 'John Carpenter'},
#  {'name': 'Lucy',
#   'year': '2003',
#   'cast': ['Rachel York',
#    'Danny Pino',
#    'Ann Dowd',
#    'Madeline Zima',
#    'LaChanze'],
#   'director': 'Glenn Jordan',
#   'writer': 'T.S. Cook'},
#  {'name': 'Love Shack',
#   'year': '2010',
#   'cast': ['Ida Anderson',
#    'Diora Baird',
#    'Bernadette Birkett',
#    'Christopher Boyer',
#    'Philippe Brenninkmeyer'],
#   'director': 'Michael B. Silver',
#   'writer': 'Michael B. Silver'},
#  {'name': 'Where to Invade Next',
#   'year': '2015',
#   'cast': ['Michael Moore', 'Dr. Pasi Sahlberg', 'Krista Kiuru', 'Jón Gnarr'],
#   'director': 'Michael Moore',
#   'writer': 'Michael Moore'},
#  {'name': 'Forever Strong',
#   'year': '2008',
#   'cast': ['Gary Cole',
#    'Sean Astin',
#    'Neal McDonough',
#    'Sean Faris',
#    'Julie Warner'],
#   'director': 'Ryan Little',
#   'writer': 'David Pliler'},
#  {'name': 'Birdman',
#   'year': '2014',
#   'cast': ['Michael Keaton',
#    'Emma Stone',
#    'Zach Galifianakis',
#    'Edward Norton',
#    'Andrea Riseborough'],
#   'director': 'Alejandro González Iñárritu',
#   'writer': 'Alejandro González Iñárritu'},
#  {'name': 'Horrible Bosses 2',
#   'year': '2014',
#   'cast': ['Jason Bateman',
#    'Jason Sudeikis',
#    'Charlie Day',
#    'Jennifer Aniston',
#    'Kevin Spacey'],
#   'director': 'Sean Anders',
#   'writer': 'N/A'},
#  {'name': 'The Family Stone',
#   'year': '2005',
#   'cast': ['Dermot Mulroney',
#    'Sarah Jessica Parker',
#    'Diane Keaton',
#    'Luke Wilson',
#    'Claire Danes'],
#   'director': 'Thomas Bezucha',
#   'writer': 'Thomas Bezucha'},
#  {'name': 'Tron: Legacy',
#   'year': '2010',
#   'cast': ['Jeff Bridges',
#    'Garrett Hedlund',
#    'Olivia Wilde',
#    'Bruce Boxleitner',
#    'James Frain'],
#   'director': 'Joseph Kosinski',
#   'writer': 'N/A'},
#  {'name': 'Inferno',
#   'year': '2016',
#   'cast': ['Tom Hanks',
#    'Felicity Jones',
#    'Omar Sy',
#    'Irrfan Khan',
#    'Sidse Babett Knudsen'],
#   'director': 'Ron Howard',
#   'writer': 'N/A'},
#  {'name': 'A Home at the End of the World',
# ...
#   'cast': ['Loretta Young',
#    'Jeff Chandler',
#    'Alex Nicol',
#    'Frances Dee',
#    'Alexander Scourby'],
#   'director': 'Joseph Pevney',
#   'writer': 'N/A'},
#  {'name': 'Mansfield Park',
#   'year': '1999',
#   'cast': ["Frances O'Connor",
#    'Lindsay Duncan',
#    'James Purefoy',
#    'Sheila Gish',
#    'Harold Pinter'],
#   'director': 'Patricia Rozema',
#   'writer': 'N/A'},
#  {'name': 'Hauling',
#   'year': '2010',
#   'cast': ['Claudinês Alvarenga'],
#   'director': 'Sean Walsh',
#   'writer': 'N/A'},
#  {'name': 'Fatal Attraction',
#   'year': '1987',
#   'cast': ['Michael Douglas',
#    'Glenn Close',
#    'Anne Archer',
#    'Ellen Hamilton Latzen',
#    'Stuart Pankin'],
#   'director': 'Adrian Lyne',
#   'writer': 'N/A'},
#  {'name': 'Requiem',
#   'year': '1995',
#   'cast': ['Tamlyn Tomita',
#    'Chris Tashima',
#    'Brenda Song',
#    'Binh Nguyen',
#    'Elizabeth Sung'],
#   'director': 'Elizabeth Sung',
#   'writer': 'Peter Tulipan'},
#  {'name': 'Hotel Artemis',
#   'year': '2018',
#   'cast': ['Jodie Foster',
#    'Sterling K. Brown',
#    'Sofia Boutella',
#    'Jeff Goldblum',
#    'Brian Tyree Henry'],
#   'director': 'Drew Pearce',
#   'writer': 'N/A'},
#  {'name': 'Oliver & Company',
#   'year': 'None',
#   'cast': ['Joey Lawrence',
#    'Billy Joel',
#    'Cheech Marin',
#    'Richard Mulligan',
#    'Roscoe Lee Browne'],
#   'director': 'George Scribner',
#   'writer': 'N/A'},
#  {'name': 'Hostage',
#   'year': 'None',
#   'cast': ['Bruce Willis',
#    'Ben Foster',
#    'Jonathan Tucker',
#    'Jimmy Bennett',
#    'Michelle Horn'],
#   'director': 'Florent-Emilio Siri',
#   'writer': 'N/A'},
#  {'name': 'Bowfinger',
#   'year': '1999',
#   'cast': ['Steve Martin',
#    'Eddie Murphy',
#    'Heather Graham',
#    'Christine Baranski',
#    'Jamie Kennedy'],
#   'director': 'Frank Oz',
#   'writer': 'N/A'},
#  {'name': "Lady and the Tramp II: Scamp's Adventure",
#   'year': '2001',
#   'cast': ['Scott Wolf',
#    'Alyssa Milano',
#    'Chazz Palminteri',
#    'Jeff Bennett',
#    'Jodi Benson'],
#   'director': 'Darrell Rooney',
#   'writer': 'N/A'},
#  {'name': 'When the Bough Breaks',
#   'year': '2016',
#   'cast': ['Morris Chestnut',
#    'Regina Hall',
#    'Jaz Sinclair',
#    'Romany Malco',
#    'Michael Kenneth Williams'],
#   'director': 'Jon Cassar',
#   'writer': 'N/A'},
#  {'name': 'The Matador',
#   'year': '2008',
#   'cast': ['David Fandila'],
#   'director': 'Nina Gilden Seavey',
#   'writer': 'N/A'},
#  {'name': 'For the Love of Spock',
#   'year': '2016',
#   'cast': ['Leonard Nimoy',
#    'William Shatner',
#    'George Takei',
#    'J.J. Abrams',
#    'Simon Pegg'],
#   'director': 'Adam Nimoy',
#   'writer': 'Adam Nimoy'},
#  {'name': 'Girls Will Be Girls',
#   'year': '2003',
#   'cast': ['Jack Plotnick',
#    'Miss Coco Peru',
#    'Jeffery Roberson',
#    'Ron Mathews',
#    'Eric Stonestreet'],
#   'director': 'Richard Day',
#   'writer': 'Richard Day'},
#  {'name': "Wes Craven's Chiller",
#   'year': '1985',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Capturing the Friedmans',
#   'year': '2003',
#   'cast': ['Arnold Friedman',
#    'Elaine Friedman',
#    'Jesse Friedman',
#    'David Friedman',
#    'Seth Friedman'],
#   'director': 'Andrew Jarecki',
#   'writer': 'N/A'},
#  {'name': 'The Proposal',
#   'year': '2009',
#   'cast': ['Sandra Bullock',
#    'Ryan Reynolds',
#    'Malin Åkerman',
#    'Craig T. Nelson',
#    'Mary Steenburgen'],
#   'director': 'Anne Fletcher',
#   'writer': 'Pete Chiarelli'},
#  {'name': 'K-9',
#   'year': '1989',
#   'cast': ['Jim Belushi',
#    'Mel Harris',
#    'Kevin Tighe',
#    "Ed O'Neill",
#    'James Handy'],
#   'director': 'Rod Daniel',
#   'writer': 'N/A'},
#  {'name': 'Be Cool',
#   'year': '2005',
#   'cast': ['John Travolta',
#    'Uma Thurman',
#    'Vince Vaughn',
#    'Cedric the Entertainer',
#    'Dwayne Johnson'],
#   'director': 'F. Gary Gray',
#   'writer': 'N/A'},
#  {'name': 'The Swan Princess',
#   'year': '1994',
#   'cast': ['Jack Palance',
#    'Howard McGillin',
#    'Michelle Nicastro',
#    'Liz Callaway',
#    'John Cleese'],
#   'director': 'Richard Rich',
#   'writer': 'N/A'},
#  {'name': 'G.I. Blues',
#   'year': '1960',
#   'cast': ['Elvis Presley',
#    'Juliet Prowse',
#    'Robert Ivers',
#    'James Douglas',
#    'Letícia Román'],
#   'director': 'Norman Taurog',
#   'writer': 'N/A'},
#  {'name': 'Horton Hears a Who!',
#   'year': '2008',
#   'cast': ['Jim Carrey',
#    'Steve Carell',
#    'Carol Burnett',
#    'Will Arnett',
#    'Seth Rogen'],
#   'director': 'Jimmy Hayward',
#   'writer': 'Jeff Siergey'},
#  {'name': 'Attack on Titan',
#   'year': '2015',
#   'cast': ['Haruma Miura',
#    'Kiko Mizuhara',
#    'Kanata Hongo',
#    'Nanami Sakuraba',
#    'Takahiro Miura'],
#   'director': 'Shinji Higuchi',
#   'writer': 'N/A'},
#  {'name': 'Disobedience',
#   'year': '2003',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Zero Effect',
#   'year': '1998',
#   'cast': ['Bill Pullman',
#    'Ben Stiller',
#    "Ryan O'Neal",
#    'Kim Dickens',
#    'Angela Featherstone'],
#   'director': 'Jake Kasdan',
#   'writer': 'Jake Kasdan'},
#  {'name': 'Super 8',
#   'year': '2011',
#   'cast': ['Joel Courtney',
#    'Elle Fanning',
#    'Riley Griffiths',
#    'Kyle Chandler',
#    'Noah Emmerich'],
#   'director': 'J.J. Abrams',
#   'writer': 'J.J. Abrams'},
#  {'name': "Pirates of the Caribbean: At World's End",
#   'year': '2007',
#   'cast': ['Johnny Depp',
#    'Orlando Bloom',
#    'Keira Knightley',
#    'Geoffrey Rush',
#    'Stellan Skarsgård'],
#   'director': 'Gore Verbinski',
#   'writer': 'N/A'},
#  {'name': 'Pacquiao: The Movie',
#   'year': '2006',
#   'cast': ['Jericho Rosales',
#    'Bea Alonzo',
#    'Bayani Agbayani',
#    'Jay Manalo',
#    'Glaiza de Castro'],
#   'director': 'Joel Lamangan',
#   'writer': 'Roy Iglesias'},
#  {'name': 'City of Men',
#   'year': '2007',
#   'cast': ['Douglas Silva',
#    'Darlan Cunha',
#    'Jonathan Haagensen',
#    'Rodrigo dos Santos',
#    'Fábio Lago'],
#   'director': 'Paulo Morelli',
#   'writer': 'N/A'},
#  {'name': 'Man of Steel',
#   'year': '2013',
#   'cast': ['Henry Cavill',
#    'Amy Adams',
#    'Michael Shannon',
#    'Diane Lane',
#    'Russell Crowe'],
#   'director': 'Zack Snyder',
#   'writer': 'N/A'},
#  {'name': 'Return of the Jedi',
#   'year': '1983',
#   'cast': ['Mark Hamill',
#    'Harrison Ford',
#    'Carrie Fisher',
#    'Billy Dee Williams',
#    'Anthony Daniels'],
#   'director': 'Richard Marquand',
#   'writer': 'N/A'},
#  {'name': 'Guys and Dolls',
#   'year': '1955',
#   'cast': ['Marlon Brando',
#    'Jean Simmons',
#    'Frank Sinatra',
#    'Vivian Blaine',
#    'Robert Keith'],
#   'director': 'Joseph L. Mankiewicz',
#   'writer': 'N/A'},
#  {'name': 'An American in Madras',
#   'year': '2013',
#   'cast': ['M. K. Thyagaraja Bhagavathar',
#    'Ellis R. Dungan',
#    'P. K. Nair',
#    'Radha Viswanathan',
#    'M. S. Subbulakshmi'],
#   'director': 'Karan Bali',
#   'writer': 'Teesha Elizabeth Cherian'},
#  {'name': 'Insidious',
#   'year': '2011',
#   'cast': ['Patrick Wilson',
#    'Rose Byrne',
#    'Lin Shaye',
#    'Ty Simpkins',
#    'Barbara Hershey'],
#   'director': 'James Wan',
#   'writer': 'Leigh Whannell'},
#  {'name': 'Rabbits',
#   'year': '2002',
#   'cast': ['Scott Coffey', 'Rebekah Del Rio', 'Laura Harring', 'Naomi Watts'],
#   'director': 'David Lynch',
#   'writer': 'N/A'},
#  {'name': 'Silver Streak',
#   'year': '1976',
#   'cast': ['Gene Wilder',
#    'Jill Clayburgh',
#    'Richard Pryor',
#    'Patrick McGoohan',
#    'Ned Beatty'],
#   'director': 'Arthur Hiller',
#   'writer': 'Colin Higgins'},
#  {'name': 'Riddick',
#   'year': '2013',
#   'cast': ['Vin Diesel',
#    'Matt Nable',
#    'Katee Sackhoff',
#    'Jordi Mollà',
#    'Dave Bautista'],
#   'director': 'David Twohy',
#   'writer': 'David Twohy'},
#  {'name': 'To Kill a Mockingbird',
#   'year': '1962',
#   'cast': ['Gregory Peck',
#    'Mary Badham',
#    'Phillip Alford',
#    'John Megna',
#    'Frank Overton'],
#   'director': 'Robert Mulligan',
#   'writer': 'N/A'},
#  {'name': 'Trouble with the Curve',
#   'year': '2012',
#   'cast': ['Clint Eastwood',
#    'Amy Adams',
#    'Justin Timberlake',
#    'Matthew Lillard',
#    'Jack Gilpin'],
#   'director': 'Robert Lorenz',
#   'writer': 'N/A'},
#  {'name': 'A Night in Casablanca',
#   'year': '1946',
#   'cast': ['Groucho Marx',
#    'Harpo Marx',
#    'Chico Marx',
#    'Charles Drake',
#    'Lois Collier'],
#   'director': 'Archie Mayo',
#   'writer': 'Joseph Fields'},
#  {'name': 'Empire of the Ants',
#   'year': '1977',
#   'cast': ['Joan Collins',
#    'Robert Lansing',
#    'John David Carson',
#    'Albert Salmi',
#    'Jacqueline Scott'],
#   'director': 'Bert I. Gordon',
#   'writer': 'N/A'},
#  {'name': 'Batman',
#   'year': '1989',
#   'cast': ['Michael Keaton',
#    'Jack Nicholson',
#    'Kim Basinger',
#    'Michael Gough',
#    'Jerry Hall'],
#   'director': 'Tim Burton',
#   'writer': 'N/A'},
#  {'name': 'Bombing the Nazis',
#   'year': '1943',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Cosmos',
#   'year': '2010',
#   'cast': ['Yao Chen', 'Guo Xiaodong', 'Zhu Yuchen', 'Annie Wu'],
#   'director': 'Po Yan',
#   'writer': 'Cui Siwei'},
#  {'name': '2012',
#   'year': '2009',
#   'cast': ['John Cusack',
#    'Chiwetel Ejiofor',
#    'Amanda Peet',
#    'Oliver Platt',
#    'Thandiwe Newton'],
#   'director': 'Roland Emmerich',
#   'writer': 'Harald Kloser'},
#  {'name': 'Sleeping Beauty',
#   'year': '1995',
#   'cast': ['Mary Costa',
#    'Bill Shirley',
#    'Eleanor Audley',
#    'Verna Felton',
#    'Barbara Luddy'],
#   'director': 'Clyde Geronimi',
#   'writer': 'N/A'},
#  {'name': 'Going Clear',
#   'year': '2015',
#   'cast': ['Paul Haggis',
#    'Jason Beghe',
#    'Alex Gibney',
#    'Lawrence Wright',
#    'Sherry Stringfield'],
#   'director': 'Alex Gibney',
#   'writer': 'Alex Gibney'},
#  {'name': 'Mystic Pizza',
#   'year': '1988',
#   'cast': ['Annabeth Gish',
#    'Julia Roberts',
#    'Lili Taylor',
#    "Vincent D'Onofrio",
#    'William R. Moses'],
#   'director': 'Donald Petrie',
#   'writer': 'N/A'},
#  {'name': 'The Transformers: The Movie',
#   'year': 'None',
#   'cast': ['Judd Nelson',
#    'Peter Cullen',
#    'Frank Welker',
#    'Leonard Nimoy',
#    'Orson Welles'],
#   'director': 'Nelson Shin',
#   'writer': 'Ron Friedman'},
#  {'name': "Good Luck Charlie, It's Christmas!",
#   'year': '2011',
#   'cast': ['Bridgit Mendler',
#    'Leigh-Allyn Baker',
#    'Jason Dolley',
#    'Eric Allan Kramer',
#    'Bradley Steven Perry'],
#   'director': 'Arlene Sanford',
#   'writer': 'Geoff Rodkey'},
#  {'name': "The 'Burbs",
#   'year': '1989',
#   'cast': ['Tom Hanks',
#    'Bruce Dern',
#    'Carrie Fisher',
#    'Rick Ducommun',
#    'Wendy Schaal'],
#   'director': 'Joe Dante',
#   'writer': 'Dana Olsen'},
#  {'name': 'The Music Man',
#   'year': '1962',
#   'cast': ['Robert Preston',
#    'Shirley Jones',
#    'Buddy Hackett',
#    'Ron Howard',
#    'Hermione Gingold'],
#   'director': 'Morton DaCosta',
#   'writer': 'N/A'},
#  {'name': 'Deathtrap',
#   'year': '1982',
#   'cast': ['Michael Caine',
#    'Christopher Reeve',
#    'Dyan Cannon',
#    'Irene Worth',
#    'Henry Jones'],
#   'director': 'Sidney Lumet',
#   'writer': 'Ira Levin'},
#  {'name': 'Absolute Beginners',
#   'year': '1986',
#   'cast': ["Eddie O'Connell",
#    'Patsy Kensit',
#    'David Bowie',
#    'James Fox',
#    'Ray Davies'],
#   'director': 'Julien Temple',
#   'writer': 'N/A'},
#  {'name': 'The Cat Returns',
#   'year': 'None',
#   'cast': ['Chizuru Ikewaki',
#    'Yoshihiko Hakamada',
#    'Aki Maeda',
#    'Takayuki Yamada',
#    'Hitomi Sato'],
#   'director': 'Hiroyuki Morita',
#   'writer': 'N/A'},
#  {'name': 'Victoria and Abdul',
#   'year': 'None',
#   'cast': ['Judi Dench',
#    'Ali Fazal',
#    'Tim Pigott-Smith',
#    'Eddie Izzard',
#    'Adeel Akhtar'],
#   'director': 'Stephen Frears',
#   'writer': 'N/A'},
#  {'name': 'A Perfect Getaway',
#   'year': '2009',
#   'cast': ['Steve Zahn',
#    'Milla Jovovich',
#    'Timothy Olyphant',
#    'Kiele Sanchez',
#    'Chris Hemsworth'],
#   'director': 'David Twohy',
#   'writer': 'N/A'},
#  {'name': 'The Wicker Man',
#   'year': '2006',
#   'cast': ['Nicolas Cage',
#    'Ellen Burstyn',
#    'Kate Beahan',
#    'Frances Conroy',
#    'Molly Parker'],
#   'director': 'Neil LaBute',
#   'writer': 'N/A'},
#  {'name': 'Dead Before Dawn',
#   'year': '2012',
#   'cast': ['Devon Bostick',
#    'Martha MacIsaac',
#    'Christopher Lloyd',
#    'Brandon Jay McLaren',
#    'Brittany Allen'],
#   'director': 'April Mullen',
#   'writer': 'Tim Doiron'},
#  {'name': 'The Last Starfighter',
#   'year': '1984',
#   'cast': ['Lance Guest',
#    'Robert Preston',
#    'Chris Hebert',
#    'Kay E. Kuter',
#    'Dan Mason'],
#   'director': 'Nick Castle',
#   'writer': 'N/A'},
#  {'name': 'Out of the Furnace',
#   'year': '2013',
#   'cast': ['Christian Bale',
#    'Zoe Saldaña',
#    'Woody Harrelson',
#    'Sam Shepard',
#    'Willem Dafoe'],
#   'director': 'Scott Cooper',
#   'writer': 'N/A'},
#  {'name': 'Napping Princess',
#   'year': '2017',
#   'cast': ['Mitsuki Takahata',
#    'Yosuke Eguchi',
#    'Shinnosuke Mitsushima',
#    'Rie Kugimiya',
#    'Tomoya Maeno'],
#   'director': 'Kenji Kamiyama',
#   'writer': 'N/A'},
#  {'name': 'American Psycho',
#   'year': '2000',
#   'cast': ['Christian Bale',
#    'Willem Dafoe',
#    'Jared Leto',
#    'Josh Lucas',
#    'Samantha Mathis'],
#   'director': 'Mary Harron',
#   'writer': 'N/A'},
#  {'name': 'Pitch Perfect 3',
#   'year': '2017',
#   'cast': ['Anna Kendrick',
#    'Rebel Wilson',
#    'Brittany Snow',
#    'Hailee Steinfeld',
#    'Elizabeth Banks'],
#   'director': 'Trish Sie',
#   'writer': 'Mike White'},
#  {'name': 'Vantage Point',
#   'year': '2008',
#   'cast': ['Dennis Quaid',
#    'Matthew Fox',
#    'Forest Whitaker',
#    'Sigourney Weaver',
#    'William Hurt'],
#   'director': 'Pete Travis',
#   'writer': 'Barry Levy'},
#  {'name': 'Terms of Endearment',
#   'year': '1983',
#   'cast': ['Shirley MacLaine',
#    'Debra Winger',
#    'Jack Nicholson',
#    'Danny DeVito',
#    'Jeff Daniels'],
#   'director': 'James L. Brooks',
#   'writer': 'N/A'},
#  {'name': "Michael Lucas' La Dolce Vita",
#   'year': '2006',
#   'cast': 'N/A',
#   'director': 'N/A',
#   'writer': 'N/A'},
#  {'name': 'Soul Plane',
#   'year': '2004',
#   'cast': ['Kevin Hart', 'Tom Arnold', 'Method Man', 'Snoop Dogg', 'Godfrey'],
#   'director': 'Jessy Terrero',
#   'writer': 'N/A'},
#  {'name': 'The Outlaws',
#   'year': '1950',
#   'cast': ['Vittorio Gassman',
#    'Ermanno Randi',
#    'Maria Grazia Francia',
#    'Umberto Spadaro',
#    "Rocco D'Assunta"],
#   'director': 'Aldo Vergano',
#   'writer': 'N/A'},
#  {'name': 'The Hunted',
#   'year': '2013',
#   'cast': ['Josh Stewart',
#    'Skipp Sudduth',
#    'Katherine Von Till',
#    'Nikki DeLoach',
#    'Ronnie Gene Blevins'],
#   'director': 'Josh Stewart',
#   'writer': 'Josh Stewart'},
#  {'name': 'Boxing Helena',
#   'year': '1993',
#   'cast': ['Julian Sands',
#    'Sherilyn Fenn',
#    'Bill Paxton',
#    'Art Garfunkel',
#    'Betsy Clark'],
#   'director': 'Jennifer Chambers Lynch',
#   'writer': 'N/A'},
#  {'name': 'Halloween',
#   'year': '1978',
#   'cast': ['Donald Pleasence',
#    'Jamie Lee Curtis',
#    'P.J. Soles',
#    'Nancy Kyes',
#    'Charles Cyphers'],
#   'director': 'John Carpenter',
#   'writer': 'N/A'},
#  {'name': 'The Da Vinci Code',
#   'year': '2006',
#   'cast': ['Tom Hanks',
#    'Audrey Tautou',
#    'Ian McKellen',
#    'Jean Reno',
#    'Paul Bettany'],
#   'director': 'Ron Howard',
#   'writer': 'N/A'},
#  {'name': "The Slammin' Salmon",
#   'year': '2009',
#   'cast': ['Michael Clarke Duncan',
#    'Jay Chandrasekhar',
#    'Kevin Heffernan',
#    'Steve Lemme',
#    'Erik Stolhanske'],
#   'director': 'Kevin Heffernan',
#   'writer': 'Jay Chandrasekhar'},
#  {'name': 'Sabotage',
#   'year': '2014',
#   'cast': ['Arnold Schwarzenegger',
#    'Sam Worthington',
#    'Olivia Williams',
#    'Mireille Enos',
#    'Joe Manganiello'],
#   'director': 'David Ayer',
#   'writer': 'David Ayer'},
#  {'name': 'Star Trek II: The Wrath of Khan',
#   'year': '1982',
#   'cast': ['William Shatner',
#    'Leonard Nimoy',
#    'DeForest Kelley',
#    'James Doohan',
#    'George Takei'],
#   'director': 'Nicholas Meyer',
#   'writer': 'N/A'},
#  {'name': 'The Constant Gardener',
#   'year': '2005',
#   'cast': ['Ralph Fiennes',
#    'Rachel Weisz',
#    'Danny Huston',
#    'Bill Nighy',
#    'Pete Postlethwaite'],
#   'director': 'Fernando Meirelles',
#   'writer': 'N/A'},
#  {'name': 'Date Night',
#   'year': '2010',
#   'cast': ['Steve Carell',
#    'Tina Fey',
#    'Mark Wahlberg',
#    'Taraji P. Henson',
#    'Jimmi Simpson'],
#   'director': 'Shawn Levy',
#   'writer': 'Josh Klausner'},
#  {'name': 'A Very Long Engagement',
#   'year': '2004',
#   'cast': ['Audrey Tautou',
#    'Gaspard Ulliel',
#    'Dominique Pinon',
#    'Chantal Neuwirth',
#    'André Dussollier'],
#   'director': 'Jean-Pierre Jeunet',
#   'writer': 'N/A'},
#  ...]

# %%
# Create a set of standardized names
standard_names_set = set()
for name in final_names:
    standard_names_set.add(name.lower())  # Convert to lowercase for case-insensitive comparison

# Check cast, director, and writer fields
for movie in relations_people_data_tmdb:
    movie['cast'] = [name for name in movie['cast'] if any(standard_name in name.lower() for standard_name in standard_names_set)]
    
    # Check if 'director' is a single string or a list
    if isinstance(movie['director'], str):
        movie['director'] = [name for name in [movie['director']] if any(standard_name in name.lower() for standard_name in standard_names_set)]
    else:
        movie['director'] = [name for name in movie['director'] if any(standard_name in name.lower() for standard_name in standard_names_set)]
    
    # Check if 'writer' is a single string or a list
    if isinstance(movie['writer'], str):
        movie['writer'] = [name for name in [movie['writer']] if any(standard_name in name.lower() for standard_name in standard_names_set)]
    else:
        movie['writer'] = [name for name in movie['writer'] if any(standard_name in name.lower() for standard_name in standard_names_set)]

# Print or use the modified data as needed
print(relations_people_data_tmdb)
# Out:
# [{'name': "Charlotte's Web", 'year': '2006', 'cast': ['Dakota Fanning', 'Julia Roberts', 'Steve Buscemi', 'Oprah Winfrey'], 'director': [], 'writer': []}, {'name': 'Everything You Always Wanted to Know About Sex*', 'year': '1972', 'cast': ['Woody Allen'], 'director': ['Woody Allen'], 'writer': []}, {'name': 'Rock-a-Doodle', 'year': '1991', 'cast': ['Glen Campbell'], 'director': ['Don Bluth'], 'writer': ['Don Bluth']}, {'name': 'Too Late', 'year': 'None', 'cast': [], 'director': [], 'writer': []}, {'name': 'Law Abiding Citizen', 'year': '2009', 'cast': ['Jamie Foxx', 'Gerard Butler'], 'director': [], 'writer': []}, {'name': 'The Black Mask', 'year': '1935', 'cast': [], 'director': [], 'writer': []}, {'name': 'Club Dread', 'year': '2004', 'cast': [], 'director': [], 'writer': []}, {'name': 'Moana', 'year': 'None', 'cast': ['Dwayne Johnson'], 'director': [], 'writer': []}, {'name': 'Signs', 'year': '2002', 'cast': ['Mel Gibson', 'Joaquin Phoenix', 'Abigail Breslin'], 'director': ['M. Night Shyamalan'], 'writer': ['M. Night Shyamalan']}, {'name': 'Beyond the Valley of the Dolls', 'year': '1970', 'cast': [], 'director': [], 'writer': []}, {'name': 'Beastly', 'year': '2011', 'cast': ['Neil Patrick Harris'], 'director': [], 'writer': []}, {'name': 'Victoria', 'year': '2015', 'cast': [], 'director': [], 'writer': []}, {'name': 'The Duel', 'year': '2016', 'cast': ['Woody Harrelson'], 'director': [], 'writer': []}, {'name': 'American Ninja 2: The Confrontation', 'year': '1987', 'cast': [], 'director': [], 'writer': []}, {'name': 'Earth to Echo', 'year': '2014', 'cast': [], 'director': [], 'writer': []}, {'name': 'Amélie', 'year': '2001', 'cast': [], 'director': [], 'writer': []}, {'name': 'Born Free', 'year': '1966', 'cast': [], 'director': [], 'writer': []}, {'name': 'Son in Law', 'year': '1993', 'cast': ['Pauly Shore'], 'director': [], 'writer': []}, {'name': 'Killer Klowns from Outer Space', 'year': '1988', 'cast': [], 'director': [], 'writer': []}, {'name': 'Holiday Inn', 'year': '1942', 'cast': ['Bing Crosby', 'Fred Astaire'], 'director': [], 'writer': []}, {'name': 'Dracula Untold', 'year': '2014', 'cast': ['Art Parkinson'], 'director': [], 'writer': []}, {'name': 'Tom and Jerry: The Fast and the Furry', 'year': 'None', 'cast': [], 'director': [], 'writer': []}, {'name': 'Shanghai Knights', 'year': '2003', 'cast': ['Jackie Chan', 'Owen Wilson', 'Donnie Yen'], 'director': [], 'writer': []}, {'name': 'Dirty Dancing: Havana Nights', 'year': 'None', 'cast': [], 'director': [], 'writer': []}, {'name': 'Ghost in the Shell: Stand Alone Complex - Solid State Society', 'year': '2006', 'cast': [], 'director': [], 'writer': []}, {'name': 'Chasing Mavericks', 'year': '2012', 'cast': ['Gerard Butler'], 'director': [], 'writer': []}, {'name': "Sophie's Choice", 'year': '1982', 'cast': ['Meryl Streep', 'Kevin Kline'], 'director': [], 'writer': []}, {'name': 'Secondhand Lions', 'year': '2003', 'cast': ['Michael Caine', 'Haley Joel Osment'], 'director': [], 'writer': []}, {'name': 'Rio 2', 'year': '2014', 'cast': ['Jesse Eisenberg', 'Anne Hathaway', 'Jamie Foxx', 'Leslie Mann'], 'director': [], 'writer': []}, {'name': 'Places in the Heart', 'year': '1984', 'cast': ['Sally Field', 'Danny Glover', 'Ed Harris'], 'director': [], 'writer': []}, {'name': 'The Incident', 'year': '2011', 'cast': [], 'director': [], 'writer': []}, {'name': 'Police Story 2', 'year': '2007', 'cast': [], 'director': [], 'writer': []}, {'name': 'Not Fade Away', 'year': '2012', 'cast': [], 'director': ['David Chase'], 'writer': ['David Chase']}, {'name': 'In the Mood for Love', 'year': '2000', 'cast': [], 'director': [], 'writer': []}, {'name': 'Kaizoku Sentai Gokaiger the Movie: The Flying Ghost Ship', 'year': '2011', 'cast': [], 'director': [], 'writer': []}, {'name': 'To Live and Die in L.A.', 'year': '1985', 'cast': ['Willem Dafoe'], 'director': [], 'writer': []}, {'name': 'The Young Guns', 'year': '1956', 'cast': [], 'director': [], 'writer': []}, {'name': 'Secret Window', ...

# %%
unique_names = set()

for movie in relations_people_data_tmdb:
    unique_names.update(movie['cast'])
    unique_names.update(movie['director'])
    unique_names.update(movie['writer'])

# Remove empty strings from the set
unique_names.discard('')

print(unique_names)
# Out:
# {'Julianne Hough', 'Barbra Streisand', 'Woody Allen', 'Ron Livingston', 'Diane Lane', 'Nicole Kidman', 'Taylor Schilling', 'James Cameron', 'Taylor Kitsch', 'Tim Robbins', 'Laura Linney', 'Brooke Shields', 'Andy Samberg', 'Minnie Driver', 'Goldie Hawn', 'Molly Ringwald', 'Billy Wilder', 'Emile Hirsch', 'Rebel Wilson', 'Cameron Crowe', 'Judd Apatow', 'Scarlett Johansson', 'Mark Wahlberg', 'Tom Arnold', 'Milla Jovovich', 'Denzel Washington', 'Sean Bean', 'Robert Mitchum', 'Byron Howard', 'Paula Patton', 'Patrick Stewart', 'Priscilla Lawson', 'Tommy Lee Jones', 'Timothy Dalton', 'Martin Lawrence', 'Jake Gyllenhaal', 'Vince Vaughn', 'Jude Law', 'Matt Smith', 'Gary Farmer', 'Chris Rock', 'Billy Howle', 'Sean Penn', 'Kevin Hart', 'Christina Hendricks', 'Kim Soo-ro', 'Nick Swardson', 'Donald Glover', 'Kevin Spacey', 'Sandra Bullock', 'Shane West', 'Lee Pace', 'Winston Churchill', 'Bette Davis', 'Alec Baldwin', 'Forest Whitaker', 'Amy Poehler', 'John Carpenter', 'Kim Novak', 'John Candy', 'Debra Messing', 'Lucas Black', 'Elizabeth Olsen', 'Regina Hall', 'William Wyler', 'Justin Bartha', 'Ally Sheedy', 'Ray Romano', 'Morten Tyldum', 'Jeremy Renner', 'Wes Anderson', 'Richard Dawson', 'Arnold Schwarzenegger', 'Billy Murray', 'Monica Potter', 'Cate Blanchett', 'Stanley Kubrick', 'Mike Myers', 'Armie Hammer', 'Miles Teller', 'Linda Hamilton', 'Lisa Kudrow', 'Natalie Portman', 'Helen Mirren', 'Michelle Monaghan', 'Ray Liotta', 'Kurt Russell', 'Danny Masterson', 'Danny Boyle', 'Martin Scorsese', 'John Grisham', 'Aaron Swartz', 'Julie Andrews', 'Barkhad Abdi', 'Sally Hawkins', 'Ken Foree', 'Ang Lee', 'Shemar Moore', 'Tom Hardy', 'Stanley Weber', 'Guy Ritchie', 'Kathleen Turner', 'James Mangold', 'Tom Hiddleston', 'Grace Kelly', 'Brad Renfro', 'David Chase', 'Dick Van Dyke', 'Sigourney Weaver', 'Jim Sturgess', 'Asa Butterfield', 'Jon Heder', 'Zak Bagans', 'Alan Arkin', 'Kristen Wiig', 'Tony Jaa', 'Josh Brolin', 'Alfred Hitchcock', 'Zach Braff', 'Keanu Reeves', 'Rooney Mara', 'Perry Caravello', 'Stanley Tucci', 'Matthew Broderick', 'Josh Gad', 'Clint Eastwood', 'Rian Johnson', 'Nathan Lane', 'Bradley Cooper', 'John Woo', 'Demi Lovato', 'Dolly Parton', 'Robert Pattinson', 'Justin Timberlake', 'Paz Vega', 'John Robinson', 'Adam Scott', 'Neil Gaiman', 'Richard Madden', 'Colin Farrell', 'Matt Damon', 'Clive Owen', 'Reese Witherspoon', 'Kiefer Sutherland', 'James Mason', 'Billy Zane', 'Rosamund Pike', 'Ethel Merman', 'Brad Ingelsby', 'Ben Affleck', 'Antonio Banderas', 'Chris Farley', 'Liza Weil', 'Joseph Gordon-Levitt', 'George Clooney', 'Judd Nelson', 'Michelle Rodriguez', 'Pierce Brosnan', 'Ingrid Bergman', 'Edward Norton', 'Sam Shepard', 'Jared Leto', 'Laurence Fishburne', 'Emma Roberts', 'Artie Lange', 'Sam Jaeger', 'Winona Ryder', 'Mel Gibson', 'Diane Keaton', 'Albert Brooks', 'Peter Dinklage', 'Justin Long', 'Barry Keoghan', 'Simon Pegg', 'Kate Winslet', 'Mia Wasikowska', 'Sam Neill', 'Hiromasa Yonebayashi', 'Whoopi Goldberg', 'Walt Disney', 'Jerry Lewis', 'Spencer Tracy', 'James Brown', 'Steve Buscemi', 'Carl Weathers', 'Will Smith', 'Halle Berry', 'Sam Rockwell', 'Jackie Chan', 'Kathy Bates', 'Christopher Mintz-Plasse', 'Sharon Stone', 'Burt Reynolds', 'Catherine Deneuve', 'George Carlin', 'Eli Roth', 'Richard Kelly', 'Jonah Hill', 'Bryan Cranston', 'Jason Bateman', 'Jason Statham', 'Taylor Lautner', 'Holly Hunter', 'Owen Wilson', 'Robert Ryan', 'Mike Flanagan', 'Tom Brady', 'Emilia Clarke', 'Judge Reinhold', 'Katherine Heigl', 'Damon Wayans', 'Lim Soo-jung', 'Bette Midler', 'Samuel West', 'Channing Tatum', 'Whitney Houston', 'Edith Ewing Bouvier Beale', 'Roman Polanski', 'Julie Brown', 'Jenna Fischer', 'Anupam Kher', 'John Cassavetes', 'Kevin James', 'Danny Glover', 'Norman Reedus', 'Glen Campbell', 'Sean Connery', 'Maika Monroe', 'Adam Sandler', 'Don Ameche', 'Matthew McConaughey', 'Howie Mandel', 'Eric Roberts', 'Bill Hader', 'Gerard Butler', 'Danny Huston', 'Milton Berle', 'Michael Bay', 'Neil Patrick Harris', 'Greg Kinnear', 'Nick Frost ...

# %%
print(unique_names)
# Out:
# {'Julianne Hough', 'Barbra Streisand', 'Woody Allen', 'Ron Livingston', 'Diane Lane', 'Nicole Kidman', 'Taylor Schilling', 'James Cameron', 'Taylor Kitsch', 'Tim Robbins', 'Laura Linney', 'Brooke Shields', 'Andy Samberg', 'Minnie Driver', 'Goldie Hawn', 'Molly Ringwald', 'Billy Wilder', 'Emile Hirsch', 'Rebel Wilson', 'Cameron Crowe', 'Judd Apatow', 'Scarlett Johansson', 'Mark Wahlberg', 'Tom Arnold', 'Milla Jovovich', 'Denzel Washington', 'Sean Bean', 'Robert Mitchum', 'Byron Howard', 'Paula Patton', 'Patrick Stewart', 'Priscilla Lawson', 'Tommy Lee Jones', 'Timothy Dalton', 'Martin Lawrence', 'Jake Gyllenhaal', 'Vince Vaughn', 'Jude Law', 'Matt Smith', 'Gary Farmer', 'Chris Rock', 'Billy Howle', 'Sean Penn', 'Kevin Hart', 'Christina Hendricks', 'Kim Soo-ro', 'Nick Swardson', 'Donald Glover', 'Kevin Spacey', 'Sandra Bullock', 'Shane West', 'Lee Pace', 'Winston Churchill', 'Bette Davis', 'Alec Baldwin', 'Forest Whitaker', 'Amy Poehler', 'John Carpenter', 'Kim Novak', 'John Candy', 'Debra Messing', 'Lucas Black', 'Elizabeth Olsen', 'Regina Hall', 'William Wyler', 'Justin Bartha', 'Ally Sheedy', 'Ray Romano', 'Morten Tyldum', 'Jeremy Renner', 'Wes Anderson', 'Richard Dawson', 'Arnold Schwarzenegger', 'Billy Murray', 'Monica Potter', 'Cate Blanchett', 'Stanley Kubrick', 'Mike Myers', 'Armie Hammer', 'Miles Teller', 'Linda Hamilton', 'Lisa Kudrow', 'Natalie Portman', 'Helen Mirren', 'Michelle Monaghan', 'Ray Liotta', 'Kurt Russell', 'Danny Masterson', 'Danny Boyle', 'Martin Scorsese', 'John Grisham', 'Aaron Swartz', 'Julie Andrews', 'Barkhad Abdi', 'Sally Hawkins', 'Ken Foree', 'Ang Lee', 'Shemar Moore', 'Tom Hardy', 'Stanley Weber', 'Guy Ritchie', 'Kathleen Turner', 'James Mangold', 'Tom Hiddleston', 'Grace Kelly', 'Brad Renfro', 'David Chase', 'Dick Van Dyke', 'Sigourney Weaver', 'Jim Sturgess', 'Asa Butterfield', 'Jon Heder', 'Zak Bagans', 'Alan Arkin', 'Kristen Wiig', 'Tony Jaa', 'Josh Brolin', 'Alfred Hitchcock', 'Zach Braff', 'Keanu Reeves', 'Rooney Mara', 'Perry Caravello', 'Stanley Tucci', 'Matthew Broderick', 'Josh Gad', 'Clint Eastwood', 'Rian Johnson', 'Nathan Lane', 'Bradley Cooper', 'John Woo', 'Demi Lovato', 'Dolly Parton', 'Robert Pattinson', 'Justin Timberlake', 'Paz Vega', 'John Robinson', 'Adam Scott', 'Neil Gaiman', 'Richard Madden', 'Colin Farrell', 'Matt Damon', 'Clive Owen', 'Reese Witherspoon', 'Kiefer Sutherland', 'James Mason', 'Billy Zane', 'Rosamund Pike', 'Ethel Merman', 'Brad Ingelsby', 'Ben Affleck', 'Antonio Banderas', 'Chris Farley', 'Liza Weil', 'Joseph Gordon-Levitt', 'George Clooney', 'Judd Nelson', 'Michelle Rodriguez', 'Pierce Brosnan', 'Ingrid Bergman', 'Edward Norton', 'Sam Shepard', 'Jared Leto', 'Laurence Fishburne', 'Emma Roberts', 'Artie Lange', 'Sam Jaeger', 'Winona Ryder', 'Mel Gibson', 'Diane Keaton', 'Albert Brooks', 'Peter Dinklage', 'Justin Long', 'Barry Keoghan', 'Simon Pegg', 'Kate Winslet', 'Mia Wasikowska', 'Sam Neill', 'Hiromasa Yonebayashi', 'Whoopi Goldberg', 'Walt Disney', 'Jerry Lewis', 'Spencer Tracy', 'James Brown', 'Steve Buscemi', 'Carl Weathers', 'Will Smith', 'Halle Berry', 'Sam Rockwell', 'Jackie Chan', 'Kathy Bates', 'Christopher Mintz-Plasse', 'Sharon Stone', 'Burt Reynolds', 'Catherine Deneuve', 'George Carlin', 'Eli Roth', 'Richard Kelly', 'Jonah Hill', 'Bryan Cranston', 'Jason Bateman', 'Jason Statham', 'Taylor Lautner', 'Holly Hunter', 'Owen Wilson', 'Robert Ryan', 'Mike Flanagan', 'Tom Brady', 'Emilia Clarke', 'Judge Reinhold', 'Katherine Heigl', 'Damon Wayans', 'Lim Soo-jung', 'Bette Midler', 'Samuel West', 'Channing Tatum', 'Whitney Houston', 'Edith Ewing Bouvier Beale', 'Roman Polanski', 'Julie Brown', 'Jenna Fischer', 'Anupam Kher', 'John Cassavetes', 'Kevin James', 'Danny Glover', 'Norman Reedus', 'Glen Campbell', 'Sean Connery', 'Maika Monroe', 'Adam Sandler', 'Don Ameche', 'Matthew McConaughey', 'Howie Mandel', 'Eric Roberts', 'Bill Hader', 'Gerard Butler', 'Danny Huston', 'Milton Berle', 'Michael Bay', 'Neil Patrick Harris', 'Greg Kinnear', 'Nick Frost ...

# %%
unique_people_list = list(unique_names)

# %% [markdown]
# Unique Years

# %%
unique_years = set()

for year in relations_people_data_tmdb:
    unique_years.add(year['year'])

# Remove empty strings from the set
unique_years.discard('')
unique_years.discard('None')

print(unique_years)
# Out:
# {'1932', '1916', '1968', '1920', '1915', '1987', '2014', '1988', '1967', '1981', '1911', '1971', '1996', '1929', '2016', '1993', '2012', '1927', '2009', '2019', '2010', '1977', '1948', '1947', '1958', '1978', '1952', '2015', '2003', '1931', '1910', '1970', '2008', '1936', '1955', '1992', '1990', '1939', '1950', '1934', '1951', '1912', '1933', '1902', '1938', '1979', '1989', '1937', '1991', '1964', '1945', '1930', '1976', '1984', '1980', '1974', '1921', '1935', '2011', '1972', '1956', '1999', '1946', '2004', '1975', '2001', '1940', '1941', '2002', '2006', '2018', '2000', '1994', '1959', '2013', '1969', '1986', '1925', '1963', '1961', '1913', '1957', '1919', '1998', '1966', '1960', '2017', '1928', '2007', '2005', '1942', '1926', '1954', '1924', '1982', '1983', '1953', '1944', '1965', '1973', '1949', '1985', '1923', '1922', '1943', '1962', '1997', '1995', '1914'}

# %% [markdown]
# ### Genres

# %%
# Function to read a JSONL file and return a list of dictionaries
relations_data = []

def read_jsonl(file_path, encoding='utf-8'):
    with open(file_path, 'r', encoding=encoding) as file:
        for line in file:
            relations_data.append(json.loads(line))
    return relations_data

read_jsonl("./bin/generated/movies_with_year_genre.jsonl")
# Out:
# [{'name': "Charlotte's Web",
#   'genres': ['Comedy', 'Family', 'Fantasy'],
#   'year': '2006'},
#  {'name': 'Everything You Always Wanted to Know About Sex*',
#   'genres': ['Comedy'],
#   'year': '1972'},
#  {'name': 'Rock-a-Doodle',
#   'genres': ['Comedy', 'Family', 'Animation', 'Fantasy', 'Music'],
#   'year': '1991'},
#  {'name': 'Too Late', 'genres': ['Drama', 'Crime', 'Mystery'], 'year': 'None'},
#  {'name': 'Law Abiding Citizen',
#   'genres': ['Drama', 'Crime', 'Thriller'],
#   'year': '2009'},
#  {'name': 'The Black Mask', 'genres': ['Crime'], 'year': '1935'},
#  {'name': 'Club Dread', 'genres': ['Comedy', 'Horror'], 'year': '2004'},
#  {'name': 'Moana',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Signs',
#   'genres': ['Drama', 'Thriller', 'Science Fiction', 'Mystery'],
#   'year': '2002'},
#  {'name': 'Beyond the Valley of the Dolls',
#   'genres': ['Comedy', 'Drama', 'Music'],
#   'year': '1970'},
#  {'name': 'Beastly',
#   'genres': ['Drama', 'Fantasy', 'Romance'],
#   'year': '2011'},
#  {'name': 'Victoria',
#   'genres': ['Crime', 'Thriller', 'Romance'],
#   'year': '2015'},
#  {'name': 'The Duel', 'genres': ['Western', 'Drama'], 'year': '2016'},
#  {'name': 'American Ninja 2: The Confrontation',
#   'genres': ['Action'],
#   'year': '1987'},
#  {'name': 'Earth to Echo',
#   'genres': ['Family', 'Adventure', 'Science Fiction'],
#   'year': '2014'},
#  {'name': 'Amélie', 'genres': ['Comedy', 'Romance'], 'year': '2001'},
#  {'name': 'Born Free', 'genres': ['Adventure'], 'year': '1966'},
#  {'name': 'Son in Law',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1993'},
#  {'name': 'Killer Klowns from Outer Space',
#   'genres': ['Comedy', 'Horror', 'Science Fiction'],
#   'year': '1988'},
#  {'name': 'Holiday Inn',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1942'},
#  {'name': 'Dracula Untold',
#   'genres': ['Horror', 'Action', 'Fantasy'],
#   'year': '2014'},
#  {'name': 'Tom and Jerry: The Fast and the Furry',
#   'genres': ['Family', 'Animation', 'Comedy', 'Action', 'Adventure'],
#   'year': 'None'},
#  {'name': 'Shanghai Knights',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Western'],
#   'year': '2003'},
#  {'name': 'Dirty Dancing: Havana Nights',
#   'genres': ['Drama', 'Romance'],
#   'year': 'None'},
#  {'name': 'Ghost in the Shell: Stand Alone Complex - Solid State Society',
#   'genres': ['Animation', 'Action', 'Thriller', 'Crime', 'Science Fiction'],
#   'year': '2006'},
#  {'name': 'Chasing Mavericks', 'genres': ['Drama'], 'year': '2012'},
#  {'name': "Sophie's Choice",
#   'genres': ['Drama', 'Romance', 'War'],
#   'year': '1982'},
#  {'name': 'Secondhand Lions', 'genres': ['Family', 'Comedy'], 'year': '2003'},
#  {'name': 'Rio 2',
#   'genres': ['Animation', 'Adventure', 'Comedy', 'Family'],
#   'year': '2014'},
#  {'name': 'Places in the Heart', 'genres': ['Drama'], 'year': '1984'},
#  {'name': 'The Incident', 'genres': ['Horror', 'Thriller'], 'year': '2011'},
#  {'name': 'Police Story 2', 'genres': ['misc'], 'year': '2007'},
#  {'name': 'Not Fade Away', 'genres': ['Drama'], 'year': '2012'},
#  {'name': 'In the Mood for Love',
#   'genres': ['Drama', 'Romance'],
#   'year': '2000'},
#  {'name': 'Kaizoku Sentai Gokaiger the Movie: The Flying Ghost Ship',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'Fantasy', 'Horror'],
#   'year': '2011'},
#  {'name': 'To Live and Die in L.A.',
#   'genres': ['Crime', 'Thriller', 'Action'],
#   'year': '1985'},
#  {'name': 'The Young Guns', 'genres': ['Western'], 'year': '1956'},
#  {'name': 'Secret Window', 'genres': ['Mystery', 'Thriller'], 'year': '2004'},
#  {'name': 'Ladybird, Ladybird', 'genres': ['Drama'], 'year': '1994'},
#  {'name': 'Robot Stories',
#   'genres': ['Drama', 'Science Fiction', 'Romance'],
#   'year': '2003'},
#  {'name': 'Amelia', 'genres': ['Adventure', 'Drama'], 'year': '2009'},
#  {'name': '21', 'genres': ['Drama', 'Crime'], 'year': '2008'},
#  {'name': 'The Rocky Horror Picture Show',
#   'genres': ['Comedy', 'Science Fiction', 'Fantasy', 'Horror'],
#   'year': '1975'},
#  {'name': 'Curse of Chucky', 'genres': ['Horror', 'Thriller'], 'year': '2013'},
#  {'name': 'Timeline',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': '2003'},
#  {'name': 'Picnic at Hanging Rock',
#   'genres': ['Drama', 'Mystery'],
#   'year': '1975'},
#  {'name': 'Epic Movie',
#   'genres': ['Comedy', 'Action', 'Adventure'],
#   'year': '2007'},
#  {'name': 'Homeward Bound',
#   'genres': ['Adventure', 'Drama', 'Romance'],
#   'year': '1923'},
#  {'name': "White Men Can't Jump",
#   'genres': ['Comedy', 'Drama'],
#   'year': '1992'},
#  {'name': 'These Final Hours',
#   'genres': ['Science Fiction', 'Drama', 'Thriller'],
#   'year': '2013'},
#  {'name': 'Fast 8', 'genres': ['Comedy'], 'year': 'None'},
#  {'name': 'Herbie: Fully Loaded',
#   'genres': ['Comedy', 'Family', 'Adventure', 'Fantasy', 'Romance'],
#   'year': '2005'},
#  {'name': "Baby's Day Out",
#   'genres': ['Family', 'Comedy', 'Adventure', 'Crime', 'Drama'],
#   'year': '1994'},
#  {'name': 'Forever Young',
#   'genres': ['Adventure', 'Fantasy', 'Drama', 'Science Fiction', 'Romance'],
#   'year': '1992'},
#  {'name': 'Spider', 'genres': ['Drama', 'Comedy', 'Action'], 'year': '2007'},
#  {'name': 'Fat Man and Little Boy',
#   'genres': ['Drama', 'History', 'War'],
#   'year': '1989'},
#  {'name': 'Hard Boiled',
#   'genres': ['Action', 'Thriller', 'Crime'],
#   'year': '1992'},
#  {'name': 'The Eye',
#   'genres': ['Drama', 'Horror', 'Thriller'],
#   'year': '2008'},
#  {'name': 'List of accolades received by Gone Girl',
#   'genres': ['misc'],
#   'year': 'None'},
#  {'name': 'Like Water for Chocolate',
#   'genres': ['Drama', 'Romance'],
#   'year': '1992'},
#  {'name': 'Urban Legend', 'genres': ['Horror', 'Mystery'], 'year': '1998'},
#  {'name': 'Dr. Strangelove', 'genres': ['Comedy', 'War'], 'year': '1964'},
#  {'name': 'Concussion', 'genres': ['Drama'], 'year': '2015'},
#  {'name': 'Breathe', 'genres': ['Crime', 'Drama'], 'year': '2009'},
#  {'name': 'Appleseed Ex Machina',
#   'genres': ['Animation', 'Action', 'Thriller', 'Science Fiction'],
#   'year': 'None'},
#  {'name': 'Shaolin Temple', 'genres': ['Action', 'Adventure'], 'year': '1976'},
#  {'name': 'Cheaper by the Dozen',
#   'genres': ['Comedy', 'Family'],
#   'year': '2003'},
#  {'name': 'Windy City Heat', 'genres': ['Comedy'], 'year': 'None'},
#  {'name': 'Dog Days', 'genres': ['Drama', 'Comedy'], 'year': '2001'},
#  {'name': 'Dead Silence', 'genres': ['Horror'], 'year': '2007'},
#  {'name': "Your Sister's Sister", 'genres': ['Comedy'], 'year': '2011'},
#  {'name': 'City of Angels',
#   'genres': ['Romance', 'Drama', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Gosford Park',
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'year': '2001'},
#  {'name': "You Don't Mess with the Zohan",
#   'genres': ['Comedy', 'Action'],
#   'year': '2008'},
#  {'name': "Cheech & Chong's Animated Movie",
#   'genres': ['Animation', 'Comedy'],
#   'year': '2013'},
#  {'name': 'Beware! The Blob',
#   'genres': ['Comedy', 'Science Fiction', 'Horror'],
#   'year': '1972'},
#  {'name': 'The Uncomfortable Camera', 'genres': ['misc'], 'year': '2005'},
#  {'name': 'Hook',
#   'genres': ['Adventure', 'Fantasy', 'Comedy', 'Family'],
#   'year': '1991'},
#  {'name': 'Winter Passing', 'genres': ['Comedy', 'Drama'], 'year': '2005'},
#  {'name': 'Little Giants', 'genres': ['Comedy', 'Family'], 'year': '1994'},
#  {'name': 'Failure to Launch',
#   'genres': ['Comedy', 'Romance'],
#   'year': '2006'},
#  {'name': 'Benji the Hunted',
#   'genres': ['Action', 'Adventure', 'Family'],
#   'year': '1987'},
#  {'name': 'Father of the Bride Part II',
#   'genres': ['Comedy', 'Family'],
#   'year': '1995'},
#  {'name': 'King Boxer', 'genres': ['Action'], 'year': '1972'},
#  {'name': 'Bully', 'genres': ['Crime', 'Drama'], 'year': '2001'},
#  {'name': 'Finding Dory',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'year': '2016'},
#  {'name': 'Run for Money', 'genres': ['Drama'], 'year': '1999'},
#  {'name': 'Stuart Little',
#   'genres': ['Family', 'Fantasy', 'Comedy', 'Adventure'],
#   'year': '1999'},
#  {'name': 'Acts of Worship', 'genres': ['Drama', 'Family'], 'year': '2001'},
#  {'name': 'Dying of Laughter', 'genres': ['Comedy'], 'year': '1999'},
#  {'name': 'Y Tu Mamá También', 'genres': ['Drama', 'Romance'], 'year': '2001'},
#  {'name': 'Lockout',
#   'genres': ['Action', 'Thriller', 'Science Fiction'],
#   'year': '2012'},
#  {'name': 'Eddie and the Cruisers II: Eddie Lives!',
#   'genres': ['Drama', 'Thriller', 'Music'],
#   'year': '1989'},
#  {'name': 'Jeepers Creepers',
#   'genres': ['Horror', 'Thriller', 'Mystery', 'Drama'],
#   'year': '2001'},
#  {'name': 'Le Mans', 'genres': ['Drama'], 'year': '1970'},
#  {'name': 'The Sisterhood of the Traveling Pants 2',
#   'genres': ['Adventure', 'Comedy', 'Drama'],
#   'year': '2008'},
#  {'name': 'Wreckers', 'genres': ['Drama'], 'year': '2011'},
#  {'name': 'Death at a Funeral', 'genres': ['Comedy'], 'year': '2010'},
#  {'name': 'Judge Dredd', 'genres': ['Science Fiction'], 'year': '1995'},
#  {'name': '12', 'genres': ['Crime', 'Drama', 'Mystery'], 'year': '2007'},
#  {'name': 'The Call', 'genres': ['Crime', 'Thriller'], 'year': '2013'},
#  {'name': 'Heaven & Earth',
#   'genres': ['History', 'War', 'Action', 'Drama'],
#   'year': '1993'},
#  {'name': 'Without Permission', 'genres': ['misc'], 'year': '2012'},
#  {'name': 'Charlie St. Cloud', 'genres': ['Drama', 'Romance'], 'year': '2010'},
#  {'name': 'One Piece Film: Z',
#   'genres': ['Animation', 'Fantasy', 'Action', 'Adventure'],
#   'year': 'None'},
#  {'name': 'The Human Centipede', 'genres': ['Horror'], 'year': '2009'},
#  {'name': 'The Mask', 'genres': ['Comedy'], 'year': '1988'},
#  {'name': 'Cast Away', 'genres': ['Adventure', 'Drama'], 'year': '2000'},
#  {'name': 'Dogtown and Z-Boys', 'genres': ['Documentary'], 'year': '2001'},
#  {'name': 'Memoirs of a Geisha',
#   'genres': ['Drama', 'Romance', 'History'],
#   'year': '2005'},
#  {'name': 'Vertical Limit',
#   'genres': ['Adventure', 'Action', 'Thriller'],
#   'year': '2000'},
#  {'name': 'Freddy Got Fingered', 'genres': ['Comedy'], 'year': '2001'},
#  {'name': 'Steve Jobs', 'genres': ['Drama', 'History'], 'year': '2015'},
#  {'name': 'Hollow Man',
#   'genres': ['Action', 'Science Fiction', 'Thriller'],
#   'year': '2000'},
#  {'name': 'Woman on Top',
#   'genres': ['Comedy', 'Drama', 'Romance', 'Fantasy'],
#   'year': '2000'},
#  {'name': 'Hamlet', 'genres': ['Drama', 'History'], 'year': '2009'},
#  {'name': 'The Seven Five', 'genres': ['Documentary'], 'year': 'None'},
#  {'name': 'The Wizard of Oz',
#   'genres': ['Adventure', 'Fantasy', 'Family'],
#   'year': '1939'},
#  {'name': 'The Best Exotic Marigold Hotel',
#   'genres': ['Drama', 'Comedy'],
#   'year': 'None'},
#  {'name': 'Lovers', 'genres': ['Drama'], 'year': '1999'},
#  {'name': 'The Transporter',
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'year': '2002'},
#  {'name': "My Baby's Daddy", 'genres': ['Comedy'], 'year': '2004'},
#  {'name': 'Children of the Corn',
#   'genres': ['Horror', 'Thriller'],
#   'year': '1984'},
#  {'name': 'Poverty Inc.', 'genres': ['Documentary'], 'year': '2014'},
#  {'name': 'Mulan',
#   'genres': ['Animation', 'Family', 'Adventure'],
#   'year': '1998'},
#  {'name': 'Drag Me to Hell', 'genres': ['Horror', 'Thriller'], 'year': '2009'},
#  {'name': 'Surf Ninjas',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Family'],
#   'year': '1993'},
#  {'name': 'Death Toll',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'year': '2008'},
#  {'name': 'Beverly Hills Cop',
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'year': '1984'},
#  {'name': 'The Revenant', 'genres': ['Comedy', 'Horror'], 'year': '2009'},
#  {'name': 'Cowboy', 'genres': ['Western'], 'year': '1958'},
#  {'name': 'Beauty and the Bestie',
#   'genres': ['Drama', 'Action', 'Comedy'],
#   'year': '2015'},
#  {'name': 'Saving Mr. Banks',
#   'genres': ['Comedy', 'Drama', 'History'],
#   'year': '2013'},
#  {'name': 'The Holy Mountain', 'genres': ['Drama'], 'year': '1973'},
#  {'name': 'The Tooth Fairy', 'genres': ['Horror'], 'year': '2006'},
#  {'name': 'Deadroom', 'genres': ['Drama'], 'year': '2005'},
#  {'name': 'The Square', 'genres': ['Drama'], 'year': '2017'},
#  {'name': 'Fatty Joins the Force', 'genres': ['Comedy'], 'year': '1913'},
#  {'name': 'The Great Mouse Detective',
#   'genres': ['Animation', 'Family', 'Adventure', 'Mystery'],
#   'year': 'None'},
#  {'name': 'Shutter',
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'year': '2008'},
#  {'name': 'Home Alone 2: Lost in New York',
#   'genres': ['Comedy', 'Family', 'Adventure'],
#   'year': '1992'},
#  {'name': 'Dial M for Murder',
#   'genres': ['Thriller', 'Crime'],
#   'year': '1954'},
#  {'name': 'Maya the Bee', 'genres': ['Family', 'Animation'], 'year': '2014'},
#  {'name': 'Groundhog Day',
#   'genres': ['Romance', 'Fantasy', 'Drama', 'Comedy'],
#   'year': 'None'},
#  {'name': 'Secretary',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '2002'},
#  {'name': 'Far and Away',
#   'genres': ['Adventure', 'Drama', 'Romance', 'Western'],
#   'year': '1992'},
#  {'name': 'Norbit', 'genres': ['Comedy'], 'year': '2007'},
#  {'name': 'From Beyond',
#   'genres': ['Horror', 'Science Fiction'],
#   'year': '1986'},
#  {'name': "Madea's Family Reunion",
#   'genres': ['Drama', 'Comedy', 'Romance'],
#   'year': '2006'},
#  {'name': 'Spetters', 'genres': ['Drama', 'Romance'], 'year': '1980'},
#  {'name': 'Amityville: The Awakening',
#   'genres': ['Thriller', 'Horror'],
#   'year': '2017'},
#  {'name': 'Yours, Mine & Ours',
#   'genres': ['Comedy', 'Family', 'Romance'],
#   'year': '2005'},
#  {'name': 'Evan Almighty',
#   'genres': ['Fantasy', 'Comedy', 'Family'],
#   'year': '2007'},
#  {'name': 'Serenity',
#   'genres': ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#   'year': '2005'},
#  {'name': 'Apocalypse Now', 'genres': ['Drama', 'War'], 'year': '1979'},
#  {'name': 'Everly', 'genres': ['Thriller', 'Action'], 'year': '2014'},
#  {'name': 'Jihad: A Story of the Others',
#   'genres': ['Documentary'],
#   'year': '2015'},
#  {'name': 'The Shootist', 'genres': ['Western', 'Drama'], 'year': '1976'},
#  {'name': 'The Danish Girl', 'genres': ['Drama'], 'year': '2015'},
#  {'name': 'RoboCop',
#   'genres': ['Action', 'Thriller', 'Science Fiction'],
#   'year': '1987'},
#  {'name': 'Cyrano de Bergerac',
#   'genres': ['Drama', 'Comedy', 'History', 'Romance'],
#   'year': '1990'},
#  {'name': 'X-Men',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Fast & Furious',
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'year': '2009'},
#  {'name': 'Night Train',
#   'genres': ['Thriller', 'Crime', 'Horror'],
#   'year': '2009'},
#  {'name': 'Psych-Out',
#   'genres': ['Drama', 'Thriller', 'Music'],
#   'year': '1968'},
#  {'name': 'Deranged',
#   'genres': ['Crime', 'Horror', 'Thriller'],
#   'year': '1974'},
#  {'name': "Charlie's Angels",
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'year': 'None'},
#  {'name': 'Faces in the Crowd',
#   'genres': ['Thriller', 'Crime'],
#   'year': '2011'},
#  {'name': 'Tiger Zinda Hai',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'year': '2017'},
#  {'name': "Being Elmo: A Puppeteer's Journey",
#   'genres': ['Documentary'],
#   'year': '2011'},
#  {'name': 'Idiocracy',
#   'genres': ['Comedy', 'Science Fiction', 'Adventure'],
#   'year': '2006'},
#  {'name': 'Seed of Chucky',
#   'genres': ['Comedy', 'Horror', 'Thriller'],
#   'year': '2004'},
#  {'name': "A Midsummer Night's Dream",
#   'genres': ['Fantasy', 'Comedy', 'Romance'],
#   'year': '1999'},
#  {'name': 'When the Levees Broke', 'genres': ['misc'], 'year': 'None'},
#  {'name': 'B*A*P*S', 'genres': ['Comedy'], 'year': '1997'},
#  {'name': 'Rush Hour',
#   'genres': ['Action', 'Comedy', 'Crime'],
#   'year': '1998'},
#  {'name': "It's a Mad, Mad, Mad, Mad World",
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'year': '1963'},
#  {'name': 'Never Back Down: No Surrender',
#   'genres': ['Drama', 'Action'],
#   'year': '2016'},
#  {'name': 'Leap Year', 'genres': ['Romance', 'Comedy'], 'year': '2010'},
#  {'name': "We're the Millers", 'genres': ['Comedy', 'Crime'], 'year': '2013'},
#  {'name': 'Sully', 'genres': ['Drama', 'History'], 'year': '2016'},
#  {'name': 'Elysium',
#   'genres': ['Science Fiction', 'Action', 'Drama', 'Thriller'],
#   'year': '2013'},
#  {'name': "Gerald's Game", 'genres': ['Horror', 'Thriller'], 'year': '2017'},
#  {'name': 'Fantastic Four',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': '2015'},
#  {'name': 'Guess Who', 'genres': ['Comedy', 'Romance'], 'year': '2005'},
#  {'name': 'Doctor Who',
#   'genres': ['TV Movie', 'Adventure', 'Science Fiction'],
#   'year': 'None'},
#  {'name': 'Snowpiercer',
#   'genres': ['Action', 'Science Fiction', 'Drama'],
#   'year': '2013'},
#  {'name': 'The Bridge on the River Kwai',
#   'genres': ['Drama', 'History', 'War'],
#   'year': '1957'},
#  {'name': 'S', 'genres': ['Comedy', 'Drama'], 'year': '2012'},
#  {'name': 'The Expendables',
#   'genres': ['Thriller', 'Adventure', 'Action'],
#   'year': '2010'},
#  {'name': 'Once Upon a Time in America',
#   'genres': ['Drama', 'Crime'],
#   'year': '1984'},
#  {'name': 'Flatliners',
#   'genres': ['Drama', 'Science Fiction', 'Horror'],
#   'year': '2017'},
#  {'name': 'Heat', 'genres': ['Action', 'Crime', 'Drama'], 'year': '1996'},
#  {'name': 'Changeling',
#   'genres': ['Crime', 'Drama', 'Mystery'],
#   'year': '2008'},
#  {'name': 'Einstein Girl', 'genres': ['misc'], 'year': '2005'},
#  {'name': 'The Town',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2010'},
#  {'name': "Valentine's Day", 'genres': ['misc'], 'year': '2007'},
#  {'name': '13th', 'genres': ['Documentary'], 'year': '2016'},
#  {'name': 'Fever', 'genres': ['Mystery', 'Crime'], 'year': '2016'},
#  {'name': 'The Bridesmaid', 'genres': ['Thriller', 'Romance'], 'year': '2004'},
#  {'name': 'Crank', 'genres': ['Action', 'Thriller', 'Crime'], 'year': '2006'},
#  {'name': 'Aladdin',
#   'genres': ['Adventure', 'Fantasy', 'Romance', 'Family'],
#   'year': 'None'},
#  {'name': 'The Little Mermaid',
#   'genres': ['Animation', 'Family', 'Fantasy'],
#   'year': '1989'},
#  {'name': 'Four Sisters and a Wedding',
#   'genres': ['Family', 'Comedy', 'Drama', 'Romance'],
#   'year': '2013'},
#  {'name': '79 A.D.', 'genres': ['Drama', 'History'], 'year': 'None'},
#  {'name': 'Bottle Rocket',
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'year': '1996'},
#  {'name': 'Love Station', 'genres': ['misc'], 'year': '2016'},
#  {'name': 'American Made',
#   'genres': ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#   'year': '2017'},
#  {'name': 'Pokémon 3: The Movie',
#   'genres': ['Adventure', 'Fantasy', 'Animation', 'Action', 'Family'],
#   'year': 'None'},
#  {'name': 'Swades', 'genres': ['Drama', 'Family'], 'year': '2004'},
#  {'name': 'The Road to El Dorado',
#   'genres': ['Family', 'Adventure', 'Animation', 'Comedy', 'Fantasy'],
#   'year': '2000'},
#  {'name': 'Tequila Sunrise',
#   'genres': ['Thriller', 'Crime', 'Romance'],
#   'year': '1988'},
#  {'name': 'Where the Money Is',
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'year': '2000'},
#  {'name': 'Scent of a Woman', 'genres': ['Comedy', 'Drama'], 'year': '1974'},
#  {'name': 'For Love of the Game',
#   'genres': ['Drama', 'Romance'],
#   'year': '1999'},
#  {'name': 'The Vanishing', 'genres': ['Thriller', 'Mystery'], 'year': '1988'},
#  {'name': 'Super8', 'genres': ['Documentary'], 'year': 'None'},
#  {'name': 'Superman: Doomsday',
#   'genres': ['Action', 'Animation', 'Science Fiction', 'Family'],
#   'year': 'None'},
#  {'name': 'Taking Lives', 'genres': ['Crime', 'Thriller'], 'year': '2004'},
#  {'name': 'Never Say Die', 'genres': ['Comedy'], 'year': '1939'},
#  {'name': 'The Single Moms Club',
#   'genres': ['Drama', 'Comedy'],
#   'year': '2014'},
#  {'name': 'Thirteen Days',
#   'genres': ['Drama', 'History', 'Thriller', 'War'],
#   'year': '2000'},
#  {'name': 'Richie Rich', 'genres': ['Comedy', 'Family'], 'year': '1994'},
#  {'name': 'The Beatles: Eight Days a Week',
#   'genres': ['Documentary', 'Music'],
#   'year': 'None'},
#  {'name': 'Mars',
#   'genres': ['Action', 'Horror', 'Science Fiction'],
#   'year': '2004'},
#  {'name': 'Lucy', 'genres': ['TV Movie', 'Drama'], 'year': '2003'},
#  {'name': 'Love Shack', 'genres': ['Comedy'], 'year': '2010'},
#  {'name': 'Where to Invade Next', 'genres': ['Documentary'], 'year': '2015'},
#  {'name': 'Forever Strong', 'genres': ['Drama', 'Action'], 'year': '2008'},
#  {'name': 'Birdman', 'genres': ['Drama', 'Comedy'], 'year': '2014'},
#  {'name': 'Horrible Bosses 2', 'genres': ['Comedy'], 'year': '2014'},
#  {'name': 'The Family Stone',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '2005'},
#  {'name': 'Tron: Legacy',
#   'genres': ['Adventure', 'Action', 'Science Fiction'],
#   'year': '2010'},
#  {'name': 'Inferno',
#   'genres': ['Mystery', 'Thriller', 'Action'],
#   'year': '2016'},
#  {'name': 'A Home at the End of the World',
#   'genres': ['Drama', 'Romance'],
#   'year': '2004'},
#  {'name': 'Herbie', 'genres': ['misc'], 'year': '1965'},
#  {'name': 'Dracula 3D', 'genres': ['Horror'], 'year': '2012'},
#  {'name': 'The Gift',
#   'genres': ['Horror', 'Drama', 'Thriller', 'Mystery'],
#   'year': '2000'},
#  {'name': 'Jiro Dreams of Sushi', 'genres': ['Documentary'], 'year': '2011'},
#  {'name': 'Wrong Cops',
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'year': '2013'},
#  {'name': 'Ghosts', 'genres': ['Drama'], 'year': '1915'},
#  {'name': 'Titan A.E.',
#   'genres': ['Animation', 'Action', 'Science Fiction', 'Family', 'Adventure'],
#   'year': '2000'},
#  {'name': 'Hamburger Hill',
#   'genres': ['War', 'Action', 'Drama'],
#   'year': '1987'},
#  {'name': 'God Bless America', 'genres': ['Comedy', 'Drama'], 'year': '2011'},
#  {'name': 'Breaking Dawn',
#   'genres': ['Mystery', 'Thriller', 'Horror'],
#   'year': '2004'},
#  {'name': 'Man on Wire', 'genres': ['Documentary'], 'year': '2008'},
#  {'name': 'The Last Escape', 'genres': ['Drama'], 'year': '2010'},
#  {'name': 'The American',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2010'},
#  {'name': 'Paranormal Activity 3',
#   'genres': ['Horror', 'Mystery'],
#   'year': '2011'},
#  {'name': 'The Odd Life of Timothy Green',
#   'genres': ['Fantasy', 'Drama', 'Comedy', 'Family'],
#   'year': '2012'},
#  {'name': 'Swiss Army Man',
#   'genres': ['Comedy', 'Drama', 'Romance', 'Fantasy', 'Adventure'],
#   'year': '2016'},
#  {'name': 'Black Belt', 'genres': ['Action', 'Drama'], 'year': '2007'},
#  {'name': 'Easy Rider', 'genres': ['Adventure', 'Drama'], 'year': '1969'},
#  {'name': 'A.I. Artificial Intelligence',
#   'genres': ['Drama', 'Science Fiction', 'Adventure'],
#   'year': '2001'},
#  {'name': 'National Treasure: Book of Secrets',
#   'genres': ['Action', 'Adventure', 'Mystery', 'Thriller'],
#   'year': '2007'},
#  {'name': 'The Belko Experiment',
#   'genres': ['Horror', 'Thriller'],
#   'year': '2016'},
#  {'name': 'Where the Red Fern Grows',
#   'genres': ['Drama', 'Family'],
#   'year': '1974'},
#  {'name': 'Blue Hawaii', 'genres': ['Comedy', 'Music'], 'year': '1961'},
#  {'name': 'Temptation: Confessions of a Marriage Counselor',
#   'genres': ['Drama'],
#   'year': '2013'},
#  {'name': 'Romance', 'genres': ['Drama'], 'year': '1920'},
#  {'name': 'My Father the Hero',
#   'genres': ['Family', 'Comedy', 'Romance'],
#   'year': '1994'},
#  {'name': 'Woody Woodpecker',
#   'genres': ['Comedy', 'Family', 'Animation'],
#   'year': '2017'},
#  {'name': 'Wings of Life', 'genres': ['Documentary'], 'year': '2011'},
#  {'name': 'Contact',
#   'genres': ['Drama', 'Science Fiction', 'Mystery'],
#   'year': '2009'},
#  {'name': 'Rob Roy',
#   'genres': ['Adventure', 'History', 'Drama', 'Action', 'War'],
#   'year': '1995'},
#  {'name': 'Jump', 'genres': ['Drama', 'Comedy'], 'year': '1999'},
#  {'name': "Everybody's Fine", 'genres': ['Drama'], 'year': '2009'},
#  {'name': 'August: Osage County',
#   'genres': ['Comedy', 'Drama'],
#   'year': '2013'},
#  {'name': 'Mission: Impossible III',
#   'genres': ['Adventure', 'Action', 'Thriller'],
#   'year': '2006'},
#  {'name': 'How to Succeed in Business Without Really Trying',
#   'genres': ['Comedy', 'Music'],
#   'year': 'None'},
#  {'name': 'Toy Story That Time Forgot',
#   'genres': ['Animation', 'Family', 'Adventure', 'Comedy'],
#   'year': 'None'},
#  {'name': 'Cry-Baby', 'genres': ['Comedy', 'Romance'], 'year': '1990'},
#  {'name': 'Fred Claus',
#   'genres': ['Action', 'Comedy', 'Drama'],
#   'year': '2007'},
#  {'name': 'Dune',
#   'genres': ['Action', 'Science Fiction', 'Adventure'],
#   'year': '1984'},
#  {'name': 'The Poseidon Adventure',
#   'genres': ['Adventure', 'Thriller', 'Action'],
#   'year': '1972'},
#  {'name': 'Dangerous Minds', 'genres': ['Drama'], 'year': '1995'},
#  {'name': 'Hanna',
#   'genres': ['Action', 'Thriller', 'Adventure'],
#   'year': '2011'},
#  {'name': "Can't Buy Me Love",
#   'genres': ['Drama', 'Comedy', 'Romance'],
#   'year': '1987'},
#  {'name': 'To Wong Foo, Thanks for Everything! Julie Newmar',
#   'genres': ['Comedy'],
#   'year': '1995'},
#  {'name': "Mr. Holland's Opus",
#   'genres': ['Drama', 'Music', 'Family'],
#   'year': '1995'},
#  {'name': 'Into the Woods', 'genres': ['Fantasy', 'Comedy'], 'year': '2014'},
#  {'name': 'Spirited Away',
#   'genres': ['Animation', 'Family', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Cowspiracy', 'genres': ['Documentary'], 'year': '2014'},
#  {'name': 'Bird on a Wire',
#   'genres': ['Action', 'Adventure', 'Comedy', 'Romance'],
#   'year': '1990'},
#  {'name': '42', 'genres': ['Drama'], 'year': '2013'},
#  {'name': 'Kingdom of Heaven',
#   'genres': ['Drama', 'Action', 'Adventure', 'History', 'War'],
#   'year': '2005'},
#  {'name': 'Nightcrawler',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2014'},
#  {'name': 'A Taste of Honey', 'genres': ['Drama'], 'year': '1961'},
#  {'name': 'Joseph: King of Dreams',
#   'genres': ['Family', 'Animation', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Heaven Is for Real', 'genres': ['Drama'], 'year': '2014'},
#  {'name': 'M. Butterfly', 'genres': ['Romance', 'Drama'], 'year': '1993'},
#  {'name': 'The First Monday in May',
#   'genres': ['Documentary'],
#   'year': 'None'},
#  {'name': 'Gun Shy',
#   'genres': ['Action', 'Comedy', 'Romance', 'Thriller'],
#   'year': '2000'},
#  {'name': 'Open House',
#   'genres': ['Drama', 'Horror', 'Thriller'],
#   'year': '2010'},
#  {'name': 'Dusk to Dawn', 'genres': ['misc'], 'year': '1922'},
#  {'name': 'The Man Who Knew Infinity', 'genres': ['Drama'], 'year': '2015'},
#  {'name': 'Avatar',
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#   'year': '2009'},
#  {'name': 'The Replacements', 'genres': ['Comedy'], 'year': '2000'},
#  {'name': 'True Romance',
#   'genres': ['Action', 'Crime', 'Romance'],
#   'year': '1993'},
#  {'name': 'Collateral Beauty', 'genres': ['Drama', 'Romance'], 'year': '2016'},
#  {'name': 'Goldie', 'genres': ['Comedy'], 'year': '1931'},
#  {'name': 'Extract', 'genres': ['Comedy'], 'year': 'None'},
#  {'name': '...When Love Happens', 'genres': ['Romance'], 'year': '2014'},
#  {'name': 'Jackass 3D',
#   'genres': ['Comedy', 'Documentary', 'Action'],
#   'year': '2010'},
#  {'name': "The Hitchhiker's Guide to the Galaxy",
#   'genres': ['Adventure', 'Comedy', 'Science Fiction'],
#   'year': '2005'},
#  {'name': 'May', 'genres': ['Comedy', 'Drama', 'Horror'], 'year': '2002'},
#  {'name': 'Jack Ryan: Shadow Recruit',
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'year': '2014'},
#  {'name': 'Sugar and Spice',
#   'genres': ['Action', 'Comedy', 'Drama', 'Romance'],
#   'year': '2006'},
#  {'name': 'Final',
#   'genres': ['Drama', 'Science Fiction', 'Thriller'],
#   'year': '2001'},
#  {'name': 'Stargate: The Ark of Truth',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'TV Movie'],
#   'year': '2008'},
#  {'name': 'Spies', 'genres': ['Comedy', 'Animation', 'War'], 'year': '1943'},
#  {'name': 'The Sweetest Thing',
#   'genres': ['Romance', 'Comedy'],
#   'year': '2002'},
#  {'name': 'The Bling Ring', 'genres': ['Drama', 'Crime'], 'year': '2013'},
#  {'name': 'Mr. Bond', 'genres': ['misc'], 'year': '1992'},
#  {'name': 'Tank Girl',
#   'genres': ['Action', 'Comedy', 'Science Fiction'],
#   'year': '1995'},
#  {'name': 'The Elephant Man', 'genres': ['Drama', 'History'], 'year': '1982'},
#  {'name': 'Joe', 'genres': ['Drama'], 'year': '2013'},
#  {'name': 'The French Connection',
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'year': '1971'},
#  {'name': 'Waltz with Bashir',
#   'genres': ['Drama', 'Animation', 'War', 'Documentary'],
#   'year': '2008'},
#  {'name': 'Good Morning, Vietnam',
#   'genres': ['Comedy', 'Drama', 'War'],
#   'year': '1987'},
#  {'name': "Schindler's List",
#   'genres': ['Drama', 'History', 'War'],
#   'year': '1993'},
#  {'name': 'The Jungle',
#   'genres': ['Family', 'Animation', 'Adventure'],
#   'year': '1967'},
#  {'name': 'Deuce Bigalow: Male Gigolo', 'genres': ['Comedy'], 'year': '1999'},
#  {'name': 'The Best Years of Our Lives',
#   'genres': ['Drama', 'Romance', 'War'],
#   'year': '1946'},
#  {'name': 'Double Impact',
#   'genres': ['Thriller', 'Action', 'Crime', 'Drama'],
#   'year': '1991'},
#  {'name': 'Popstar: Never Stop Never Stopping',
#   'genres': ['Comedy', 'Music'],
#   'year': '2016'},
#  {'name': 'Hardball', 'genres': ['Drama'], 'year': '2001'},
#  {'name': 'Fissures', 'genres': ['misc'], 'year': '2009'},
#  {'name': 'Gone Fishing', 'genres': ['misc'], 'year': '2008'},
#  {'name': 'Air Bud', 'genres': ['Comedy', 'Family'], 'year': '1997'},
#  {'name': 'Clerks', 'genres': ['Comedy'], 'year': '1994'},
#  {'name': 'Rent', 'genres': ['Drama', 'Romance'], 'year': '2005'},
#  {'name': 'Roll Bounce',
#   'genres': ['Comedy', 'Drama', 'Family'],
#   'year': '2005'},
#  {'name': 'Charlie and the Chocolate Factory',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'year': '2005'},
#  {'name': 'Once Upon a Time in the West',
#   'genres': ['Drama', 'Western'],
#   'year': '1968'},
#  {'name': 'The Juror', 'genres': ['Thriller', 'Crime'], 'year': '1996'},
#  {'name': 'The Strangers',
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'year': '2012'},
#  {'name': 'Wet Hot American Summer', 'genres': ['Comedy'], 'year': '2001'},
#  {'name': 'Tammy', 'genres': ['Comedy'], 'year': '2014'},
#  {'name': 'Dredd', 'genres': ['Action', 'Science Fiction'], 'year': '2012'},
#  {'name': 'Egypt as it Was in the Time of Moses',
#   'genres': ['misc'],
#   'year': '1912'},
#  {'name': 'Clerks II', 'genres': ['Comedy'], 'year': '2006'},
#  {'name': 'Under Siege', 'genres': ['Action', 'Thriller'], 'year': '1992'},
#  {'name': 'Saw III',
#   'genres': ['Horror', 'Thriller', 'Crime'],
#   'year': '2006'},
#  {'name': 'The Hot Chick', 'genres': ['Comedy', 'Fantasy'], 'year': '2002'},
#  {'name': 'All Dogs Go to Heaven',
#   'genres': ['Drama', 'Animation', 'Family', 'Comedy', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'The Pacifier',
#   'genres': ['Comedy', 'Family', 'Action'],
#   'year': '2005'},
#  {'name': 'Murder on the Orient Express',
#   'genres': ['Mystery', 'Drama', 'Crime'],
#   'year': '2017'},
#  {'name': 'Camp Rock 2: The Final Jam',
#   'genres': ['Comedy', 'Music', 'TV Movie'],
#   'year': 'None'},
#  {'name': 'Million Dollar Baby', 'genres': ['Drama'], 'year': '2004'},
#  {'name': 'The Penthouse', 'genres': ['Thriller', 'Drama'], 'year': '1967'},
#  {'name': 'John Carter',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': '2012'},
#  {'name': 'Night of Fear', 'genres': ['misc'], 'year': '1972'},
#  {'name': 'Crooklyn', 'genres': ['Comedy', 'Drama'], 'year': '1994'},
#  {'name': 'Enclosure', 'genres': ['Drama'], 'year': '1961'},
#  {'name': "Ryan's Daughter",
#   'genres': ['Drama', 'Romance', 'History'],
#   'year': '1970'},
#  {'name': 'The Lord of the Rings',
#   'genres': ['Adventure', 'Animation', 'Fantasy'],
#   'year': '1978'},
#  {'name': 'K', 'genres': ['misc'], 'year': '2002'},
#  {'name': 'What About Bob%3F', 'genres': ['misc'], 'year': '1991'},
#  {'name': 'Gridiron Gang', 'genres': ['Crime', 'Drama'], 'year': '2006'},
#  {'name': 'The Matrix Revisited', 'genres': ['Documentary'], 'year': 'None'},
#  {'name': 'Touch of Evil',
#   'genres': ['Crime', 'Thriller', 'Mystery'],
#   'year': '1958'},
#  {'name': 'Dance Flick',
#   'genres': ['Music', 'Comedy', 'Action'],
#   'year': '2009'},
#  {'name': 'Memories of Murder',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2003'},
#  {'name': 'The Unsinkable Molly Brown', 'genres': ['Comedy'], 'year': '1964'},
#  {'name': 'Heidi', 'genres': ['Drama', 'Family'], 'year': '2005'},
#  {'name': 'Miss You Already', 'genres': ['Comedy', 'Drama'], 'year': '2015'},
#  {'name': "It's a Wonderful Life",
#   'genres': ['Drama', 'Family', 'Fantasy'],
#   'year': '1946'},
#  {'name': 'Rachel Getting Married',
#   'genres': ['Drama', 'Romance'],
#   'year': '2008'},
#  {'name': 'Star Trek: First Contact',
#   'genres': ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#   'year': '1996'},
#  {'name': 'The Jungle Book',
#   'genres': ['Family', 'Animation', 'Adventure'],
#   'year': '1967'},
#  {'name': 'Dark Night', 'genres': ['Drama'], 'year': '2016'},
#  {'name': 'Come On, Leathernecks!',
#   'genres': ['Adventure', 'Drama', 'Romance'],
#   'year': '1938'},
#  {'name': 'Star Trek: Of Gods and Men', 'genres': ['misc'], 'year': 'None'},
#  {'name': 'Parenthood', 'genres': ['Comedy', 'Drama'], 'year': '1989'},
#  {'name': "Wayne's World", 'genres': ['Comedy', 'Music'], 'year': '1992'},
#  {'name': 'Alien Nation',
#   'genres': ['Science Fiction', 'Crime', 'Thriller'],
#   'year': '1988'},
#  {'name': 'Team Foxcatcher', 'genres': ['Documentary'], 'year': '2016'},
#  {'name': 'Hot Shots!', 'genres': ['Action', 'Comedy', 'War'], 'year': '1991'},
#  {'name': 'The Dark Half', 'genres': ['Mystery', 'Horror'], 'year': '1993'},
#  {'name': 'Sinbad: Legend of the Seven Seas',
#   'genres': ['Family',
#    'Animation',
#    'Adventure',
#    'Comedy',
#    'Fantasy',
#    'Action'],
#   'year': '2003'},
#  {'name': 'The Sea Wolves',
#   'genres': ['War', 'Action', 'Thriller'],
#   'year': '1980'},
#  {'name': 'South Park',
#   'genres': ['Animation', 'Comedy', 'Science Fiction', 'TV Movie'],
#   'year': 'None'},
#  {'name': 'The Game',
#   'genres': ['Drama', 'Thriller', 'Mystery'],
#   'year': '2010'},
#  {'name': 'Poseidon',
#   'genres': ['Adventure', 'Action', 'Drama', 'Thriller'],
#   'year': '2006'},
#  {'name': 'Missing Women', 'genres': ['Crime', 'Thriller'], 'year': '1951'},
#  {'name': 'Strange Brew', 'genres': ['Comedy'], 'year': '1983'},
#  {'name': 'The Kids Are All Right',
#   'genres': ['Comedy', 'Drama'],
#   'year': 'None'},
#  {'name': 'Revenge',
#   'genres': ['Thriller', 'Romance', 'Drama'],
#   'year': '1990'},
#  {'name': 'Why Him%3F', 'genres': ['misc'], 'year': '2016'},
#  {'name': 'I Love Me', 'genres': ['misc'], 'year': '2012'},
#  {'name': 'Queen of Katwe', 'genres': ['Drama'], 'year': '2016'},
#  {'name': 'Book of Shadows: Blair Witch 2',
#   'genres': ['Mystery', 'Thriller', 'Horror'],
#   'year': '2000'},
#  {'name': 'Inside Man',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2006'},
#  {'name': 'Are We Done Yet%3F', 'genres': ['misc'], 'year': '2007'},
#  {'name': 'Gods of Egypt',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'year': '2016'},
#  {'name': 'Ace Ventura: Pet Detective',
#   'genres': ['Comedy', 'Mystery'],
#   'year': '1994'},
#  {'name': 'Alien vs. Predator',
#   'genres': ['Adventure', 'Science Fiction', 'Action', 'Horror'],
#   'year': '2004'},
#  {'name': 'The Manchurian Candidate',
#   'genres': ['Thriller', 'Drama'],
#   'year': '1962'},
#  {'name': 'Star Wars Kid', 'genres': ['Documentary'], 'year': 'None'},
#  {'name': "Look Who's Talking",
#   'genres': ['Comedy', 'Romance'],
#   'year': '1989'},
#  {'name': 'Boo 2! A Madea Halloween',
#   'genres': ['Horror', 'Comedy'],
#   'year': '2017'},
#  {'name': 'Halloweentown',
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy', 'TV Movie'],
#   'year': 'None'},
#  {'name': 'Star Trek: Nemesis',
#   'genres': ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#   'year': '2002'},
#  {'name': 'Insidious', 'genres': ['Horror', 'Thriller'], 'year': 'None'},
#  {'name': 'Balto',
#   'genres': ['Family', 'Animation', 'Adventure'],
#   'year': '1995'},
#  {'name': 'All Eyez on Me',
#   'genres': ['History', 'Drama', 'Music'],
#   'year': 'None'},
#  {'name': 'Supergirl',
#   'genres': ['Adventure', 'Fantasy', 'Action', 'Science Fiction'],
#   'year': '1984'},
#  {'name': 'Extinction',
#   'genres': ['Action', 'Drama', 'Science Fiction', 'Thriller'],
#   'year': 'None'},
#  {'name': 'Wolf Creek', 'genres': ['Horror', 'Thriller'], 'year': '2005'},
#  {'name': 'Bird', 'genres': ['Drama', 'Music'], 'year': '1988'},
#  {'name': 'The Air I Breathe',
#   'genres': ['Thriller', 'Crime'],
#   'year': '2007'},
#  {'name': 'Amusement', 'genres': ['Horror', 'Mystery'], 'year': '2008'},
#  {'name': '48 Hours of Hallucinatory Sex', 'genres': ['misc'], 'year': '1987'},
#  {'name': 'Triple 9',
#   'genres': ['Action', 'Crime', 'Adventure', 'Thriller'],
#   'year': '2016'},
#  {'name': 'Step Up',
#   'genres': ['Music', 'Drama', 'Romance', 'Crime'],
#   'year': 'None'},
#  {'name': 'Their Finest',
#   'genres': ['Romance', 'War', 'Drama'],
#   'year': '2016'},
#  {'name': "101 Dalmatians II: Patch's London Adventure",
#   'genres': ['Family', 'Adventure', 'Comedy', 'Animation'],
#   'year': '2003'},
#  {'name': 'Above Suspicion', 'genres': ['Drama', 'Thriller'], 'year': '1995'},
#  {'name': 'Superhero Movie',
#   'genres': ['Comedy', 'Action', 'Science Fiction'],
#   'year': '2008'},
#  {'name': 'Fun Mom Dinner', 'genres': ['Comedy'], 'year': 'None'},
#  {'name': 'The Sandlot', 'genres': ['Family', 'Comedy'], 'year': '1993'},
#  {'name': "All's Faire in Love",
#   'genres': ['Comedy', 'Romance'],
#   'year': '2009'},
#  {'name': 'USS Indianapolis: Men of Courage',
#   'genres': ['Action', 'War'],
#   'year': 'None'},
#  {'name': 'Mean Streets', 'genres': ['Drama', 'Crime'], 'year': '1973'},
#  {'name': 'Arthur Christmas',
#   'genres': ['Drama', 'Animation', 'Family', 'Comedy'],
#   'year': '2011'},
#  {'name': 'Cold Mountain',
#   'genres': ['Drama', 'War', 'History', 'Adventure', 'Romance'],
#   'year': '2003'},
#  {'name': 'Keanu', 'genres': ['Action', 'Comedy', 'Crime'], 'year': '2016'},
#  {'name': 'My Big Fat Greek Wedding',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '2002'},
#  {'name': 'The Rock',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'year': '1996'},
#  {'name': 'Jump Tomorrow',
#   'genres': ['Drama', 'Comedy', 'Romance'],
#   'year': '2001'},
#  {'name': 'The Monkey King',
#   'genres': ['Action', 'Adventure', 'Family', 'Fantasy'],
#   'year': '2014'},
#  {'name': 'Notebook', 'genres': ['Romance', 'Drama'], 'year': 'None'},
#  {'name': 'Focus', 'genres': ['Romance', 'Comedy', 'Crime'], 'year': '2015'},
#  {'name': 'Pat Garrett and Billy the Kid',
#   'genres': ['Western'],
#   'year': '1973'},
#  {'name': 'Smiley Face', 'genres': ['Comedy'], 'year': '2007'},
#  {'name': 'Cowboys & Aliens',
#   'genres': ['Action', 'Science Fiction', 'Thriller', 'Western'],
#   'year': '2011'},
#  {'name': 'Captain America: Civil War',
#   'genres': ['Adventure', 'Action', 'Science Fiction'],
#   'year': '2016'},
#  {'name': 'The Tuxedo',
#   'genres': ['Thriller', 'Action', 'Comedy', 'Science Fiction'],
#   'year': '2002'},
#  {'name': 'Womb', 'genres': ['Romance', 'Science Fiction'], 'year': '2010'},
#  {'name': 'I Think I Love My Wife',
#   'genres': ['Comedy', 'Romance'],
#   'year': '2007'},
#  {'name': 'Gone in 60 Seconds', 'genres': ['Action', 'Crime'], 'year': '1974'},
#  {'name': 'Timecrimes',
#   'genres': ['Science Fiction', 'Thriller'],
#   'year': '2007'},
#  {'name': 'The Night of the Iguana',
#   'genres': ['Drama', 'Romance'],
#   'year': '1964'},
#  {'name': 'The 40-Year-Old Virgin',
#   'genres': ['Comedy', 'Romance'],
#   'year': '2005'},
#  {'name': 'Gladiatress',
#   'genres': ['Comedy', 'Adventure', 'Action'],
#   'year': '2004'},
#  {'name': 'The High and the Mighty',
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller'],
#   'year': '1954'},
#  {'name': 'Next of Kin', 'genres': ['Adventure', 'Action'], 'year': '1989'},
#  {'name': 'The People Under the Stairs',
#   'genres': ['Horror', 'Comedy'],
#   'year': '1991'},
#  {'name': 'Knights', 'genres': ['Action', 'Science Fiction'], 'year': '1993'},
#  {'name': 'Them', 'genres': ['Horror', 'Thriller'], 'year': '2006'},
#  {'name': 'When in Rome',
#   'genres': ['Adventure', 'Family', 'Romance'],
#   'year': '2002'},
#  {'name': 'Stonehearst Asylum',
#   'genres': ['Thriller', 'Mystery', 'Horror'],
#   'year': '2014'},
#  {'name': 'Despicable Me 2',
#   'genres': ['Animation', 'Comedy', 'Family'],
#   'year': '2013'},
#  {'name': 'Summer Holiday', 'genres': ['Music', 'Romance'], 'year': '1963'},
#  {'name': 'Analyze This', 'genres': ['Comedy', 'Crime'], 'year': '1999'},
#  {'name': 'T2', 'genres': ['Drama', 'Comedy'], 'year': '2017'},
#  {'name': 'Just Go with It', 'genres': ['Comedy', 'Romance'], 'year': '2011'},
#  {'name': 'Tom and Jerry: Spy Quest',
#   'genres': ['Animation', 'Family', 'Comedy'],
#   'year': '2015'},
#  {'name': 'Side Effects',
#   'genres': ['Thriller', 'Crime', 'Drama'],
#   'year': '2013'},
#  {'name': 'Lionheart', 'genres': ['Action'], 'year': '1990'},
#  {'name': 'Camp Rock',
#   'genres': ['Family', 'Music', 'Comedy', 'Drama', 'TV Movie', 'Romance'],
#   'year': 'None'},
#  {'name': 'Mortal Kombat: Annihilation',
#   'genres': ['Action', 'Fantasy', 'Science Fiction'],
#   'year': '1997'},
#  {'name': 'Titanic II',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'year': '2010'},
#  {'name': 'The Sniper', 'genres': ['Action', 'Thriller'], 'year': '2009'},
#  {'name': 'Diablo',
#   'genres': ['Action', 'Adventure', 'Thriller', 'Western'],
#   'year': '2015'},
#  {'name': 'Hard Target',
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller'],
#   'year': '1993'},
#  {'name': 'The New Guy', 'genres': ['Comedy'], 'year': '2002'},
#  {'name': 'Spawn',
#   'genres': ['Action',
#    'Adventure',
#    'Fantasy',
#    'Horror',
#    'Science Fiction',
#    'Thriller'],
#   'year': '1997'},
#  {'name': "Girls' Night", 'genres': ['Comedy', 'Drama'], 'year': '1998'},
#  {'name': 'Superbad', 'genres': ['Comedy'], 'year': '2007'},
#  {'name': 'Where the Red Fern Grows',
#   'genres': ['Drama', 'Family'],
#   'year': '2003'},
#  {'name': 'Larry the Cable Guy: Health Inspector',
#   'genres': ['Comedy'],
#   'year': '2006'},
#  {'name': 'The Hungover Games', 'genres': ['Comedy'], 'year': '2014'},
#  {'name': 'The Death of Stalin',
#   'genres': ['Comedy', 'Drama', 'History'],
#   'year': 'None'},
#  {'name': 'The Killer Inside Me',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '2010'},
#  {'name': 'Invictus', 'genres': ['Drama', 'History'], 'year': '2009'},
#  {'name': 'Twister', 'genres': ['Drama', 'Comedy'], 'year': '1989'},
#  {'name': 'Ewoks: The Battle for Endor',
#   'genres': ['Adventure', 'Family', 'TV Movie', 'Science Fiction', 'Fantasy'],
#   'year': 'None'},
#  {'name': 'Life', 'genres': ['Comedy', 'Crime'], 'year': '1999'},
#  {'name': 'I Love You to Death',
#   'genres': ['Comedy', 'Crime'],
#   'year': '1990'},
#  {'name': 'Me Before You', 'genres': ['Drama', 'Romance'], 'year': 'None'},
#  {'name': 'Hustle & Flow',
#   'genres': ['Crime', 'Drama', 'Music'],
#   'year': '2005'},
#  {'name': 'Face/Off',
#   'genres': ['Action', 'Crime', 'Science Fiction'],
#   'year': '1997'},
#  {'name': 'Fallen', 'genres': ['Crime', 'Drama', 'Thriller'], 'year': '1998'},
#  {'name': 'No Escape',
#   'genres': ['Crime', 'Drama', 'Romance'],
#   'year': '1953'},
#  {'name': 'Superbeast',
#   'genres': ['Science Fiction', 'Horror'],
#   'year': '1972'},
#  {'name': 'I Love You Phillip Morris',
#   'genres': ['Comedy', 'Crime', 'Drama', 'Romance'],
#   'year': '2009'},
#  {'name': 'Becoming Jane', 'genres': ['Romance', 'Drama'], 'year': '2007'},
#  {'name': 'Free Willy 2: The Adventure Home',
#   'genres': ['Family', 'Adventure', 'Drama'],
#   'year': '1995'},
#  {'name': 'Hudson Hawk',
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'year': '1991'},
#  {'name': 'Candyman: Farewell to the Flesh',
#   'genres': ['Horror', 'Thriller'],
#   'year': '1995'},
#  {'name': 'Casablanca, Casablanca',
#   'genres': ['Drama', 'Romance'],
#   'year': '1985'},
#  {'name': 'Lakeview Terrace',
#   'genres': ['Drama', 'Crime', 'Thriller'],
#   'year': '2008'},
#  {'name': 'Bats',
#   'genres': ['Horror', 'Thriller', 'Science Fiction'],
#   'year': '1999'},
#  {'name': 'Krampus',
#   'genres': ['Horror', 'Comedy', 'Fantasy'],
#   'year': '2015'},
#  {'name': 'Water for Elephants',
#   'genres': ['Drama', 'Romance'],
#   'year': '2011'},
#  {'name': 'Wind in the Willows',
#   'genres': ['Fantasy', 'Drama', 'Science Fiction', 'Family', 'Animation'],
#   'year': '1988'},
#  {'name': 'Fools Rush In',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1997'},
#  {'name': 'Blood Simple',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'year': '1984'},
#  {'name': 'The Horse Whisperer',
#   'genres': ['Adventure', 'Drama', 'Romance'],
#   'year': '1998'},
#  {'name': 'Forget Paris',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1995'},
#  {'name': 'Abraham Lincoln: Vampire Hunter',
#   'genres': ['Action', 'Fantasy', 'Horror'],
#   'year': '2012'},
#  {'name': 'My Cousin Vinny', 'genres': ['Comedy'], 'year': '1992'},
#  {'name': 'The Nun',
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'year': '2018'},
#  {'name': 'One Day in September', 'genres': ['Documentary'], 'year': '1999'},
#  {'name': 'The Love Bug',
#   'genres': ['Comedy', 'Family', 'Fantasy'],
#   'year': '1968'},
#  {'name': 'The Pit and the Pendulum',
#   'genres': ['Fantasy', 'Horror', 'Thriller'],
#   'year': '2009'},
#  {'name': 'Space Cop', 'genres': ['misc'], 'year': '2016'},
#  {'name': 'Red Dragon',
#   'genres': ['Crime', 'Thriller', 'Horror'],
#   'year': '2002'},
#  {'name': 'Displaced', 'genres': ['misc'], 'year': '2010'},
#  {'name': 'Wild Canaries',
#   'genres': ['Comedy', 'Mystery', 'Romance'],
#   'year': '2014'},
#  {'name': 'When Marnie Was There',
#   'genres': ['Animation', 'Drama'],
#   'year': 'None'},
#  {'name': 'Blade II',
#   'genres': ['Fantasy', 'Horror', 'Action', 'Thriller'],
#   'year': '2002'},
#  {'name': 'The Age of Innocence',
#   'genres': ['Drama', 'Romance'],
#   'year': '1993'},
#  {'name': 'United 93',
#   'genres': ['Drama', 'History', 'Crime', 'Thriller', 'Action'],
#   'year': '2006'},
#  {'name': 'Mother', 'genres': ['Documentary'], 'year': '2009'},
#  {'name': 'War', 'genres': ['Romance', 'Drama'], 'year': '2014'},
#  {'name': 'Goodbye Solo', 'genres': ['Drama'], 'year': '2008'},
#  {'name': 'Josie and the Pussycats',
#   'genres': ['Comedy', 'Music'],
#   'year': '2001'},
#  {'name': 'Cop',
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   'year': '1988'},
#  {'name': 'Outland', 'genres': ['Science Fiction', 'Action'], 'year': '1981'},
#  {'name': 'Antz',
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'year': '1998'},
#  {'name': 'Tulip Fever', 'genres': ['Drama', 'Romance'], 'year': '2017'},
#  {'name': "Mr. Bean's Holiday",
#   'genres': ['Family', 'Comedy'],
#   'year': '2007'},
#  {'name': 'The Worst of Faces of Death',
#   'genres': ['Documentary', 'Horror'],
#   'year': '1987'},
#  {'name': 'The Eyes of My Mother',
#   'genres': ['Drama', 'Horror'],
#   'year': '2016'},
#  {'name': 'The Best Little Whorehouse in Texas',
#   'genres': ['Comedy'],
#   'year': '1982'},
#  {'name': 'American Graffiti', 'genres': ['Comedy', 'Drama'], 'year': '1973'},
#  {'name': 'Confessions of a Shopaholic',
#   'genres': ['Comedy', 'Romance'],
#   'year': '2009'},
#  {'name': 'I Heart Huckabees',
#   'genres': ['Comedy', 'Romance'],
#   'year': '2004'},
#  {'name': 'Three Days',
#   'genres': ['Family', 'Fantasy', 'Drama', 'TV Movie'],
#   'year': '2001'},
#  {'name': 'Air Bud', 'genres': ['Comedy', 'Family'], 'year': 'None'},
#  {'name': 'Love Potion No. 9',
#   'genres': ['Comedy', 'Romance', 'Fantasy', 'Science Fiction'],
#   'year': '1992'},
#  {'name': 'Sleepy Hollow',
#   'genres': ['Drama', 'Fantasy', 'Thriller', 'Mystery', 'Horror'],
#   'year': '1999'},
#  {'name': 'Zombeavers',
#   'genres': ['Horror', 'Action', 'Comedy'],
#   'year': '2014'},
#  {'name': 'Loved', 'genres': ['Drama', 'Thriller'], 'year': '1997'},
#  {'name': 'Soul Food', 'genres': ['Comedy', 'Drama'], 'year': '1997'},
#  {'name': 'A Christmas Carol',
#   'genres': ['Animation', 'Family', 'Fantasy'],
#   'year': '2009'},
#  {'name': 'The Expendables 3',
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'year': '2014'},
#  {'name': 'Just Wright',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '2010'},
#  {'name': 'Little Men', 'genres': ['Drama'], 'year': '2016'},
#  {'name': "The Warrior's Way",
#   'genres': ['Adventure', 'Fantasy', 'Action', 'Western', 'Thriller'],
#   'year': 'None'},
#  {'name': 'Saint Ange', 'genres': ['Horror', 'Mystery'], 'year': '2004'},
#  {'name': 'FernGully: The Last Rainforest',
#   'genres': ['Family', 'Fantasy', 'Animation', 'Adventure'],
#   'year': 'None'},
#  {'name': 'Love at Sea', 'genres': ['misc'], 'year': '1936'},
#  {'name': 'A Serbian Film',
#   'genres': ['Crime', 'Horror', 'Thriller'],
#   'year': '2010'},
#  {'name': "The Man Who Wasn't There", 'genres': ['misc'], 'year': '1987'},
#  {'name': 'Captain America: The Winter Soldier',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': 'None'},
#  {'name': 'Spider-Man 2',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'year': '2004'},
#  {'name': 'Kiss of the Dragon',
# ...
#   'genres': ['Thriller', 'Science Fiction', 'Drama'],
#   'year': '1983'},
#  {'name': 'Holy Water', 'genres': ['Comedy'], 'year': '2009'},
#  {'name': 'Lucky Logan',
#   'genres': ['Comedy', 'Crime', 'Action', 'Drama'],
#   'year': '2017'},
#  {'name': 'Turtles Can Fly', 'genres': ['Drama'], 'year': '2004'},
#  {'name': 'The Haunted World of El Superbeasto',
#   'genres': ['Animation', 'Horror', 'Action', 'Comedy'],
#   'year': '2009'},
#  {'name': 'Kevin Hart: Let Me Explain',
#   'genres': ['Comedy', 'Documentary'],
#   'year': '2013'},
#  {'name': 'Heathers', 'genres': ['misc'], 'year': '1988'},
#  {'name': 'The Grinch',
#   'genres': ['Animation', 'Family', 'Comedy', 'Fantasy'],
#   'year': '2018'},
#  {'name': 'House of Games',
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   'year': '1987'},
#  {'name': 'Population 436', 'genres': ['Horror', 'Thriller'], 'year': '2006'},
#  {'name': 'Teen Beach Movie',
#   'genres': ['Family', 'Music', 'TV Movie', 'Comedy'],
#   'year': 'None'},
#  {'name': 'The Entity', 'genres': ['misc'], 'year': '1981'},
#  {'name': 'Mr. Deeds', 'genres': ['Comedy', 'Romance'], 'year': '2002'},
#  {'name': 'The Giver', 'genres': ['Drama', 'Science Fiction'], 'year': '2014'},
#  {'name': 'Valentine', 'genres': ['Horror', 'Thriller'], 'year': '2001'},
#  {'name': 'Gnomes',
#   'genres': ['Animation', 'Fantasy', 'Family', 'TV Movie'],
#   'year': 'None'},
#  {'name': 'Allied',
#   'genres': ['Action', 'Drama', 'War', 'Romance', 'Thriller'],
#   'year': '2016'},
#  {'name': 'Argo', 'genres': ['Drama', 'Thriller'], 'year': '2012'},
#  {'name': 'Break-Up', 'genres': ['Romance', 'Comedy'], 'year': '2014'},
#  {'name': 'Percy Jackson',
#   'genres': ['Adventure', 'Fantasy', 'Family'],
#   'year': 'None'},
#  {'name': 'Ratatouille',
#   'genres': ['Animation', 'Comedy', 'Family', 'Fantasy'],
#   'year': '2007'},
#  {'name': 'Psycho',
#   'genres': ['Mystery', 'Thriller', 'Horror'],
#   'year': '1998'},
#  {'name': "Ocean's 8",
#   'genres': ['Crime', 'Comedy', 'Action'],
#   'year': '2018'},
#  {'name': 'Warcraft',
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'year': '2016'},
#  {'name': 'Star Trek Generations',
#   'genres': ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#   'year': '1994'},
#  {'name': 'Hollywood Shuffle', 'genres': ['Comedy'], 'year': '1987'},
#  {'name': 'Coach Carter', 'genres': ['Drama', 'History'], 'year': '2005'},
#  {'name': 'The Reader', 'genres': ['Drama', 'Romance'], 'year': '2008'},
#  {'name': 'Dunkirk', 'genres': ['Drama', 'War'], 'year': '1958'},
#  {'name': 'The Good, the Bad and the Ugly',
#   'genres': ['Western'],
#   'year': '1966'},
#  {'name': 'The Motorcycle Diaries', 'genres': ['Drama'], 'year': '2004'},
#  {'name': 'Safety Not Guaranteed',
#   'genres': ['Comedy', 'Romance', 'Science Fiction'],
#   'year': '2012'},
#  {'name': 'Ice Age: Dawn of the Dinosaurs',
#   'genres': ['Animation', 'Comedy', 'Family', 'Adventure'],
#   'year': '2009'},
#  {'name': 'Yellow Submarine',
#   'genres': ['Music', 'Animation', 'Adventure', 'Comedy', 'Fantasy'],
#   'year': '1968'},
#  {'name': 'I, Robot', 'genres': ['Action', 'Science Fiction'], 'year': '2004'},
#  {'name': 'The Expendables',
#   'genres': ['Thriller', 'Adventure', 'Action'],
#   'year': 'None'},
#  {'name': 'Born to Be Wild',
#   'genres': ['Documentary', 'Adventure'],
#   'year': '2011'},
#  {'name': 'Eight Below',
#   'genres': ['Adventure', 'Drama', 'Family'],
#   'year': '2006'},
#  {'name': 'Reds', 'genres': ['Drama', 'History', 'Romance'], 'year': '1981'},
#  {'name': 'The Longest Yard', 'genres': ['Comedy'], 'year': '2005'},
#  {'name': 'Sneakers', 'genres': ['Comedy', 'Crime', 'Drama'], 'year': '1992'},
#  {'name': 'Altered Carbon', 'genres': ['misc'], 'year': '2018'},
#  {'name': 'Jurassic Park III',
#   'genres': ['Adventure', 'Action', 'Thriller', 'Science Fiction'],
#   'year': '2001'},
#  {'name': 'Grimm', 'genres': ['Drama', 'Comedy', 'Adventure'], 'year': '2003'},
#  {'name': 'Paranormal Activity 4', 'genres': ['Horror'], 'year': '2012'},
#  {'name': 'Hollow', 'genres': ['Mystery', 'Horror', 'Drama'], 'year': '2014'},
#  {'name': 'Do You Believe in Magic',
#   'genres': ['Documentary'],
#   'year': '2008'},
#  {'name': 'Student Bodies', 'genres': ['Comedy', 'Horror'], 'year': '1981'},
#  {'name': 'The Thin Man',
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'year': '1934'},
#  {'name': 'Dragonslayer', 'genres': ['Fantasy', 'Adventure'], 'year': '1981'},
#  {'name': 'Son of Flubber',
#   'genres': ['Comedy', 'Family', 'Science Fiction'],
#   'year': '1963'},
#  {'name': 'Tokusou Sentai Dekaranger The Movie: Full Blast Action',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'Crime'],
#   'year': '2004'},
#  {'name': 'The Queen',
#   'genres': ['Drama', 'Fantasy', 'Horror'],
#   'year': '2012'},
#  {'name': 'The River Wild',
#   'genres': ['Adventure', 'Thriller'],
#   'year': '1994'},
#  {'name': 'Encounters of the Spooky Kind',
#   'genres': ['Action', 'Comedy', 'Fantasy', 'Horror'],
#   'year': '1980'},
#  {'name': 'Two for the Road',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1967'},
#  {'name': 'Leprechaun 3', 'genres': ['Comedy', 'Horror'], 'year': '1995'},
#  {'name': 'The Watch',
#   'genres': ['Comedy', 'Action', 'Science Fiction'],
#   'year': '2012'},
#  {'name': 'The Patriots', 'genres': ['Drama', 'Crime'], 'year': '1994'},
#  {'name': 'Daddy Day Camp', 'genres': ['Family', 'Comedy'], 'year': '2007'},
#  {'name': "Look Who's Talking Now",
#   'genres': ['Romance', 'Comedy', 'Family'],
#   'year': '1993'},
#  {'name': 'Commando 2', 'genres': ['Action', 'Thriller'], 'year': '2017'},
#  {'name': 'The Hatching', 'genres': ['Crime', 'Thriller'], 'year': '2016'},
#  {'name': 'The Cobbler',
#   'genres': ['Fantasy', 'Comedy', 'Drama'],
#   'year': '2014'},
#  {'name': 'Guardians of the Galaxy',
#   'genres': ['Action', 'Science Fiction', 'Adventure'],
#   'year': '2014'},
#  {'name': 'Knocked Up',
#   'genres': ['Comedy', 'Romance', 'Drama'],
#   'year': '2007'},
#  {'name': 'Lone Wolf and Cub: Sword of Vengeance',
#   'genres': ['Drama', 'Action'],
#   'year': '1972'},
#  {'name': 'Happy Madison Productions', 'genres': ['misc'], 'year': 'None'},
#  {'name': 'I Spit on Your Grave 2',
#   'genres': ['Thriller', 'Horror', 'Crime'],
#   'year': '2013'},
#  {'name': 'Funny Face',
#   'genres': ['Comedy', 'Romance', 'Music'],
#   'year': '1957'},
#  {'name': 'Annabelle', 'genres': ['Horror'], 'year': '2014'},
#  {'name': 'Death at a Funeral', 'genres': ['Comedy', 'Drama'], 'year': '2007'},
#  {'name': 'Head Above Water',
#   'genres': ['Comedy', 'Thriller'],
#   'year': '1996'},
#  {'name': "Daddy's Little Girls",
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '2007'},
#  {'name': 'Super Troopers 2',
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'year': '2018'},
#  {'name': 'Prom Night',
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'year': '1980'},
#  {'name': 'Only the Brave', 'genres': ['Drama', 'Action'], 'year': '2017'},
#  {'name': 'The Cincinnati Kid', 'genres': ['Drama'], 'year': '1965'},
#  {'name': 'The Big Wedding', 'genres': ['Comedy'], 'year': '2013'},
#  {'name': 'Foul Play', 'genres': ['Comedy', 'Drama'], 'year': '1977'},
#  {'name': 'The Computer Wore Tennis Shoes',
#   'genres': ['Comedy', 'Family', 'Drama'],
#   'year': '1969'},
#  {'name': 'The Magnificent Seven',
#   'genres': ['Adventure', 'Action', 'Western'],
#   'year': '2016'},
#  {'name': 'Kevin Hart: What Now%3F', 'genres': ['misc'], 'year': '2016'},
#  {'name': 'Zombieland', 'genres': ['Comedy', 'Horror'], 'year': '2009'},
#  {'name': 'Indiana Jones', 'genres': ['Adventure', 'Action'], 'year': 'None'},
#  {'name': 'The Dilemma', 'genres': ['Comedy', 'Drama'], 'year': 'None'},
#  {'name': 'Speed', 'genres': ['Documentary'], 'year': '1984'},
#  {'name': 'Little England', 'genres': ['Drama', 'Romance'], 'year': 'None'},
#  {'name': 'Men in Black', 'genres': ['Comedy'], 'year': '1934'},
#  {'name': 'The Fifth Seal', 'genres': ['Drama', 'War'], 'year': '1976'},
#  {'name': 'The Bad News Bears',
#   'genres': ['Family', 'Comedy'],
#   'year': '1976'},
#  {'name': 'Corpse Bride',
#   'genres': ['Romance', 'Fantasy', 'Animation'],
#   'year': '2005'},
#  {'name': 'The Princess Diaries 2: Royal Engagement',
#   'genres': ['Comedy', 'Drama', 'Family', 'Romance'],
#   'year': '2004'},
#  {'name': 'The Lovers',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'Romance'],
#   'year': '2017'},
#  {'name': 'Casting JonBenet',
#   'genres': ['Documentary', 'Crime'],
#   'year': '2017'},
#  {'name': 'Nora', 'genres': ['Drama'], 'year': '1944'},
#  {'name': "2016: Obama's America",
#   'genres': ['Documentary', 'Fantasy'],
#   'year': '2012'},
#  {'name': 'My Friend Dahmer',
#   'genres': ['History', 'Drama', 'Crime', 'Horror'],
#   'year': 'None'},
#  {'name': 'Ten Dead Men', 'genres': ['Action', 'Thriller'], 'year': '2008'},
#  {'name': 'Pinocchio', 'genres': ['Animation', 'Family'], 'year': '2012'},
#  {'name': 'Days of Glory',
#   'genres': ['Drama', 'History', 'War'],
#   'year': '2006'},
#  {'name': 'Get Over It', 'genres': ['Comedy', 'Romance'], 'year': '2001'},
#  {'name': 'Dirty Mary, Crazy Larry',
#   'genres': ['Action', 'Adventure', 'Crime', 'Comedy'],
#   'year': '1974'},
#  {'name': 'Because of You', 'genres': ['Drama', 'Romance'], 'year': '1952'},
#  {'name': 'Mansfield Park', 'genres': ['Romance', 'Drama'], 'year': '1999'},
#  {'name': 'Hauling', 'genres': ['misc'], 'year': '2010'},
#  {'name': 'Fatal Attraction', 'genres': ['Drama', 'Thriller'], 'year': '1987'},
#  {'name': 'Requiem', 'genres': ['misc'], 'year': '1995'},
#  {'name': 'Hotel Artemis',
#   'genres': ['Thriller', 'Science Fiction', 'Action'],
#   'year': '2018'},
#  {'name': 'Oliver & Company',
#   'genres': ['Animation', 'Comedy', 'Family'],
#   'year': 'None'},
#  {'name': 'Hostage',
#   'genres': ['Action', 'Thriller', 'Crime'],
#   'year': 'None'},
#  {'name': 'Bowfinger', 'genres': ['Comedy'], 'year': '1999'},
#  {'name': "Lady and the Tramp II: Scamp's Adventure",
#   'genres': ['Family', 'Animation', 'Romance', 'Adventure'],
#   'year': '2001'},
#  {'name': 'When the Bough Breaks',
#   'genres': ['Mystery', 'Thriller', 'Drama', 'Horror'],
#   'year': '2016'},
#  {'name': 'The Matador', 'genres': ['Documentary'], 'year': '2008'},
#  {'name': 'For the Love of Spock', 'genres': ['Documentary'], 'year': '2016'},
#  {'name': 'Girls Will Be Girls', 'genres': ['Comedy'], 'year': '2003'},
#  {'name': "Wes Craven's Chiller", 'genres': ['misc'], 'year': '1985'},
#  {'name': 'Capturing the Friedmans',
#   'genres': ['Documentary'],
#   'year': '2003'},
#  {'name': 'The Proposal',
#   'genres': ['Comedy', 'Romance', 'Drama'],
#   'year': '2009'},
#  {'name': 'K-9', 'genres': ['Action', 'Comedy', 'Crime'], 'year': '1989'},
#  {'name': 'Be Cool', 'genres': ['Comedy', 'Crime'], 'year': '2005'},
#  {'name': 'The Swan Princess',
#   'genres': ['Family', 'Animation', 'Fantasy', 'Adventure', 'Comedy'],
#   'year': '1994'},
#  {'name': 'G.I. Blues', 'genres': ['Comedy', 'Music'], 'year': '1960'},
#  {'name': 'Horton Hears a Who!',
#   'genres': ['Animation', 'Comedy', 'Family', 'Adventure', 'Fantasy'],
#   'year': '2008'},
#  {'name': 'Attack on Titan',
#   'genres': ['Horror', 'Fantasy', 'Action', 'Science Fiction'],
#   'year': '2015'},
#  {'name': 'Disobedience', 'genres': ['misc'], 'year': '2003'},
#  {'name': 'Zero Effect',
#   'genres': ['Comedy', 'Crime', 'Mystery', 'Thriller'],
#   'year': '1998'},
#  {'name': 'Super 8',
#   'genres': ['Thriller', 'Science Fiction', 'Mystery'],
#   'year': '2011'},
#  {'name': "Pirates of the Caribbean: At World's End",
#   'genres': ['Adventure', 'Fantasy', 'Action'],
#   'year': '2007'},
#  {'name': 'Pacquiao: The Movie',
#   'genres': ['Drama', 'Action'],
#   'year': '2006'},
#  {'name': 'City of Men', 'genres': ['Drama'], 'year': '2007'},
#  {'name': 'Man of Steel',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': '2013'},
#  {'name': 'Return of the Jedi',
#   'genres': ['Adventure', 'Action', 'Science Fiction'],
#   'year': '1983'},
#  {'name': 'Guys and Dolls',
#   'genres': ['Comedy', 'Crime', 'Romance'],
#   'year': '1955'},
#  {'name': 'An American in Madras', 'genres': ['Documentary'], 'year': '2013'},
#  {'name': 'Insidious', 'genres': ['Horror', 'Thriller'], 'year': '2011'},
#  {'name': 'Rabbits',
#   'genres': ['Horror', 'Mystery', 'Comedy'],
#   'year': '2002'},
#  {'name': 'Silver Streak',
#   'genres': ['Comedy', 'Crime', 'Romance', 'Thriller'],
#   'year': '1976'},
#  {'name': 'Riddick',
#   'genres': ['Science Fiction', 'Action', 'Thriller'],
#   'year': '2013'},
#  {'name': 'To Kill a Mockingbird', 'genres': ['Drama'], 'year': '1962'},
#  {'name': 'Trouble with the Curve',
#   'genres': ['Drama', 'Romance'],
#   'year': '2012'},
#  {'name': 'A Night in Casablanca', 'genres': ['Comedy'], 'year': '1946'},
#  {'name': 'Empire of the Ants',
#   'genres': ['Horror', 'Science Fiction'],
#   'year': '1977'},
#  {'name': 'Batman', 'genres': ['Fantasy', 'Action', 'Crime'], 'year': '1989'},
#  {'name': 'Bombing the Nazis', 'genres': ['misc'], 'year': '1943'},
#  {'name': 'Cosmos', 'genres': ['Drama'], 'year': '2010'},
#  {'name': '2012',
#   'genres': ['Action', 'Adventure', 'Science Fiction'],
#   'year': '2009'},
#  {'name': 'Sleeping Beauty',
#   'genres': ['Fantasy', 'Animation', 'Romance', 'Family'],
#   'year': '1995'},
#  {'name': 'Going Clear', 'genres': ['Documentary'], 'year': '2015'},
#  {'name': 'Mystic Pizza',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'year': '1988'},
#  {'name': 'The Transformers: The Movie',
#   'genres': ['Animation', 'Science Fiction', 'Action', 'Adventure', 'Family'],
#   'year': 'None'},
#  {'name': "Good Luck Charlie, It's Christmas!",
#   'genres': ['TV Movie', 'Comedy', 'Family'],
#   'year': '2011'},
#  {'name': "The 'Burbs",
#   'genres': ['Comedy', 'Horror', 'Thriller'],
#   'year': '1989'},
#  {'name': 'The Music Man',
#   'genres': ['Comedy', 'Family', 'Music', 'Romance'],
#   'year': '1962'},
#  {'name': 'Deathtrap',
#   'genres': ['Comedy', 'Mystery', 'Thriller'],
#   'year': '1982'},
#  {'name': 'Absolute Beginners',
#   'genres': ['Drama', 'Music', 'Romance'],
#   'year': '1986'},
#  {'name': 'The Cat Returns',
#   'genres': ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Family'],
#   'year': 'None'},
#  {'name': 'Victoria and Abdul',
#   'genres': ['Drama', 'History'],
#   'year': 'None'},
#  {'name': 'A Perfect Getaway',
#   'genres': ['Thriller', 'Mystery', 'Adventure'],
#   'year': '2009'},
#  {'name': 'The Wicker Man',
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'year': '2006'},
#  {'name': 'Dead Before Dawn',
#   'genres': ['Adventure', 'Comedy', 'Horror'],
#   'year': '2012'},
#  {'name': 'The Last Starfighter',
#   'genres': ['Adventure', 'Science Fiction', 'Action'],
#   'year': '1984'},
#  {'name': 'Out of the Furnace',
#   'genres': ['Thriller', 'Drama', 'Crime'],
#   'year': '2013'},
#  {'name': 'Napping Princess',
#   'genres': ['Fantasy', 'Adventure', 'Animation', 'Drama', 'Science Fiction'],
#   'year': '2017'},
#  {'name': 'American Psycho',
#   'genres': ['Thriller', 'Drama', 'Crime'],
#   'year': '2000'},
#  {'name': 'Pitch Perfect 3', 'genres': ['Comedy', 'Music'], 'year': '2017'},
#  {'name': 'Vantage Point',
#   'genres': ['Drama', 'Action', 'Thriller', 'Crime'],
#   'year': '2008'},
#  {'name': 'Terms of Endearment',
#   'genres': ['Drama', 'Comedy'],
#   'year': '1983'},
#  {'name': "Michael Lucas' La Dolce Vita", 'genres': ['misc'], 'year': '2006'},
#  {'name': 'Soul Plane', 'genres': ['Romance', 'Comedy'], 'year': '2004'},
#  {'name': 'The Outlaws', 'genres': ['Drama'], 'year': '1950'},
#  {'name': 'The Hunted', 'genres': ['Thriller'], 'year': '2013'},
#  {'name': 'Boxing Helena',
#   'genres': ['Drama', 'Romance', 'Thriller', 'Horror'],
#   'year': '1993'},
#  {'name': 'Halloween', 'genres': ['Horror', 'Thriller'], 'year': '1978'},
#  {'name': 'The Da Vinci Code',
#   'genres': ['Thriller', 'Mystery'],
#   'year': '2006'},
#  {'name': "The Slammin' Salmon", 'genres': ['Comedy'], 'year': '2009'},
#  {'name': 'Sabotage',
#   'genres': ['Action', 'Drama', 'Thriller', 'Crime'],
#   'year': '2014'},
#  {'name': 'Star Trek II: The Wrath of Khan',
#   'genres': ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#   'year': '1982'},
#  {'name': 'The Constant Gardener',
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'year': '2005'},
#  {'name': 'Date Night',
#   'genres': ['Comedy', 'Action', 'Adventure'],
#   'year': '2010'},
#  {'name': 'A Very Long Engagement',
#   'genres': ['Drama', 'Romance', 'War'],
#   'year': '2004'},
#  ...]

# %%
filtered_data = relations_data

print(filtered_data)
# Out:
# [{'name': "Charlotte's Web", 'genres': ['Comedy', 'Family', 'Fantasy'], 'year': '2006'}, {'name': 'Everything You Always Wanted to Know About Sex*', 'genres': ['Comedy'], 'year': '1972'}, {'name': 'Rock-a-Doodle', 'genres': ['Comedy', 'Family', 'Animation', 'Fantasy', 'Music'], 'year': '1991'}, {'name': 'Too Late', 'genres': ['Drama', 'Crime', 'Mystery'], 'year': 'None'}, {'name': 'Law Abiding Citizen', 'genres': ['Drama', 'Crime', 'Thriller'], 'year': '2009'}, {'name': 'The Black Mask', 'genres': ['Crime'], 'year': '1935'}, {'name': 'Club Dread', 'genres': ['Comedy', 'Horror'], 'year': '2004'}, {'name': 'Moana', 'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'], 'year': 'None'}, {'name': 'Signs', 'genres': ['Drama', 'Thriller', 'Science Fiction', 'Mystery'], 'year': '2002'}, {'name': 'Beyond the Valley of the Dolls', 'genres': ['Comedy', 'Drama', 'Music'], 'year': '1970'}, {'name': 'Beastly', 'genres': ['Drama', 'Fantasy', 'Romance'], 'year': '2011'}, {'name': 'Victoria', 'genres': ['Crime', 'Thriller', 'Romance'], 'year': '2015'}, {'name': 'The Duel', 'genres': ['Western', 'Drama'], 'year': '2016'}, {'name': 'American Ninja 2: The Confrontation', 'genres': ['Action'], 'year': '1987'}, {'name': 'Earth to Echo', 'genres': ['Family', 'Adventure', 'Science Fiction'], 'year': '2014'}, {'name': 'Amélie', 'genres': ['Comedy', 'Romance'], 'year': '2001'}, {'name': 'Born Free', 'genres': ['Adventure'], 'year': '1966'}, {'name': 'Son in Law', 'genres': ['Comedy', 'Drama', 'Romance'], 'year': '1993'}, {'name': 'Killer Klowns from Outer Space', 'genres': ['Comedy', 'Horror', 'Science Fiction'], 'year': '1988'}, {'name': 'Holiday Inn', 'genres': ['Comedy', 'Drama', 'Romance'], 'year': '1942'}, {'name': 'Dracula Untold', 'genres': ['Horror', 'Action', 'Fantasy'], 'year': '2014'}, {'name': 'Tom and Jerry: The Fast and the Furry', 'genres': ['Family', 'Animation', 'Comedy', 'Action', 'Adventure'], 'year': 'None'}, {'name': 'Shanghai Knights', 'genres': ['Action', 'Adventure', 'Comedy', 'Western'], 'year': '2003'}, {'name': 'Dirty Dancing: Havana Nights', 'genres': ['Drama', 'Romance'], 'year': 'None'}, {'name': 'Ghost in the Shell: Stand Alone Complex - Solid State Society', 'genres': ['Animation', 'Action', 'Thriller', 'Crime', 'Science Fiction'], 'year': '2006'}, {'name': 'Chasing Mavericks', 'genres': ['Drama'], 'year': '2012'}, {'name': "Sophie's Choice", 'genres': ['Drama', 'Romance', 'War'], 'year': '1982'}, {'name': 'Secondhand Lions', 'genres': ['Family', 'Comedy'], 'year': '2003'}, {'name': 'Rio 2', 'genres': ['Animation', 'Adventure', 'Comedy', 'Family'], 'year': '2014'}, {'name': 'Places in the Heart', 'genres': ['Drama'], 'year': '1984'}, {'name': 'The Incident', 'genres': ['Horror', 'Thriller'], 'year': '2011'}, {'name': 'Police Story 2', 'genres': ['misc'], 'year': '2007'}, {'name': 'Not Fade Away', 'genres': ['Drama'], 'year': '2012'}, {'name': 'In the Mood for Love', 'genres': ['Drama', 'Romance'], 'year': '2000'}, {'name': 'Kaizoku Sentai Gokaiger the Movie: The Flying Ghost Ship', 'genres': ['Action', 'Adventure', 'Science Fiction', 'Fantasy', 'Horror'], 'year': '2011'}, {'name': 'To Live and Die in L.A.', 'genres': ['Crime', 'Thriller', 'Action'], 'year': '1985'}, {'name': 'The Young Guns', 'genres': ['Western'], 'year': '1956'}, {'name': 'Secret Window', 'genres': ['Mystery', 'Thriller'], 'year': '2004'}, {'name': 'Ladybird, Ladybird', 'genres': ['Drama'], 'year': '1994'}, {'name': 'Robot Stories', 'genres': ['Drama', 'Science Fiction', 'Romance'], 'year': '2003'}, {'name': 'Amelia', 'genres': ['Adventure', 'Drama'], 'year': '2009'}, {'name': '21', 'genres': ['Drama', 'Crime'], 'year': '2008'}, {'name': 'The Rocky Horror Picture Show', 'genres': ['Comedy', 'Science Fiction', 'Fantasy', 'Horror'], 'year': '1975'}, {'name': 'Curse of Chucky', 'genres': ['Horror', 'Thriller'], 'year': '2013'}, {'name': 'Timeline', 'genres': ['Action', 'Adventure', 'Science Fiction'], 'year': '2003'}, {'name': 'Picnic at Hanging Rock',  ...

# %%
unique_genres = set()

for movie in filtered_data:
    unique_genres.update(movie['genres'])

unique_genres_list = list(unique_genres)

print(unique_genres_list)
# Out:
# ['Music', 'Animation', 'TV Movie', 'Mystery', 'Adventure', 'War', 'Fantasy', 'Crime', 'Drama', 'Family', 'Thriller', 'Action', 'Comedy', 'misc', 'Science Fiction', 'Documentary', 'Western', 'History', 'Horror', 'Romance']

# %% [markdown]
# ## Relations

# %%
print(relations_people_data_tmdb[0])
# Out:
# {'name': "Charlotte's Web", 'year': '2006', 'cast': ['Dakota Fanning', 'Julia Roberts', 'Steve Buscemi', 'Oprah Winfrey'], 'director': [], 'writer': []}

# %%
relations_list = []

for movie_info in filtered_data:
    name = movie_info['name']
    genre = movie_info['genres']
    year = movie_info['year']

    temp_data = next((item for item in relations_people_data_tmdb if item['name'] == name and item['year']==year), {})
    cast = temp_data.get('cast', [])
    director = temp_data.get('director', [])
    writer = temp_data.get('writer', [])

    relations_list.append({
        'name': name,
        'genre': genre,
        'cast': cast,
        'director': director,
        'writer': writer,
        'year': year
    })

for movie_info in relations_list:
    if movie_info['name'] == "Insidious":
        print(movie_info)
# Out:
# {'name': 'Insidious', 'genre': ['Horror', 'Thriller'], 'cast': ['Patrick Wilson', 'Rose Byrne', 'Ty Simpkins'], 'director': ['James Wan'], 'writer': [], 'year': 'None'}
# {'name': 'Insidious', 'genre': ['Horror', 'Thriller'], 'cast': ['Patrick Wilson', 'Rose Byrne', 'Ty Simpkins'], 'director': ['James Wan'], 'writer': [], 'year': '2011'}
# {'name': 'Insidious', 'genre': ['Horror', 'Thriller'], 'cast': ['Patrick Wilson', 'Rose Byrne', 'Ty Simpkins'], 'director': ['James Wan'], 'writer': [], 'year': '2010'}

# %%
temp_data
# Out:
# {'name': 'Justice', 'year': '1914', 'cast': [], 'director': [], 'writer': []}

# %%
relations_list
# Out:
# [{'name': "Charlotte's Web",
#   'genre': ['Comedy', 'Family', 'Fantasy'],
#   'cast': ['Dakota Fanning',
#    'Julia Roberts',
#    'Steve Buscemi',
#    'Oprah Winfrey'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Everything You Always Wanted to Know About Sex*',
#   'genre': ['Comedy'],
#   'cast': ['Woody Allen'],
#   'director': ['Woody Allen'],
#   'writer': [],
#   'year': '1972'},
#  {'name': 'Rock-a-Doodle',
#   'genre': ['Comedy', 'Family', 'Animation', 'Fantasy', 'Music'],
#   'cast': ['Glen Campbell'],
#   'director': ['Don Bluth'],
#   'writer': ['Don Bluth'],
#   'year': '1991'},
#  {'name': 'Too Late',
#   'genre': ['Drama', 'Crime', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Law Abiding Citizen',
#   'genre': ['Drama', 'Crime', 'Thriller'],
#   'cast': ['Jamie Foxx', 'Gerard Butler'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'The Black Mask',
#   'genre': ['Crime'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1935'},
#  {'name': 'Club Dread',
#   'genre': ['Comedy', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Moana',
#   'genre': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'cast': ['Dwayne Johnson'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Signs',
#   'genre': ['Drama', 'Thriller', 'Science Fiction', 'Mystery'],
#   'cast': ['Mel Gibson', 'Joaquin Phoenix', 'Abigail Breslin'],
#   'director': ['M. Night Shyamalan'],
#   'writer': ['M. Night Shyamalan'],
#   'year': '2002'},
#  {'name': 'Beyond the Valley of the Dolls',
#   'genre': ['Comedy', 'Drama', 'Music'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1970'},
#  {'name': 'Beastly',
#   'genre': ['Drama', 'Fantasy', 'Romance'],
#   'cast': ['Neil Patrick Harris'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Victoria',
#   'genre': ['Crime', 'Thriller', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'The Duel',
#   'genre': ['Western', 'Drama'],
#   'cast': ['Woody Harrelson'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'American Ninja 2: The Confrontation',
#   'genre': ['Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'Earth to Echo',
#   'genre': ['Family', 'Adventure', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Amélie',
#   'genre': ['Comedy', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Born Free',
#   'genre': ['Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1966'},
#  {'name': 'Son in Law',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'cast': ['Pauly Shore'],
#   'director': [],
#   'writer': [],
#   'year': '1993'},
#  {'name': 'Killer Klowns from Outer Space',
#   'genre': ['Comedy', 'Horror', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1988'},
#  {'name': 'Holiday Inn',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'cast': ['Bing Crosby', 'Fred Astaire'],
#   'director': [],
#   'writer': [],
#   'year': '1942'},
#  {'name': 'Dracula Untold',
#   'genre': ['Horror', 'Action', 'Fantasy'],
#   'cast': ['Art Parkinson'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Tom and Jerry: The Fast and the Furry',
#   'genre': ['Family', 'Animation', 'Comedy', 'Action', 'Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Shanghai Knights',
#   'genre': ['Action', 'Adventure', 'Comedy', 'Western'],
#   'cast': ['Jackie Chan', 'Owen Wilson', 'Donnie Yen'],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Dirty Dancing: Havana Nights',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Ghost in the Shell: Stand Alone Complex - Solid State Society',
#   'genre': ['Animation', 'Action', 'Thriller', 'Crime', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Chasing Mavericks',
#   'genre': ['Drama'],
#   'cast': ['Gerard Butler'],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': "Sophie's Choice",
#   'genre': ['Drama', 'Romance', 'War'],
#   'cast': ['Meryl Streep', 'Kevin Kline'],
#   'director': [],
#   'writer': [],
#   'year': '1982'},
#  {'name': 'Secondhand Lions',
#   'genre': ['Family', 'Comedy'],
#   'cast': ['Michael Caine', 'Haley Joel Osment'],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Rio 2',
#   'genre': ['Animation', 'Adventure', 'Comedy', 'Family'],
#   'cast': ['Jesse Eisenberg', 'Anne Hathaway', 'Jamie Foxx', 'Leslie Mann'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Places in the Heart',
#   'genre': ['Drama'],
#   'cast': ['Sally Field', 'Danny Glover', 'Ed Harris'],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'The Incident',
#   'genre': ['Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Police Story 2',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Not Fade Away',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': ['David Chase'],
#   'writer': ['David Chase'],
#   'year': '2012'},
#  {'name': 'In the Mood for Love',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Kaizoku Sentai Gokaiger the Movie: The Flying Ghost Ship',
#   'genre': ['Action', 'Adventure', 'Science Fiction', 'Fantasy', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'To Live and Die in L.A.',
#   'genre': ['Crime', 'Thriller', 'Action'],
#   'cast': ['Willem Dafoe'],
#   'director': [],
#   'writer': [],
#   'year': '1985'},
#  {'name': 'The Young Guns',
#   'genre': ['Western'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1956'},
#  {'name': 'Secret Window',
#   'genre': ['Mystery', 'Thriller'],
#   'cast': ['Johnny Depp'],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Ladybird, Ladybird',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'Robot Stories',
#   'genre': ['Drama', 'Science Fiction', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Amelia',
#   'genre': ['Adventure', 'Drama'],
#   'cast': ['Hilary Swank', 'Richard Gere'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': '21',
#   'genre': ['Drama', 'Crime'],
#   'cast': ['Jim Sturgess', 'Kevin Spacey', 'Kate Bosworth'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'The Rocky Horror Picture Show',
#   'genre': ['Comedy', 'Science Fiction', 'Fantasy', 'Horror'],
#   'cast': ['Tim Curry', 'Susan Sarandon'],
#   'director': [],
#   'writer': [],
#   'year': '1975'},
#  {'name': 'Curse of Chucky',
#   'genre': ['Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Timeline',
#   'genre': ['Action', 'Adventure', 'Science Fiction'],
#   'cast': ['Paul Walker', 'Gerard Butler'],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Picnic at Hanging Rock',
#   'genre': ['Drama', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1975'},
#  {'name': 'Epic Movie',
#   'genre': ['Comedy', 'Action', 'Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Homeward Bound',
#   'genre': ['Adventure', 'Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1923'},
#  {'name': "White Men Can't Jump",
#   'genre': ['Comedy', 'Drama'],
#   'cast': ['Wesley Snipes', 'Woody Harrelson'],
#   'director': [],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'These Final Hours',
#   'genre': ['Science Fiction', 'Drama', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Fast 8',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Herbie: Fully Loaded',
#   'genre': ['Comedy', 'Family', 'Adventure', 'Fantasy', 'Romance'],
#   'cast': ['Lindsay Lohan', 'Michael Keaton', 'Matt Dillon', 'Justin Long'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': "Baby's Day Out",
#   'genre': ['Family', 'Comedy', 'Adventure', 'Crime', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'Forever Young',
#   'genre': ['Adventure', 'Fantasy', 'Drama', 'Science Fiction', 'Romance'],
#   'cast': ['Mel Gibson', 'Jamie Lee Curtis'],
#   'director': [],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'Spider',
#   'genre': ['Drama', 'Comedy', 'Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Fat Man and Little Boy',
#   'genre': ['Drama', 'History', 'War'],
#   'cast': ['Paul Newman', 'John Cusack'],
#   'director': [],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'Hard Boiled',
#   'genre': ['Action', 'Thriller', 'Crime'],
#   'cast': [],
#   'director': ['John Woo'],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'The Eye',
#   'genre': ['Drama', 'Horror', 'Thriller'],
#   'cast': ['Jessica Alba'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'List of accolades received by Gone Girl',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Like Water for Chocolate',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'Urban Legend',
#   'genre': ['Horror', 'Mystery'],
#   'cast': ['Jared Leto'],
#   'director': [],
#   'writer': [],
#   'year': '1998'},
#  {'name': 'Dr. Strangelove',
#   'genre': ['Comedy', 'War'],
#   'cast': ['Peter Sellers'],
#   'director': ['Stanley Kubrick'],
#   'writer': [],
#   'year': '1964'},
#  {'name': 'Concussion',
#   'genre': ['Drama'],
#   'cast': ['Will Smith', 'Alec Baldwin', 'Albert Brooks'],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Breathe',
#   'genre': ['Crime', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Appleseed Ex Machina',
#   'genre': ['Animation', 'Action', 'Thriller', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Shaolin Temple',
#   'genre': ['Action', 'Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1976'},
#  {'name': 'Cheaper by the Dozen',
#   'genre': ['Comedy', 'Family'],
#   'cast': ['Steve Martin', 'Hilary Duff'],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Windy City Heat',
#   'genre': ['Comedy'],
#   'cast': ['Perry Caravello', 'Dane Cook'],
#   'director': [],
#   'writer': ['Jimmy Kimmel'],
#   'year': 'None'},
#  {'name': 'Dog Days',
#   'genre': ['Drama', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Dead Silence',
#   'genre': ['Horror'],
#   'cast': [],
#   'director': ['James Wan'],
#   'writer': ['James Wan'],
#   'year': '2007'},
#  {'name': "Your Sister's Sister",
#   'genre': ['Comedy'],
#   'cast': ['Emily Blunt'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'City of Angels',
#   'genre': ['Romance', 'Drama', 'Fantasy'],
#   'cast': ['Nicolas Cage', 'Meg Ryan'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Gosford Park',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': "You Don't Mess with the Zohan",
#   'genre': ['Comedy', 'Action'],
#   'cast': ['Adam Sandler', 'Nick Swardson'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': "Cheech & Chong's Animated Movie",
#   'genre': ['Animation', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Beware! The Blob',
#   'genre': ['Comedy', 'Science Fiction', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1972'},
#  {'name': 'The Uncomfortable Camera',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Hook',
#   'genre': ['Adventure', 'Fantasy', 'Comedy', 'Family'],
#   'cast': ['Dustin Hoffman', 'Robin Williams', 'Julia Roberts', 'Bob Hoskins'],
#   'director': ['Steven Spielberg'],
#   'writer': [],
#   'year': '1991'},
#  {'name': 'Winter Passing',
#   'genre': ['Comedy', 'Drama'],
#   'cast': ['Zooey Deschanel', 'Will Ferrell', 'Ed Harris'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Little Giants',
#   'genre': ['Comedy', 'Family'],
#   'cast': ['Rick Moranis'],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'Failure to Launch',
#   'genre': ['Comedy', 'Romance'],
#   'cast': ['Matthew McConaughey',
#    'Zooey Deschanel',
#    'Justin Bartha',
#    'Bradley Cooper'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Benji the Hunted',
#   'genre': ['Action', 'Adventure', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'Father of the Bride Part II',
#   'genre': ['Comedy', 'Family'],
#   'cast': ['Steve Martin', 'Diane Keaton', 'Martin Short'],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'King Boxer',
#   'genre': ['Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1972'},
#  {'name': 'Bully',
#   'genre': ['Crime', 'Drama'],
#   'cast': ['Brad Renfro'],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Finding Dory',
#   'genre': ['Adventure', 'Animation', 'Comedy', 'Family'],
#   'cast': ['Albert Brooks', 'Ellen DeGeneres', 'Diane Keaton'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Run for Money',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'Stuart Little',
#   'genre': ['Family', 'Fantasy', 'Comedy', 'Adventure'],
#   'cast': ['Nathan Lane'],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'Acts of Worship',
#   'genre': ['Drama', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Dying of Laughter',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'Y Tu Mamá También',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Lockout',
#   'genre': ['Action', 'Thriller', 'Science Fiction'],
#   'cast': ['Guy Pearce'],
#   'director': [],
#   'writer': ['Luc Besson'],
#   'year': '2012'},
#  {'name': 'Eddie and the Cruisers II: Eddie Lives!',
#   'genre': ['Drama', 'Thriller', 'Music'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'Jeepers Creepers',
#   'genre': ['Horror', 'Thriller', 'Mystery', 'Drama'],
#   'cast': ['Justin Long'],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Le Mans',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1970'},
#  {'name': 'The Sisterhood of the Traveling Pants 2',
#   'genre': ['Adventure', 'Comedy', 'Drama'],
#   'cast': ['Blake Lively'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Wreckers',
#   'genre': ['Drama'],
#   'cast': ['Benedict Cumberbatch'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Death at a Funeral',
#   'genre': ['Comedy'],
#   'cast': ['Chris Rock', 'Martin Lawrence', 'Regina Hall'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Judge Dredd',
#   'genre': ['Science Fiction'],
#   'cast': ['Sylvester Stallone', 'Diane Lane', 'Rob Schneider'],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': '12',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'The Call',
#   'genre': ['Crime', 'Thriller'],
#   'cast': ['Halle Berry', 'Abigail Breslin', 'Morris Chestnut'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Heaven & Earth',
#   'genre': ['History', 'War', 'Action', 'Drama'],
#   'cast': ['Tommy Lee Jones'],
#   'director': ['Oliver Stone'],
#   'writer': [],
#   'year': '1993'},
#  {'name': 'Without Permission',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'Charlie St. Cloud',
#   'genre': ['Drama', 'Romance'],
#   'cast': ['Zac Efron'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'One Piece Film: Z',
#   'genre': ['Animation', 'Fantasy', 'Action', 'Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'The Human Centipede',
#   'genre': ['Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'The Mask',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1988'},
#  {'name': 'Cast Away',
#   'genre': ['Adventure', 'Drama'],
#   'cast': ['Tom Hanks', 'Helen Hunt'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Dogtown and Z-Boys',
#   'genre': ['Documentary'],
#   'cast': ['Sean Penn'],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Memoirs of a Geisha',
#   'genre': ['Drama', 'Romance', 'History'],
#   'cast': ['Michelle Yeoh'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Vertical Limit',
#   'genre': ['Adventure', 'Action', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Freddy Got Fingered',
#   'genre': ['Comedy'],
#   'cast': ['Tom Green'],
#   'director': ['Tom Green'],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Steve Jobs',
#   'genre': ['Drama', 'History'],
#   'cast': ['Michael Fassbender', 'Kate Winslet', 'Seth Rogen', 'Jeff Daniels'],
#   'director': ['Danny Boyle'],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Hollow Man',
#   'genre': ['Action', 'Science Fiction', 'Thriller'],
#   'cast': ['Kevin Bacon', 'Josh Brolin'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Woman on Top',
#   'genre': ['Comedy', 'Drama', 'Romance', 'Fantasy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Hamlet',
#   'genre': ['Drama', 'History'],
#   'cast': ['Mel Gibson'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'The Seven Five',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'The Wizard of Oz',
#   'genre': ['Adventure', 'Fantasy', 'Family'],
#   'cast': ['Judy Garland'],
#   'director': [],
#   'writer': [],
#   'year': '1939'},
#  {'name': 'The Best Exotic Marigold Hotel',
#   'genre': ['Drama', 'Comedy'],
#   'cast': ['Judi Dench'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Lovers',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'The Transporter',
#   'genre': ['Action', 'Crime', 'Thriller'],
#   'cast': ['Jason Statham'],
#   'director': [],
#   'writer': [],
#   'year': '2002'},
#  {'name': "My Baby's Daddy",
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Children of the Corn',
#   'genre': ['Horror', 'Thriller'],
#   'cast': ['Linda Hamilton'],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'Poverty Inc.',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Mulan',
#   'genre': ['Animation', 'Family', 'Adventure'],
#   'cast': ['Eddie Murphy'],
#   'director': [],
#   'writer': [],
#   'year': '1998'},
#  {'name': 'Drag Me to Hell',
#   'genre': ['Horror', 'Thriller'],
#   'cast': ['Justin Long'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Surf Ninjas',
#   'genre': ['Action', 'Adventure', 'Comedy', 'Family'],
#   'cast': ['Rob Schneider', 'Leslie Nielsen'],
#   'director': [],
#   'writer': [],
#   'year': '1993'},
#  {'name': 'Death Toll',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'cast': ['Lou Diamond Phillips'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Beverly Hills Cop',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'cast': ['Eddie Murphy', 'Judge Reinhold'],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'The Revenant',
#   'genre': ['Comedy', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Cowboy',
#   'genre': ['Western'],
#   'cast': ['Jack Lemmon'],
#   'director': [],
#   'writer': [],
#   'year': '1958'},
#  {'name': 'Beauty and the Bestie',
#   'genre': ['Drama', 'Action', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Saving Mr. Banks',
#   'genre': ['Comedy', 'Drama', 'History'],
#   'cast': ['Emma Thompson', 'Tom Hanks', 'Colin Farrell'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'The Holy Mountain',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1973'},
#  {'name': 'The Tooth Fairy',
#   'genre': ['Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Deadroom',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'The Square',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Fatty Joins the Force',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1913'},
#  {'name': 'The Great Mouse Detective',
#   'genre': ['Animation', 'Family', 'Adventure', 'Mystery'],
#   'cast': ['Vincent Price'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Shutter',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Home Alone 2: Lost in New York',
#   'genre': ['Comedy', 'Family', 'Adventure'],
#   'cast': ['Macaulay Culkin', 'Joe Pesci'],
#   'director': ['Chris Columbus'],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'Dial M for Murder',
#   'genre': ['Thriller', 'Crime'],
#   'cast': ['Grace Kelly'],
#   'director': ['Alfred Hitchcock'],
#   'writer': [],
#   'year': '1954'},
#  {'name': 'Maya the Bee',
#   'genre': ['Family', 'Animation'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Groundhog Day',
#   'genre': ['Romance', 'Fantasy', 'Drama', 'Comedy'],
#   'cast': ['Bill Murray'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Secretary',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2002'},
#  {'name': 'Far and Away',
#   'genre': ['Adventure', 'Drama', 'Romance', 'Western'],
#   'cast': ['Tom Cruise', 'Nicole Kidman'],
#   'director': ['Ron Howard'],
#   'writer': [],
#   'year': '1992'},
#  {'name': 'Norbit',
#   'genre': ['Comedy'],
#   'cast': ['Eddie Murphy', 'Terry Crews'],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'From Beyond',
#   'genre': ['Horror', 'Science Fiction'],
#   'cast': ['Ken Foree'],
#   'director': [],
#   'writer': [],
#   'year': '1986'},
#  {'name': "Madea's Family Reunion",
#   'genre': ['Drama', 'Comedy', 'Romance'],
#   'cast': ['Tyler Perry'],
#   'director': ['Tyler Perry'],
#   'writer': ['Tyler Perry'],
#   'year': '2006'},
#  {'name': 'Spetters',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1980'},
#  {'name': 'Amityville: The Awakening',
#   'genre': ['Thriller', 'Horror'],
#   'cast': ['Bella Thorne'],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Yours, Mine & Ours',
#   'genre': ['Comedy', 'Family', 'Romance'],
#   'cast': ['Dennis Quaid'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Evan Almighty',
#   'genre': ['Fantasy', 'Comedy', 'Family'],
#   'cast': ['Steve Carell', 'Morgan Freeman', 'Lauren Graham'],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Serenity',
#   'genre': ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#   'cast': [],
#   'director': ['Joss Whedon'],
#   'writer': ['Joss Whedon'],
#   'year': '2005'},
#  {'name': 'Apocalypse Now',
#   'genre': ['Drama', 'War'],
#   'cast': ['Laurence Fishburne'],
#   'director': [],
#   'writer': [],
#   'year': '1979'},
#  {'name': 'Everly',
#   'genre': ['Thriller', 'Action'],
#   'cast': ['Salma Hayek Pinault'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Jihad: A Story of the Others',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'The Shootist',
#   'genre': ['Western', 'Drama'],
#   'cast': ['John Wayne', 'Lauren Bacall', 'Ron Howard'],
#   'director': [],
#   'writer': [],
#   'year': '1976'},
#  {'name': 'The Danish Girl',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'RoboCop',
#   'genre': ['Action', 'Thriller', 'Science Fiction'],
#   'cast': ['Nancy Allen'],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'Cyrano de Bergerac',
#   'genre': ['Drama', 'Comedy', 'History', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1990'},
#  {'name': 'X-Men',
#   'genre': ['Action', 'Adventure', 'Science Fiction', 'Fantasy'],
#   'cast': ['James McAvoy', 'Michael Fassbender', 'Jennifer Lawrence'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Fast & Furious',
#   'genre': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'cast': ['Vin Diesel', 'Paul Walker', 'Michelle Rodriguez'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Night Train',
#   'genre': ['Thriller', 'Crime', 'Horror'],
#   'cast': ['Danny Glover', 'Steve Zahn'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Psych-Out',
#   'genre': ['Drama', 'Thriller', 'Music'],
#   'cast': ['Jack Nicholson'],
#   'director': [],
#   'writer': [],
#   'year': '1968'},
#  {'name': 'Deranged',
#   'genre': ['Crime', 'Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1974'},
#  {'name': "Charlie's Angels",
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'cast': ['Kristen Stewart', 'Patrick Stewart'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Faces in the Crowd',
#   'genre': ['Thriller', 'Crime'],
#   'cast': ['Milla Jovovich'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Tiger Zinda Hai',
#   'genre': ['Action', 'Adventure', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': "Being Elmo: A Puppeteer's Journey",
#   'genre': ['Documentary'],
#   'cast': ['Whoopi Goldberg'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Idiocracy',
#   'genre': ['Comedy', 'Science Fiction', 'Adventure'],
#   'cast': ['Luke Wilson', 'Maya Rudolph', 'Dax Shepard', 'Terry Crews'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Seed of Chucky',
#   'genre': ['Comedy', 'Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': "A Midsummer Night's Dream",
#   'genre': ['Fantasy', 'Comedy', 'Romance'],
#   'cast': ['Kevin Kline', 'Stanley Tucci'],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'When the Levees Broke',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'B*A*P*S',
#   'genre': ['Comedy'],
#   'cast': ['Halle Berry'],
#   'director': ['Robert Townsend'],
#   'writer': [],
#   'year': '1997'},
#  {'name': 'Rush Hour',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'cast': ['Jackie Chan', 'Chris Tucker'],
#   'director': [],
#   'writer': [],
#   'year': '1998'},
#  {'name': "It's a Mad, Mad, Mad, Mad World",
#   'genre': ['Action', 'Adventure', 'Comedy'],
#   'cast': ['Spencer Tracy', 'Milton Berle', 'Ethel Merman'],
#   'director': [],
#   'writer': [],
#   'year': '1963'},
#  {'name': 'Never Back Down: No Surrender',
#   'genre': ['Drama', 'Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Leap Year',
#   'genre': ['Romance', 'Comedy'],
#   'cast': ['Amy Adams', 'Adam Scott'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': "We're the Millers",
#   'genre': ['Comedy', 'Crime'],
#   'cast': ['Jennifer Aniston', 'Emma Roberts'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Sully',
#   'genre': ['Drama', 'History'],
#   'cast': ['Tom Hanks', 'Laura Linney'],
#   'director': ['Clint Eastwood'],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Elysium',
#   'genre': ['Science Fiction', 'Action', 'Drama', 'Thriller'],
#   'cast': ['Matt Damon', 'Jodie Foster'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': "Gerald's Game",
#   'genre': ['Horror', 'Thriller'],
#   'cast': [],
#   'director': ['Mike Flanagan'],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Fantastic Four',
#   'genre': ['Action', 'Adventure', 'Science Fiction'],
#   'cast': ['Miles Teller'],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Guess Who',
#   'genre': ['Comedy', 'Romance'],
#   'cast': ['Bernie Mac', 'Ashton Kutcher'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Doctor Who',
#   'genre': ['TV Movie', 'Adventure', 'Science Fiction'],
#   'cast': ['Eric Roberts'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Snowpiercer',
#   'genre': ['Action', 'Science Fiction', 'Drama'],
#   'cast': ['Chris Evans'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'The Bridge on the River Kwai',
#   'genre': ['Drama', 'History', 'War'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1957'},
#  {'name': 'S',
#   'genre': ['Comedy', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'The Expendables',
#   'genre': ['Thriller', 'Adventure', 'Action'],
#   'cast': ['Sylvester Stallone', 'Jason Statham', 'Jet Li', 'Eric Roberts'],
#   'director': ['Sylvester Stallone'],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Once Upon a Time in America',
#   'genre': ['Drama', 'Crime'],
#   'cast': ['Robert De Niro'],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'Flatliners',
#   'genre': ['Drama', 'Science Fiction', 'Horror'],
#   'cast': ['Kiefer Sutherland',
#    'Julia Roberts',
#    'Kevin Bacon',
#    'William Baldwin'],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Heat',
#   'genre': ['Action', 'Crime', 'Drama'],
#   'cast': ['Al Pacino', 'Robert De Niro', 'Val Kilmer'],
#   'director': ['Michael Mann'],
#   'writer': [],
#   'year': '1996'},
#  {'name': 'Changeling',
#   'genre': ['Crime', 'Drama', 'Mystery'],
#   'cast': ['Angelina Jolie'],
#   'director': ['Clint Eastwood'],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Einstein Girl',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'The Town',
#   'genre': ['Crime', 'Drama', 'Thriller'],
#   'cast': ['Ben Affleck', 'Jeremy Renner', 'Blake Lively'],
#   'director': ['Ben Affleck'],
#   'writer': [],
#   'year': '2010'},
#  {'name': "Valentine's Day",
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': '13th',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Fever',
#   'genre': ['Mystery', 'Crime'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'The Bridesmaid',
#   'genre': ['Thriller', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Crank',
#   'genre': ['Action', 'Thriller', 'Crime'],
#   'cast': ['Jason Statham'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Aladdin',
#   'genre': ['Adventure', 'Fantasy', 'Romance', 'Family'],
#   'cast': ['Will Smith'],
#   'director': ['Guy Ritchie'],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'The Little Mermaid',
#   'genre': ['Animation', 'Family', 'Fantasy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'Four Sisters and a Wedding',
#   'genre': ['Family', 'Comedy', 'Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': '79 A.D.',
#   'genre': ['Drama', 'History'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Bottle Rocket',
#   'genre': ['Comedy', 'Crime', 'Drama'],
#   'cast': ['Owen Wilson', 'Luke Wilson'],
#   'director': ['Wes Anderson'],
#   'writer': [],
#   'year': '1996'},
#  {'name': 'Love Station',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'American Made',
#   'genre': ['Action', 'Comedy', 'Crime', 'Drama', 'Thriller'],
#   'cast': ['Tom Cruise'],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Pokémon 3: The Movie',
#   'genre': ['Adventure', 'Fantasy', 'Animation', 'Action', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Swades',
#   'genre': ['Drama', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'The Road to El Dorado',
#   'genre': ['Family', 'Adventure', 'Animation', 'Comedy', 'Fantasy'],
#   'cast': ['Kevin Kline'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Tequila Sunrise',
#   'genre': ['Thriller', 'Crime', 'Romance'],
#   'cast': ['Mel Gibson', 'Kurt Russell'],
#   'director': [],
#   'writer': [],
#   'year': '1988'},
#  {'name': 'Where the Money Is',
#   'genre': ['Comedy', 'Crime', 'Drama'],
#   'cast': ['Paul Newman'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Scent of a Woman',
#   'genre': ['Comedy', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1974'},
#  {'name': 'For Love of the Game',
#   'genre': ['Drama', 'Romance'],
#   'cast': ['Kevin Costner', 'Jena Malone', 'Brian Cox'],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'The Vanishing',
#   'genre': ['Thriller', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1988'},
#  {'name': 'Super8',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Superman: Doomsday',
#   'genre': ['Action', 'Animation', 'Science Fiction', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Taking Lives',
#   'genre': ['Crime', 'Thriller'],
#   'cast': ['Angelina Jolie', 'Ethan Hawke', 'Kiefer Sutherland'],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Never Say Die',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1939'},
#  {'name': 'The Single Moms Club',
#   'genre': ['Drama', 'Comedy'],
#   'cast': [],
#   'director': ['Tyler Perry'],
#   'writer': ['Tyler Perry'],
#   'year': '2014'},
#  {'name': 'Thirteen Days',
#   'genre': ['Drama', 'History', 'Thriller', 'War'],
#   'cast': ['Kevin Costner'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Richie Rich',
#   'genre': ['Comedy', 'Family'],
#   'cast': ['Macaulay Culkin'],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'The Beatles: Eight Days a Week',
#   'genre': ['Documentary', 'Music'],
#   'cast': [],
#   'director': ['Ron Howard'],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Mars',
#   'genre': ['Action', 'Horror', 'Science Fiction'],
#   'cast': ['Ice Cube', 'Jason Statham'],
#   'director': ['John Carpenter'],
#   'writer': ['John Carpenter'],
#   'year': '2004'},
#  {'name': 'Lucy',
#   'genre': ['TV Movie', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Love Shack',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Where to Invade Next',
#   'genre': ['Documentary'],
#   'cast': ['Michael Moore'],
#   'director': ['Michael Moore'],
#   'writer': ['Michael Moore'],
#   'year': '2015'},
#  {'name': 'Forever Strong',
#   'genre': ['Drama', 'Action'],
#   'cast': ['Sean Astin'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Birdman',
#   'genre': ['Drama', 'Comedy'],
#   'cast': ['Michael Keaton',
#    'Emma Stone',
#    'Zach Galifianakis',
#    'Edward Norton'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Horrible Bosses 2',
#   'genre': ['Comedy'],
#   'cast': ['Jason Bateman', 'Charlie Day', 'Jennifer Aniston', 'Kevin Spacey'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'The Family Stone',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'cast': ['Diane Keaton', 'Luke Wilson', 'Claire Danes'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Tron: Legacy',
#   'genre': ['Adventure', 'Action', 'Science Fiction'],
#   'cast': ['Jeff Bridges'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Inferno',
#   'genre': ['Mystery', 'Thriller', 'Action'],
#   'cast': ['Tom Hanks'],
#   'director': ['Ron Howard'],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'A Home at the End of the World',
#   'genre': ['Drama', 'Romance'],
#   'cast': ['Colin Farrell', 'Robin Wright'],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Herbie',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1965'},
#  {'name': 'Dracula 3D',
#   'genre': ['Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'The Gift',
#   'genre': ['Horror', 'Drama', 'Thriller', 'Mystery'],
#   'cast': ['Cate Blanchett', 'Keanu Reeves', 'Katie Holmes', 'Greg Kinnear'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Jiro Dreams of Sushi',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Wrong Cops',
#   'genre': ['Comedy', 'Crime', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Ghosts',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1915'},
#  {'name': 'Titan A.E.',
#   'genre': ['Animation', 'Action', 'Science Fiction', 'Family', 'Adventure'],
#   'cast': ['Matt Damon', 'Drew Barrymore', 'Nathan Lane'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Hamburger Hill',
#   'genre': ['War', 'Action', 'Drama'],
#   'cast': ['Don Cheadle'],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'God Bless America',
#   'genre': ['Comedy', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Breaking Dawn',
#   'genre': ['Mystery', 'Thriller', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'Man on Wire',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'The Last Escape',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'The American',
#   'genre': ['Crime', 'Drama', 'Thriller'],
#   'cast': ['George Clooney'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Paranormal Activity 3',
#   'genre': ['Horror', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'The Odd Life of Timothy Green',
#   'genre': ['Fantasy', 'Drama', 'Comedy', 'Family'],
#   'cast': ['Jennifer Garner', 'Ron Livingston'],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'Swiss Army Man',
#   'genre': ['Comedy', 'Drama', 'Romance', 'Fantasy', 'Adventure'],
#   'cast': ['Daniel Radcliffe'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Black Belt',
#   'genre': ['Action', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Easy Rider',
#   'genre': ['Adventure', 'Drama'],
#   'cast': ['Dennis Hopper', 'Jack Nicholson'],
#   'director': ['Dennis Hopper'],
#   'writer': [],
#   'year': '1969'},
#  {'name': 'A.I. Artificial Intelligence',
#   'genre': ['Drama', 'Science Fiction', 'Adventure'],
#   'cast': ['Haley Joel Osment', 'Jude Law'],
#   'director': ['Steven Spielberg'],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'National Treasure: Book of Secrets',
#   'genre': ['Action', 'Adventure', 'Mystery', 'Thriller'],
#   'cast': ['Nicolas Cage', 'Ed Harris'],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'The Belko Experiment',
#   'genre': ['Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Where the Red Fern Grows',
#   'genre': ['Drama', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1974'},
#  {'name': 'Blue Hawaii',
#   'genre': ['Comedy', 'Music'],
#   'cast': ['Angela Lansbury'],
#   'director': [],
#   'writer': [],
#   'year': '1961'},
#  {'name': 'Temptation: Confessions of a Marriage Counselor',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': ['Tyler Perry'],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Romance',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1920'},
#  {'name': 'My Father the Hero',
#   'genre': ['Family', 'Comedy', 'Romance'],
#   'cast': ['Katherine Heigl'],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'Woody Woodpecker',
#   'genre': ['Comedy', 'Family', 'Animation'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Wings of Life',
#   'genre': ['Documentary'],
#   'cast': ['Meryl Streep'],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Contact',
#   'genre': ['Drama', 'Science Fiction', 'Mystery'],
#   'cast': ['Jodie Foster', 'Matthew McConaughey'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Rob Roy',
#   'genre': ['Adventure', 'History', 'Drama', 'Action', 'War'],
#   'cast': ['Liam Neeson'],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'Jump',
#   'genre': ['Drama', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': "Everybody's Fine",
#   'genre': ['Drama'],
#   'cast': ['Robert De Niro',
#    'Drew Barrymore',
#    'Kate Beckinsale',
#    'Sam Rockwell'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'August: Osage County',
#   'genre': ['Comedy', 'Drama'],
#   'cast': ['Julia Roberts', 'Meryl Streep', 'Juliette Lewis'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Mission: Impossible III',
#   'genre': ['Adventure', 'Action', 'Thriller'],
#   'cast': ['Tom Cruise', 'Michelle Monaghan'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'How to Succeed in Business Without Really Trying',
#   'genre': ['Comedy', 'Music'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Toy Story That Time Forgot',
#   'genre': ['Animation', 'Family', 'Adventure', 'Comedy'],
#   'cast': ['Tom Hanks', 'Tim Allen'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Cry-Baby',
#   'genre': ['Comedy', 'Romance'],
#   'cast': ['Johnny Depp', 'Ricki Lake'],
#   'director': ['John Waters'],
#   'writer': ['John Waters'],
#   'year': '1990'},
#  {'name': 'Fred Claus',
#   'genre': ['Action', 'Comedy', 'Drama'],
#   'cast': ['Vince Vaughn', 'Rachel Weisz'],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Dune',
#   'genre': ['Action', 'Science Fiction', 'Adventure'],
#   'cast': ['Patrick Stewart'],
#   'director': ['David Lynch'],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'The Poseidon Adventure',
#   'genre': ['Adventure', 'Thriller', 'Action'],
#   'cast': ['Gene Hackman'],
#   'director': [],
#   'writer': [],
#   'year': '1972'},
#  {'name': 'Dangerous Minds',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'Hanna',
#   'genre': ['Action', 'Thriller', 'Adventure'],
#   'cast': ['Saoirse Ronan', 'Eric Bana', 'Cate Blanchett'],
#   'director': ['Joe Wright'],
#   'writer': [],
#   'year': '2011'},
#  {'name': "Can't Buy Me Love",
#   'genre': ['Drama', 'Comedy', 'Romance'],
#   'cast': ['Patrick Dempsey', 'Seth Green'],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'To Wong Foo, Thanks for Everything! Julie Newmar',
#   'genre': ['Comedy'],
#   'cast': ['Patrick Swayze', 'Wesley Snipes'],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': "Mr. Holland's Opus",
#   'genre': ['Drama', 'Music', 'Family'],
#   'cast': ['Richard Dreyfuss'],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'Into the Woods',
#   'genre': ['Fantasy', 'Comedy'],
#   'cast': ['Meryl Streep', 'Emily Blunt', 'Anna Kendrick', 'Chris Pine'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Spirited Away',
#   'genre': ['Animation', 'Family', 'Fantasy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Cowspiracy',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Bird on a Wire',
#   'genre': ['Action', 'Adventure', 'Comedy', 'Romance'],
#   'cast': ['Mel Gibson', 'Goldie Hawn', 'David Carradine'],
#   'director': [],
#   'writer': [],
#   'year': '1990'},
#  {'name': '42',
#   'genre': ['Drama'],
#   'cast': ['Chadwick Boseman', 'Harrison Ford'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Kingdom of Heaven',
#   'genre': ['Drama', 'Action', 'Adventure', 'History', 'War'],
#   'cast': ['Orlando Bloom', 'Eva Green', 'Jeremy Irons', 'Edward Norton'],
#   'director': ['Ridley Scott'],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Nightcrawler',
#   'genre': ['Crime', 'Drama', 'Thriller'],
#   'cast': ['Jake Gyllenhaal'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'A Taste of Honey',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1961'},
#  {'name': 'Joseph: King of Dreams',
#   'genre': ['Family', 'Animation', 'Fantasy'],
#   'cast': ['Ben Affleck', 'Mark Hamill'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Heaven Is for Real',
#   'genre': ['Drama'],
#   'cast': ['Greg Kinnear', 'Connor Corum'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'M. Butterfly',
#   'genre': ['Romance', 'Drama'],
#   'cast': ['Jeremy Irons'],
#   'director': [],
#   'writer': [],
#   'year': '1993'},
#  {'name': 'The First Monday in May',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Gun Shy',
#   'genre': ['Action', 'Comedy', 'Romance', 'Thriller'],
#   'cast': ['Sandra Bullock', 'Liam Neeson'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Open House',
#   'genre': ['Drama', 'Horror', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Dusk to Dawn',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1922'},
#  {'name': 'The Man Who Knew Infinity',
#   'genre': ['Drama'],
#   'cast': ['Jeremy Irons'],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Avatar',
#   'genre': ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#   'cast': ['Michelle Rodriguez', 'Sigourney Weaver'],
#   'director': ['James Cameron'],
#   'writer': ['James Cameron'],
#   'year': '2009'},
#  {'name': 'The Replacements',
#   'genre': ['Comedy'],
#   'cast': ['Keanu Reeves', 'Gene Hackman'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'True Romance',
#   'genre': ['Action', 'Crime', 'Romance'],
#   'cast': ['Christian Slater', 'Patricia Arquette', 'Gary Oldman'],
#   'director': ['Tony Scott'],
#   'writer': ['Quentin Tarantino'],
#   'year': '1993'},
#  {'name': 'Collateral Beauty',
#   'genre': ['Drama', 'Romance'],
#   'cast': ['Will Smith', 'Edward Norton', 'Kate Winslet', 'Helen Mirren'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Goldie',
#   'genre': ['Comedy'],
#   'cast': ['Spencer Tracy'],
#   'director': [],
#   'writer': [],
#   'year': '1931'},
#  {'name': 'Extract',
#   'genre': ['Comedy'],
#   'cast': ['Jason Bateman', 'Mila Kunis', 'Kristen Wiig', 'Ben Affleck'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': '...When Love Happens',
#   'genre': ['Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Jackass 3D',
#   'genre': ['Comedy', 'Documentary', 'Action'],
#   'cast': ['Johnny Knoxville'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': "The Hitchhiker's Guide to the Galaxy",
#   'genre': ['Adventure', 'Comedy', 'Science Fiction'],
#   'cast': ['Martin Freeman',
#    'Zooey Deschanel',
#    'Sam Rockwell',
#    'Alan Rickman'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'May',
#   'genre': ['Comedy', 'Drama', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2002'},
#  {'name': 'Jack Ryan: Shadow Recruit',
#   'genre': ['Action', 'Drama', 'Thriller'],
#   'cast': ['Chris Pine', 'Keira Knightley', 'Kevin Costner'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Sugar and Spice',
#   'genre': ['Action', 'Comedy', 'Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Final',
#   'genre': ['Drama', 'Science Fiction', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Stargate: The Ark of Truth',
# ...
#   'genre': ['Comedy', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1977'},
#  {'name': 'The Computer Wore Tennis Shoes',
#   'genre': ['Comedy', 'Family', 'Drama'],
#   'cast': ['Kurt Russell'],
#   'director': [],
#   'writer': [],
#   'year': '1969'},
#  {'name': 'The Magnificent Seven',
#   'genre': ['Adventure', 'Action', 'Western'],
#   'cast': ['Denzel Washington', 'Chris Pratt', 'Ethan Hawke'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Kevin Hart: What Now%3F',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Zombieland',
#   'genre': ['Comedy', 'Horror'],
#   'cast': ['Woody Harrelson',
#    'Jesse Eisenberg',
#    'Emma Stone',
#    'Abigail Breslin'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Indiana Jones',
#   'genre': ['Adventure', 'Action'],
#   'cast': ['Harrison Ford'],
#   'director': ['James Mangold'],
#   'writer': ['James Mangold'],
#   'year': 'None'},
#  {'name': 'The Dilemma',
#   'genre': ['Comedy', 'Drama'],
#   'cast': ['Vince Vaughn', 'Kevin James', 'Winona Ryder', 'Queen Latifah'],
#   'director': ['Ron Howard'],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Speed',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'Little England',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Men in Black',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1934'},
#  {'name': 'The Fifth Seal',
#   'genre': ['Drama', 'War'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1976'},
#  {'name': 'The Bad News Bears',
#   'genre': ['Family', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1976'},
#  {'name': 'Corpse Bride',
#   'genre': ['Romance', 'Fantasy', 'Animation'],
#   'cast': ['Johnny Depp', 'Emily Watson'],
#   'director': ['Tim Burton'],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'The Princess Diaries 2: Royal Engagement',
#   'genre': ['Comedy', 'Drama', 'Family', 'Romance'],
#   'cast': ['Anne Hathaway', 'Julie Andrews'],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'The Lovers',
#   'genre': ['Action', 'Adventure', 'Science Fiction', 'Romance'],
#   'cast': ['Josh Hartnett'],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Casting JonBenet',
#   'genre': ['Documentary', 'Crime'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Nora',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1944'},
#  {'name': "2016: Obama's America",
#   'genre': ['Documentary', 'Fantasy'],
#   'cast': ['Barack Obama'],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'My Friend Dahmer',
#   'genre': ['History', 'Drama', 'Crime', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Ten Dead Men',
#   'genre': ['Action', 'Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Pinocchio',
#   'genre': ['Animation', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'Days of Glory',
#   'genre': ['Drama', 'History', 'War'],
#   'cast': ['Jamel Debbouze'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Get Over It',
#   'genre': ['Comedy', 'Romance'],
#   'cast': ['Ben Foster', 'Shane West'],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'Dirty Mary, Crazy Larry',
#   'genre': ['Action', 'Adventure', 'Crime', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1974'},
#  {'name': 'Because of You',
#   'genre': ['Drama', 'Romance'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1952'},
#  {'name': 'Mansfield Park',
#   'genre': ['Romance', 'Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': 'Hauling',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'Fatal Attraction',
#   'genre': ['Drama', 'Thriller'],
#   'cast': ['Michael Douglas'],
#   'director': [],
#   'writer': [],
#   'year': '1987'},
#  {'name': 'Requiem',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'Hotel Artemis',
#   'genre': ['Thriller', 'Science Fiction', 'Action'],
#   'cast': ['Jodie Foster', 'Jeff Goldblum'],
#   'director': [],
#   'writer': [],
#   'year': '2018'},
#  {'name': 'Oliver & Company',
#   'genre': ['Animation', 'Comedy', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Hostage',
#   'genre': ['Action', 'Thriller', 'Crime'],
#   'cast': ['Bruce Willis', 'Ben Foster'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Bowfinger',
#   'genre': ['Comedy'],
#   'cast': ['Steve Martin', 'Eddie Murphy'],
#   'director': [],
#   'writer': [],
#   'year': '1999'},
#  {'name': "Lady and the Tramp II: Scamp's Adventure",
#   'genre': ['Family', 'Animation', 'Romance', 'Adventure'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2001'},
#  {'name': 'When the Bough Breaks',
#   'genre': ['Mystery', 'Thriller', 'Drama', 'Horror'],
#   'cast': ['Morris Chestnut', 'Regina Hall'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'The Matador',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'For the Love of Spock',
#   'genre': ['Documentary'],
#   'cast': ['George Takei', 'Simon Pegg'],
#   'director': [],
#   'writer': [],
#   'year': '2016'},
#  {'name': 'Girls Will Be Girls',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': "Wes Craven's Chiller",
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1985'},
#  {'name': 'Capturing the Friedmans',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'The Proposal',
#   'genre': ['Comedy', 'Romance', 'Drama'],
#   'cast': ['Sandra Bullock', 'Ryan Reynolds'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'K-9',
#   'genre': ['Action', 'Comedy', 'Crime'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'Be Cool',
#   'genre': ['Comedy', 'Crime'],
#   'cast': ['John Travolta', 'Uma Thurman', 'Vince Vaughn', 'Dwayne Johnson'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'The Swan Princess',
#   'genre': ['Family', 'Animation', 'Fantasy', 'Adventure', 'Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1994'},
#  {'name': 'G.I. Blues',
#   'genre': ['Comedy', 'Music'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1960'},
#  {'name': 'Horton Hears a Who!',
#   'genre': ['Animation', 'Comedy', 'Family', 'Adventure', 'Fantasy'],
#   'cast': ['Jim Carrey', 'Steve Carell', 'Seth Rogen'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Attack on Titan',
#   'genre': ['Horror', 'Fantasy', 'Action', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Disobedience',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2003'},
#  {'name': 'Zero Effect',
#   'genre': ['Comedy', 'Crime', 'Mystery', 'Thriller'],
#   'cast': ['Ben Stiller'],
#   'director': [],
#   'writer': [],
#   'year': '1998'},
#  {'name': 'Super 8',
#   'genre': ['Thriller', 'Science Fiction', 'Mystery'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': "Pirates of the Caribbean: At World's End",
#   'genre': ['Adventure', 'Fantasy', 'Action'],
#   'cast': ['Johnny Depp', 'Orlando Bloom', 'Keira Knightley'],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Pacquiao: The Movie',
#   'genre': ['Drama', 'Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'City of Men',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2007'},
#  {'name': 'Man of Steel',
#   'genre': ['Action', 'Adventure', 'Science Fiction'],
#   'cast': ['Amy Adams', 'Diane Lane', 'Russell Crowe'],
#   'director': ['Zack Snyder'],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Return of the Jedi',
#   'genre': ['Adventure', 'Action', 'Science Fiction'],
#   'cast': ['Mark Hamill', 'Harrison Ford', 'Carrie Fisher'],
#   'director': [],
#   'writer': [],
#   'year': '1983'},
#  {'name': 'Guys and Dolls',
#   'genre': ['Comedy', 'Crime', 'Romance'],
#   'cast': ['Marlon Brando'],
#   'director': [],
#   'writer': [],
#   'year': '1955'},
#  {'name': 'An American in Madras',
#   'genre': ['Documentary'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Insidious',
#   'genre': ['Horror', 'Thriller'],
#   'cast': ['Patrick Wilson', 'Rose Byrne', 'Ty Simpkins'],
#   'director': ['James Wan'],
#   'writer': [],
#   'year': '2011'},
#  {'name': 'Rabbits',
#   'genre': ['Horror', 'Mystery', 'Comedy'],
#   'cast': ['Naomi Watts'],
#   'director': ['David Lynch'],
#   'writer': [],
#   'year': '2002'},
#  {'name': 'Silver Streak',
#   'genre': ['Comedy', 'Crime', 'Romance', 'Thriller'],
#   'cast': ['Gene Wilder', 'Richard Pryor'],
#   'director': [],
#   'writer': [],
#   'year': '1976'},
#  {'name': 'Riddick',
#   'genre': ['Science Fiction', 'Action', 'Thriller'],
#   'cast': ['Vin Diesel'],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'To Kill a Mockingbird',
#   'genre': ['Drama'],
#   'cast': ['Gregory Peck'],
#   'director': [],
#   'writer': [],
#   'year': '1962'},
#  {'name': 'Trouble with the Curve',
#   'genre': ['Drama', 'Romance'],
#   'cast': ['Clint Eastwood', 'Amy Adams', 'Justin Timberlake'],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'A Night in Casablanca',
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1946'},
#  {'name': 'Empire of the Ants',
#   'genre': ['Horror', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1977'},
#  {'name': 'Batman',
#   'genre': ['Fantasy', 'Action', 'Crime'],
#   'cast': ['Michael Keaton', 'Jack Nicholson'],
#   'director': ['Tim Burton'],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'Bombing the Nazis',
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1943'},
#  {'name': 'Cosmos',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': '2012',
#   'genre': ['Action', 'Adventure', 'Science Fiction'],
#   'cast': ['John Cusack', 'Chiwetel Ejiofor'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Sleeping Beauty',
#   'genre': ['Fantasy', 'Animation', 'Romance', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1995'},
#  {'name': 'Going Clear',
#   'genre': ['Documentary'],
#   'cast': ['Paul Haggis'],
#   'director': [],
#   'writer': [],
#   'year': '2015'},
#  {'name': 'Mystic Pizza',
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'cast': ['Julia Roberts'],
#   'director': [],
#   'writer': [],
#   'year': '1988'},
#  {'name': 'The Transformers: The Movie',
#   'genre': ['Animation', 'Science Fiction', 'Action', 'Adventure', 'Family'],
#   'cast': ['Judd Nelson', 'Orson Welles'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': "Good Luck Charlie, It's Christmas!",
#   'genre': ['TV Movie', 'Comedy', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2011'},
#  {'name': "The 'Burbs",
#   'genre': ['Comedy', 'Horror', 'Thriller'],
#   'cast': ['Tom Hanks', 'Carrie Fisher'],
#   'director': [],
#   'writer': [],
#   'year': '1989'},
#  {'name': 'The Music Man',
#   'genre': ['Comedy', 'Family', 'Music', 'Romance'],
#   'cast': ['Ron Howard'],
#   'director': [],
#   'writer': [],
#   'year': '1962'},
#  {'name': 'Deathtrap',
#   'genre': ['Comedy', 'Mystery', 'Thriller'],
#   'cast': ['Michael Caine', 'Christopher Reeve'],
#   'director': [],
#   'writer': [],
#   'year': '1982'},
#  {'name': 'Absolute Beginners',
#   'genre': ['Drama', 'Music', 'Romance'],
#   'cast': ['David Bowie'],
#   'director': [],
#   'writer': [],
#   'year': '1986'},
#  {'name': 'The Cat Returns',
#   'genre': ['Adventure', 'Fantasy', 'Animation', 'Drama', 'Family'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'Victoria and Abdul',
#   'genre': ['Drama', 'History'],
#   'cast': ['Judi Dench', 'Adeel Akhtar'],
#   'director': [],
#   'writer': [],
#   'year': 'None'},
#  {'name': 'A Perfect Getaway',
#   'genre': ['Thriller', 'Mystery', 'Adventure'],
#   'cast': ['Steve Zahn', 'Milla Jovovich', 'Chris Hemsworth'],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'The Wicker Man',
#   'genre': ['Horror', 'Mystery', 'Thriller'],
#   'cast': ['Nicolas Cage'],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Dead Before Dawn',
#   'genre': ['Adventure', 'Comedy', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2012'},
#  {'name': 'The Last Starfighter',
#   'genre': ['Adventure', 'Science Fiction', 'Action'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1984'},
#  {'name': 'Out of the Furnace',
#   'genre': ['Thriller', 'Drama', 'Crime'],
#   'cast': ['Christian Bale', 'Woody Harrelson', 'Sam Shepard', 'Willem Dafoe'],
#   'director': ['Scott Cooper'],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Napping Princess',
#   'genre': ['Fantasy', 'Adventure', 'Animation', 'Drama', 'Science Fiction'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'American Psycho',
#   'genre': ['Thriller', 'Drama', 'Crime'],
#   'cast': ['Christian Bale', 'Willem Dafoe', 'Jared Leto'],
#   'director': [],
#   'writer': [],
#   'year': '2000'},
#  {'name': 'Pitch Perfect 3',
#   'genre': ['Comedy', 'Music'],
#   'cast': ['Anna Kendrick', 'Rebel Wilson'],
#   'director': [],
#   'writer': [],
#   'year': '2017'},
#  {'name': 'Vantage Point',
#   'genre': ['Drama', 'Action', 'Thriller', 'Crime'],
#   'cast': ['Dennis Quaid', 'Forest Whitaker', 'Sigourney Weaver'],
#   'director': [],
#   'writer': [],
#   'year': '2008'},
#  {'name': 'Terms of Endearment',
#   'genre': ['Drama', 'Comedy'],
#   'cast': ['Jack Nicholson', 'Danny DeVito', 'Jeff Daniels'],
#   'director': [],
#   'writer': [],
#   'year': '1983'},
#  {'name': "Michael Lucas' La Dolce Vita",
#   'genre': ['misc'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2006'},
#  {'name': 'Soul Plane',
#   'genre': ['Romance', 'Comedy'],
#   'cast': ['Kevin Hart', 'Tom Arnold'],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  {'name': 'The Outlaws',
#   'genre': ['Drama'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1950'},
#  {'name': 'The Hunted',
#   'genre': ['Thriller'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2013'},
#  {'name': 'Boxing Helena',
#   'genre': ['Drama', 'Romance', 'Thriller', 'Horror'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '1993'},
#  {'name': 'Halloween',
#   'genre': ['Horror', 'Thriller'],
#   'cast': ['Jamie Lee Curtis'],
#   'director': ['John Carpenter'],
#   'writer': [],
#   'year': '1978'},
#  {'name': 'The Da Vinci Code',
#   'genre': ['Thriller', 'Mystery'],
#   'cast': ['Tom Hanks', 'Jean Reno', 'Paul Bettany'],
#   'director': ['Ron Howard'],
#   'writer': [],
#   'year': '2006'},
#  {'name': "The Slammin' Salmon",
#   'genre': ['Comedy'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2009'},
#  {'name': 'Sabotage',
#   'genre': ['Action', 'Drama', 'Thriller', 'Crime'],
#   'cast': ['Arnold Schwarzenegger'],
#   'director': [],
#   'writer': [],
#   'year': '2014'},
#  {'name': 'Star Trek II: The Wrath of Khan',
#   'genre': ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#   'cast': ['George Takei'],
#   'director': [],
#   'writer': [],
#   'year': '1982'},
#  {'name': 'The Constant Gardener',
#   'genre': ['Drama', 'Mystery', 'Thriller'],
#   'cast': ['Ralph Fiennes', 'Rachel Weisz', 'Danny Huston'],
#   'director': [],
#   'writer': [],
#   'year': '2005'},
#  {'name': 'Date Night',
#   'genre': ['Comedy', 'Action', 'Adventure'],
#   'cast': ['Steve Carell', 'Tina Fey', 'Mark Wahlberg'],
#   'director': [],
#   'writer': [],
#   'year': '2010'},
#  {'name': 'A Very Long Engagement',
#   'genre': ['Drama', 'Romance', 'War'],
#   'cast': [],
#   'director': [],
#   'writer': [],
#   'year': '2004'},
#  ...]

# %% [markdown]
# # Feeding to the graph

# %%
# %pip install py2neo
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: py2neo in c:\users\taksh\appdata\roaming\python\python311\site-packages (2021.2.4)
# Requirement already satisfied: certifi in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (2023.11.17)
# Requirement already satisfied: interchange~=2021.0.4 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: monotonic in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (1.6)
# Requirement already satisfied: packaging in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (23.2)
# Requirement already satisfied: pansi>=2020.7.3 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pygments>=2.0.0 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (2.17.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (1.16.0)
# Requirement already satisfied: urllib3 in c:\users\taksh\appdata\roaming\python\python311\site-packages (from py2neo) (1.26.16)
# Requirement already satisfied: pytz in c:\users\taksh\appdata\roaming\python\python311\site-packages (from interchange~=2021.0.4->py2neo) (2023.3.post1)

# %%
from py2neo import Graph, Node, Relationship

class MovieGraph:
    def __init__(self):
        self.graph = Graph("bolt://localhost:7687", user="neo4j", password="12345678")

    def create_movie_nodes(self, movie_data):
        for movie_info in movie_data:
            movie_node = Node("Movie", title=movie_info["title"], release_year=movie_info["release_year"])
            self.graph.create(movie_node)

    def create_genre_nodes(self, genre_data):
        for genre_name in genre_data:
            genre_node = Node("Genre", title=genre_name)
            self.graph.create(genre_node)

    def create_people_nodes(self, people_data):
        for person_name in people_data:
            person_node = Node("Person", name=person_name)
            self.graph.create(person_node)

    def create_year_nodes(self, year_data):
        for year in year_data:
            year_node = Node("Year", release_year=year)
            self.graph.create(year_node)

    def create_relationships(self, relationship_data):
        for movie_info in relationship_data:
            movie_node = self.graph.nodes.match(title=movie_info["name"], release_year=movie_info["year"]).first()

            if movie_node:
                # Create relationships for genres
                for genre in movie_info.get("genre", []):
                    genre_node = self.graph.nodes.match(title=genre).first()

                    if genre_node:
                        genre_relationship = Relationship(movie_node, "HAS_GENRE", genre_node)
                        self.graph.create(genre_relationship)
                        
                        # Bidirectional relationship
                        reverse_genre_relationship = Relationship(genre_node, "GENRE_OF", movie_node)
                        self.graph.create(reverse_genre_relationship)

                # Create relationships for cast
                for cast_name in movie_info.get("cast", []):
                    cast_node = self.graph.nodes.match(name=cast_name).first()

                    if cast_node:
                        cast_relationship = Relationship(movie_node, "HAS_CAST", cast_node)
                        self.graph.create(cast_relationship)

                        # Bidirectional relationship
                        reverse_cast_relationship = Relationship(cast_node, "CAST_IN", movie_node)
                        self.graph.create(reverse_cast_relationship)

                # Create relationships for directors
                for director_name in movie_info.get("director", []):
                    director_node = self.graph.nodes.match(name=director_name).first()

                    if director_node:
                        director_relationship = Relationship(movie_node, "HAS_DIRECTOR", director_node)
                        self.graph.create(director_relationship)

                        # Bidirectional relationship
                        reverse_director_relationship = Relationship(director_node, "DIRECTED", movie_node)
                        self.graph.create(reverse_director_relationship)

                # Create relationships for writers
                for writer_name in movie_info.get("writer", []):
                    writer_node = self.graph.nodes.match(name=writer_name).first()

                    if writer_node:
                        writer_relationship = Relationship(movie_node, "HAS_WRITER", writer_node)
                        self.graph.create(writer_relationship)

                        # Bidirectional relationship
                        reverse_writer_relationship = Relationship(writer_node, "WRITTEN_BY", movie_node)
                        self.graph.create(reverse_writer_relationship)
                
                # Create relationships for years
                for year in movie_info.get("year", []):
                    year_node = self.graph.nodes.match(release_year=year).first()

                    if year_node:
                        year_relationship = Relationship(movie_node, "RELEASED_IN_YEAR", year_node)
                        self.graph.create(year_relationship)

                        # Bidirectional relationship
                        reverse_year_relationship = Relationship(year_node, "YEAR_OF_RELEASE", movie_node)
                        self.graph.create(reverse_year_relationship)


genre_data = unique_genres_list

people_data = unique_people_list

year_data = unique_years

movie_graph = MovieGraph()
movie_graph.create_movie_nodes(movie_names_data)
movie_graph.create_genre_nodes(genre_data)
movie_graph.create_people_nodes(people_data)
movie_graph.create_year_nodes(year_data)

# %%
relationship_data = relations_list
movie_graph.create_relationships(relationship_data)

# %% [markdown]
# # Playground

# %%
import pandas as pd

# Assuming your CSV file has columns: ID, Movie Name, No of Mentions
file_path = './movies_with_mentions.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Check the actual column names in your DataFrame
print("Column names:", df.columns)

# Check for duplicate entries based on the correct column name
duplicates = df[df.duplicated('movieName', keep=False)]

# Display the duplicate entries
if not duplicates.empty:
    print("Duplicate Movies:")
    print(duplicates)
    
    # Remove the duplicate entries from the DataFrame
    df = df.drop_duplicates('movieName', keep='first')
    
    print("Duplicate movies removed.")
    
    # Save the modified DataFrame back to the CSV file
    df.to_csv(file_path, index=False)
    
    print("CSV file updated.")
else:
    print("No duplicate movies found.")
# Out:
# Column names: Index(['movieId', 'movieName', 'nbMentions'], dtype='object')
# No duplicate movies found.

# %%
import json

def find_duplicates(json_file):
    # List to store duplicate entries
    duplicates = []

    # Create a dictionary to store entries based on name and year
    entries_dict = {}

    with open(json_file, 'r') as file:
        # Iterate through each line in the file
        for line in file:
            try:
                # Parse each line as JSON
                entry_data = json.loads(line)
                
                # Extract relevant information
                entry_id = entry_data.get("id")
                name = entry_data.get("name")
                year = entry_data.get("year")

                # Create a unique key based on name and year
                key = f"{name}_{year}"

                # Check if the key is already in the dictionary
                if key in entries_dict:
                    # Add the current entry and the existing entry to the duplicates list
                    duplicates.append((entry_id, entries_dict[key]))
                else:
                    # Add the entry to the dictionary
                    entries_dict[key] = entry_id

            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

    return duplicates

# Example usage
json_file_path = './movienames_year_cid.jsonl'
duplicates = find_duplicates(json_file_path)

print(duplicates)

# Print the duplicate entries
for duplicate in duplicates:
    print(f"Duplicate entries: {duplicate}")
# Out:
# [(None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, None), (None, No ...
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# ...
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)
# Duplicate entries: (None, None)

# %%
import json

def read_jsonl_to_dict(jsonl_file):
    data_dict = {}

    with open(jsonl_file, 'r') as file:
        for line in file:
            try:
                entry_data = json.loads(line)
                
                # Assuming each entry has a unique identifier as "id"
                entry_id = entry_data.get("id")

                # Add the entry to the dictionary using the entry_id as the key
                data_dict[entry_id] = entry_data

            except json.JSONDecodeError as e:
                print(f"Error decoding JSON: {e}")

    return data_dict

# Example usage
jsonl_file_path = './movienames_year_cid.jsonl'
entries_dict = read_jsonl_to_dict(jsonl_file_path)

# Print the dictionary
print(entries_dict)
# Out:
# {None: {'200018': {'name': 'The Force', 'year': None, 'conversationIds': ['19920']}}}

# %%
file_path = './movienames_year_cid.jsonl'

# Function to read a JSONL file and return a list of dictionaries
def read_jsonl(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
    return data

# %%
movieszz = read_jsonl(file_path)
# Out:
# {'111776': {'name': 'Super Troopers',
#   'year': '2001',
#   'conversationIds': ['20001',
#    '20041',
#    '20721',
#    '20838',
#    '20868',
#    '21180',
#    '21182',
#    '21183',
#    '21208',
#    '21231',
#    '21728',
#    '21825',
#    '21829',
#    '21834',
#    '21836',
#    '21838',
#    '21840',
#    '21841',
#    '21842',
#    '21845',
#    '21847',
#    '21852',
#    '21867',
#    '21869',
#    '21872',
#    '21883',
#    '21924',
#    '21992',
#    '22190',
#    '22440',
#    '22441',
#    '22446',
#    '22447',
#    '22452',
#    '22453',
#    '22454',
#    '22455',
#    '22459',
#    '22480',
#    '22482',
#    '22580',
#    '22619',
#    '22680',
#    '22683',
#    '22694',
#    '22696',
#    '22706',
#    '22707',
#    '22708',
#    '22709',
#    '22710',
#    '471',
#    '871',
#    '927',
#    '931',
#    '1057',
#    '3393',
#    '3775',
#    '3779',
#    '3824',
#    '5505',
#    '5802',
#    '5804',
#    '5943',
#    '6081',
#    '6161',
#    '6322',
#    '7323',
#    '7540',
#    '8132',
#    '9757',
#    '10580',
#    '10806',
#    '11017',
#    '12080',
#    '12164',
#    '12201',
#    '12563',
#    '13704',
#    '14133',
#    '16412',
#    '16427',
#    '16503',
#    '16699',
#    '16848',
#    '18300',
#    '18439',
#    '18451',
#    '18488',
#    '18644',
#    '18648',
#    '19280',
#    '19373',
#    '19489',
#    '19607',
#    '19627',
#    '19630',
#    '19802',
#    '19828']}}

# %%
unique_values = set()

for i in movieszz:
    for x in i:
        val = str(i[x]['name']) + "$" + str(i[x]['year'])
        unique_values.add(val)

# %%
jsonl_file_path = './bin/generated/movies_with_year.jsonl'

with open(jsonl_file_path, 'w') as file:
    for unique_value in unique_values:
        movie_name, movie_year = unique_value.split('$')
        movie_details = {"name": movie_name, "year": movie_year}  # Convert year to integer if needed
        json.dump(movie_details, file)
        file.write('\n')

# %% [markdown]
# //Code to get Actors Directos and Cast
